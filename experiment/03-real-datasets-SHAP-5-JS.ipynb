# %%
from DCC import *
from Utils import *
from Plots import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path
from collections import defaultdict

# %%
init_plotting()

# %%
dataset2name = {
    "Bala_classification_dataset.csv": "Bala Classification",
    "Bala_regression_dataset.csv": "Bala Regression",
    "bandgap.csv": "Bandgap",
    "BMDS_data.csv": "BMDS",
    "Crystal_structure.csv": "Crystal Structure",
    "Glass.csv": "Glass",
    "PUE.csv": "PUE",
}

# %%
from enum import Enum
from sklearn.datasets import make_classification


class PerturbationType(Enum):
    Deletion = "Deletion"
    AdditionLinear = "AdditionLinear"
    AdditionRand = "AdditionRand"
    ReplacementLinear = "ReplacementLinear"
    ReplacementRand = "ReplacementRand"


def generate_random_according_df(
    n: int, m: int, df: pd.DataFrame, task_type=None, target_col=None
):
    cols = df.columns
    new_data = []
    for i in range(n):
        new_row = []
        for j in range(m):
            new_row.append(random.uniform(df[cols[j]].min(), df[cols[j]].max()))
        new_data.append(new_row)
    new_df = pd.DataFrame(new_data, columns=cols)
    if task_type == "classification":
        if target_col is not None:
            new_df[target_col] = np.random.choice(
                df[target_col].unique(), size=n, replace=True
            )
    return new_df


def generate_linear_according_df(
    n: int, m: int, df: pd.DataFrame, task_type=None, target_col=None
):
    if task_type == "classification":
        # Generate a classification dataset
        X, y = make_classification(
            n_samples=n,
            n_features=m - 1,
            n_classes=len(df[target_col].unique()),
            n_informative= (m - 1) // 2,
        )[:2]
    else:
        X, y = make_regression(
            n_samples=n, n_features=m - 1, noise=0.1
        )[:2]

    X_cols = [x for x in df.columns if x != target_col]
    df_linear = pd.DataFrame(X, columns=X_cols)
    df_linear[target_col] = y
    # normalize the data to the range of df
    for col in df.columns:
        min_val = df[col].min()
        max_val = df[col].max()
        df_linear[col] = (df_linear[col] - df_linear[col].min()) / (
            df_linear[col].max() - df_linear[col].min()
        ) * (max_val - min_val) + min_val

    return df_linear


def dcc_exp(
    data: pd.DataFrame,
    ptb_type: PerturbationType,
    task_type,
    target_col,
    ratio=0.1,
    eps=0.04,
    corr_func=js_corr_matrix,
):
    eps /= 2
    n, m = data.shape
    if ptb_type == PerturbationType.Deletion:
        perturbed_data = data.sample(frac=1 - ratio)
    elif ptb_type == PerturbationType.AdditionLinear:
        df_linear = generate_linear_according_df(
            n // 20, m, data, task_type, target_col
        )
        perturbed_data = pd.concat([data, df_linear], ignore_index=True)
    elif ptb_type == PerturbationType.AdditionRand:
        df_rand = generate_random_according_df(n // 20, m, data, task_type, target_col)
        perturbed_data = pd.concat([data, df_rand], ignore_index=True)
    elif ptb_type == PerturbationType.ReplacementLinear:
        df_linear = generate_linear_according_df(
            n // 20, m, data, task_type, target_col
        )
        perturbed_data = random_replace_rows(data, df_linear)
    elif ptb_type == PerturbationType.ReplacementRand:
        df_rand = generate_random_according_df(n // 20, m, data, task_type, target_col)
        perturbed_data = random_replace_rows(data, df_rand)
    else:
        raise ValueError(f"Unknown perturbation type: {ptb_type}")

    return dcc_diff_features(data, perturbed_data, target_col, eps=eps, corr_func=corr_func), perturbed_data

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import r2_score, accuracy_score
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from joblib import Parallel, delayed
import shap

dataset_dir = Path("processed_data")
datasets = list(dataset_dir.glob("*.csv"))
dataset_config = {
    "Bala_classification_dataset.csv": {
        "target_col": "Formability",
        "type": "classification",
    },
    "Bala_regression_dataset.csv": {
        "target_col": "Ferroelectric_Tc_in_Kelvin",
        "type": "regression",
    },
    "bandgap.csv": {
        "target_col": "target",
        "type": "regression",
    },
    "BMDS_data.csv": {
        "target_col": "soc_bandgap",
        "type": "regression",
    },
    "Crystal_structure.csv": {
        "target_col": "Lowest distortion",
        "type": "classification",
    },
    "Glass.csv": {
        "target_col": "Type of glass",
        "type": "classification",
    },
    "PUE.csv": {
        "target_col": "logYM",
        "type": "regression",
    },
}
def get_shap_values(df, target_col, type):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    if type == "regression":
        model = RandomForestRegressor(n_estimators=500, random_state=42)
    elif type == "classification":
        model = RandomForestClassifier(n_estimators=500, random_state=42)
    else:
        raise ValueError("type must be either 'regression' or 'classification'")
    model.fit(X, y)

    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X)
    # shap.summary_plot(shap_values, X, plot_type="bar")
    if type == "classification":
        # For classification, shap_values is a list of arrays, one for each class
        # We take the mean absolute value across all classes
        mean_abs_shap = np.mean(np.mean(np.abs(shap_values), axis=0), axis=1)
    else:
        mean_abs_shap = np.mean(np.abs(shap_values), axis=0)
    # print(f"Mean absolute SHAP values: {mean_abs_shap}")
    feats2shap = {col: mean_abs_shap[i] for i, col in enumerate(X.columns)}
    return feats2shap

# %%
results = defaultdict(dict)

dataset_dir = Path("processed_data")
for d in dataset_dir.glob("*.csv"):
    print(d.name)
    df = pd.read_csv(d)
    target_col = dataset_config[d.name]["target_col"]
    task_type = dataset_config[d.name]["type"]
    feats2shap = get_shap_values(df, target_col, task_type)
    results[d.name]["ori_feats2shap"] = feats2shap
    results[d.name]["name"] = dataset2name[d.name]
    results[d.name]["type"] = task_type
    results[d.name]["target_col"] = target_col

    results[d.name][PerturbationType.Deletion.value] = {}
    results[d.name][PerturbationType.AdditionLinear.value] = {}
    results[d.name][PerturbationType.AdditionRand.value] = {}
    results[d.name][PerturbationType.ReplacementLinear.value] = {}
    results[d.name][PerturbationType.ReplacementRand.value] = {}


    for ptb_type in PerturbationType:
        print(f"Perturbation type: {ptb_type.value}")
        dcc_val, perturbed_df = dcc_exp(df, ptb_type,task_type, target_col,ratio=0.1, eps=0.04)
        feats2shap = get_shap_values(perturbed_df, target_col, task_type)
        results[d.name][ptb_type.value]["dcc"] = dcc_val
        results[d.name][ptb_type.value]["feats2shap"] = feats2shap
# Out:
# Bala_classification_dataset.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# Bala_regression_dataset.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# bandgap.csv
# Perturbation type: Deletion
# d:\software\miniforge3\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Perturbation type: AdditionLinear
# d:\software\miniforge3\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# d:\software\miniforge3\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Perturbation type: ReplacementRand
# BMDS_data.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# Crystal_structure.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# Glass.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# PUE.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand

# %%
results
# Out:
# defaultdict(dict,
#             {'Bala_classification_dataset.csv': {'ori_feats2shap': {'Compound': 0.03134094185329982,
#                'x(BiMe1Me2)O3': 0.03253681248549997,
#                'Me1': 0.03877389122758503,
#                'Me2': 0.03135248369332674,
#                'frac-Me1': 0.010455383934140304,
#                'frac-Me2': 0.012826707669024998,
#                'frac-Me3': 0.0014052899024165804,
#                'PT-content': 0.03145345210691547,
#                'Tolerance_Factor': 0.057509877941759366,
#                'Valence_Electron_Number': 0.022618344283104205,
#                'Martynov_Batsanov_Electronegativity': 0.05540413959655249,
#                'Ideal_Bond_Length_Sum': 0.03186445153895874,
#                'Mendeleev_Number': 0.0964075149296759},
#               'name': 'Bala Classification',
#               'type': 'classification',
#               'target_col': 'Formability',
#               'Deletion': {'dcc': {'Compound': 0.9285714285714286,
#                 'x(BiMe1Me2)O3': 0.6428571428571429,
#                 'Me1': 1.0,
#                 'Me2': 1.0,
#                 'frac-Me1': 0.9285714285714286,
#                 'frac-Me2': 0.9285714285714286,
#                 'frac-Me3': 1.0,
#                 'PT-content': 0.7142857142857143,
#                 'Tolerance_Factor': 0.8571428571428571,
#                 'Valence_Electron_Number': 0.8571428571428571,
#                 'Martynov_Batsanov_Electronegativity': 0.8571428571428571,
#                 'Ideal_Bond_Length_Sum': 0.8571428571428571,
#                 'Mendeleev_Number': 0.8571428571428571},
#                'feats2shap': {'Compound': 0.03425180133972411,
#                 'x(BiMe1Me2)O3': 0.03034763861106418,
#                 'Me1': 0.0410222257156124,
#                 'Me2': 0.035460634101638,
#                 'frac-Me1': 0.01001746663010742,
#                 'frac-Me2': 0.011319165370522558,
#                 'frac-Me3': 0.0018037689154344443,
#                 'PT-content': 0.03214071652487052,
#                 'Tolerance_Factor': 0.055406068957514765,
#                 'Valence_Electron_Number': 0.024436547115450583,
#                 'Martynov_Batsanov_Electronegativity': 0.054769086101220214,
#                 'Ideal_Bond_Length_Sum': 0.030560584577682116,
#                 'Mendeleev_Number': 0.09845912392823775}},
#               'AdditionLinear': {'dcc': {'Compound': 0.5714285714285714,
#                 'x(BiMe1Me2)O3': 0.5,
#                 'Me1': 0.5,
#                 'Me2': 0.5714285714285714,
#                 'frac-Me1': 0.14285714285714285,
#                 'frac-Me2': 0.14285714285714285,
#                 'frac-Me3': 0.07142857142857142,
#                 'PT-content': 0.6428571428571429,
#                 'Tolerance_Factor': 0.5,
#                 'Valence_Electron_Number': 0.07142857142857142,
#                 'Martynov_Batsanov_Electronegativity': 0.2857142857142857,
#                 'Ideal_Bond_Length_Sum': 0.42857142857142855,
#                 'Mendeleev_Number': 0.35714285714285715},
#                'feats2shap': {'Compound': 0.033378379700839345,
#                 'x(BiMe1Me2)O3': 0.02602609867550023,
#                 'Me1': 0.041593772648539515,
#                 'Me2': 0.026692816021186436,
#                 'frac-Me1': 0.011143956908246969,
#                 'frac-Me2': 0.013458436608697983,
#                 'frac-Me3': 0.0014131833453217683,
#                 'PT-content': 0.039075229246355495,
#                 'Tolerance_Factor': 0.052369809656346876,
#                 'Valence_Electron_Number': 0.028903467827353854,
#                 'Martynov_Batsanov_Electronegativity': 0.05175875663628261,
#                 'Ideal_Bond_Length_Sum': 0.03649487501265254,
#                 'Mendeleev_Number': 0.09070241614614072}},
#               'AdditionRand': {'dcc': {'Compound': 0.5,
#                 'x(BiMe1Me2)O3': 0.7857142857142857,
#                 'Me1': 0.6428571428571429,
#                 'Me2': 0.7857142857142857,
#                 'frac-Me1': 0.42857142857142855,
#                 'frac-Me2': 0.7857142857142857,
#                 'frac-Me3': 0.07142857142857142,
#                 'PT-content': 0.7857142857142857,
#                 'Tolerance_Factor': 0.7142857142857143,
#                 'Valence_Electron_Number': 0.07142857142857142,
#                 'Martynov_Batsanov_Electronegativity': 0.2857142857142857,
#                 'Ideal_Bond_Length_Sum': 0.6428571428571429,
#                 'Mendeleev_Number': 0.6428571428571429},
#                'feats2shap': {'Compound': 0.03237367183038764,
#                 'x(BiMe1Me2)O3': 0.029703847298212887,
#                 'Me1': 0.03795021905718757,
#                 'Me2': 0.03187494856030239,
#                 'frac-Me1': 0.011932693723223116,
#                 'frac-Me2': 0.01354744831047768,
#                 'frac-Me3': 0.001966956837157129,
#                 'PT-content': 0.04862691040230033,
#                 'Tolerance_Factor': 0.04749577859239998,
#                 'Valence_Electron_Number': 0.022279519413343746,
#                 'Martynov_Batsanov_Electronegativity': 0.057234182648493524,
#                 'Ideal_Bond_Length_Sum': 0.031200819134182455,
#                 'Mendeleev_Number': 0.08573856547104396}},
#               'ReplacementLinear': {'dcc': {'Compound': 0.35714285714285715,
#                 'x(BiMe1Me2)O3': 0.42857142857142855,
#                 'Me1': 0.35714285714285715,
#                 'Me2': 0.5,
#                 'frac-Me1': 0.07142857142857142,
#                 'frac-Me2': 0.07142857142857142,
#                 'frac-Me3': 0.07142857142857142,
#                 'PT-content': 0.5714285714285714,
#                 'Tolerance_Factor': 0.42857142857142855,
#                 'Valence_Electron_Number': 0.07142857142857142,
#                 'Martynov_Batsanov_Electronegativity': 0.07142857142857142,
#                 'Ideal_Bond_Length_Sum': 0.21428571428571427,
#                 'Mendeleev_Number': 0.14285714285714285},
#                'feats2shap': {'Compound': 0.03350006852174795,
#                 'x(BiMe1Me2)O3': 0.03298315287374744,
#                 'Me1': 0.0404180712514918,
#                 'Me2': 0.027322308283137826,
#                 'frac-Me1': 0.011110952553550341,
#                 'frac-Me2': 0.013777195406896299,
#                 'frac-Me3': 0.001993393275096361,
#                 'PT-content': 0.025582083443675963,
#                 'Tolerance_Factor': 0.06838803333100608,
#                 'Valence_Electron_Number': 0.021288993118643663,
#                 'Martynov_Batsanov_Electronegativity': 0.06419683003990889,
#                 'Ideal_Bond_Length_Sum': 0.030662388876434465,
#                 'Mendeleev_Number': 0.09078977440600747}},
#               'ReplacementRand': {'dcc': {'Compound': 0.2857142857142857,
#                 'x(BiMe1Me2)O3': 0.5714285714285714,
#                 'Me1': 0.6428571428571429,
#                 'Me2': 0.5,
#                 'frac-Me1': 0.07142857142857142,
#                 'frac-Me2': 0.14285714285714285,
#                 'frac-Me3': 0.07142857142857142,
#                 'PT-content': 0.6428571428571429,
#                 'Tolerance_Factor': 0.42857142857142855,
#                 'Valence_Electron_Number': 0.07142857142857142,
#                 'Martynov_Batsanov_Electronegativity': 0.5714285714285714,
#                 'Ideal_Bond_Length_Sum': 0.35714285714285715,
#                 'Mendeleev_Number': 0.5},
#                'feats2shap': {'Compound': 0.028193011463644176,
#                 'x(BiMe1Me2)O3': 0.02393609009831591,
#                 'Me1': 0.039720317663827664,
#                 'Me2': 0.03492340629007902,
#                 'frac-Me1': 0.009829595883158793,
#                 'frac-Me2': 0.011756582863871271,
#                 'frac-Me3': 0.0020162660450547994,
#                 'PT-content': 0.037582071687977205,
#                 'Tolerance_Factor': 0.06229915764199177,
#                 'Valence_Electron_Number': 0.021975282805471397,
#                 'Martynov_Batsanov_Electronegativity': 0.04882649934011821,
#                 'Ideal_Bond_Length_Sum': 0.031426847598187244,
#                 'Mendeleev_Number': 0.1106851484704363}}},
#              'Bala_regression_dataset.csv': {'ori_feats2shap': {'Compound': 20.60837120403372,
#                'xBi(Me1Me2)O3': 7.275054606853217,
#                'xPT': 5.9968442030385996,
#                'Tolerance_Factor': 4.654389571341294,
#                'Ionic_Displacements': 39.4761867419901},
#               'name': 'Bala Regression',
#               'type': 'regression',
#               'target_col': 'Ferroelectric_Tc_in_Kelvin',
#               'Deletion': {'dcc': {'Compound': 0.5,
#                 'xBi(Me1Me2)O3': 0.3333333333333333,
#                 'xPT': 0.16666666666666666,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 0.6666666666666666},
#                'feats2shap': {'Compound': 17.91687316171064,
#                 'xBi(Me1Me2)O3': 7.778495140013419,
#                 'xPT': 6.804528361057363,
#                 'Tolerance_Factor': 6.0214097357961345,
#                 'Ionic_Displacements': 35.48037735876476}},
#               'AdditionLinear': {'dcc': {'Compound': 0.6666666666666666,
#                 'xBi(Me1Me2)O3': 0.5,
#                 'xPT': 0.8333333333333334,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 0.16666666666666666},
#                'feats2shap': {'Compound': 22.650770196140797,
#                 'xBi(Me1Me2)O3': 7.885664024922341,
#                 'xPT': 6.97331587135653,
#                 'Tolerance_Factor': 6.553252853478748,
#                 'Ionic_Displacements': 38.22683877612467}},
#               'AdditionRand': {'dcc': {'Compound': 0.5,
#                 'xBi(Me1Me2)O3': 0.8333333333333334,
#                 'xPT': 0.6666666666666666,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 0.16666666666666666},
#                'feats2shap': {'Compound': 26.09138082836313,
#                 'xBi(Me1Me2)O3': 5.199258833710219,
#                 'xPT': 8.033171986288595,
#                 'Tolerance_Factor': 4.173595806977425,
#                 'Ionic_Displacements': 35.6554496437886}},
#               'ReplacementLinear': {'dcc': {'Compound': 0.8333333333333334,
#                 'xBi(Me1Me2)O3': 0.8333333333333334,
#                 'xPT': 0.8333333333333334,
#                 'Tolerance_Factor': 0.8333333333333334,
#                 'Ionic_Displacements': 0.16666666666666666},
#                'feats2shap': {'Compound': 26.04436587994631,
#                 'xBi(Me1Me2)O3': 8.051233669251735,
#                 'xPT': 5.002040540188696,
#                 'Tolerance_Factor': 10.724890044779537,
#                 'Ionic_Displacements': 37.60347596833333}},
#               'ReplacementRand': {'dcc': {'Compound': 0.8333333333333334,
#                 'xBi(Me1Me2)O3': 0.5,
#                 'xPT': 0.16666666666666666,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 0.5},
#                'feats2shap': {'Compound': 19.52307239932515,
#                 'xBi(Me1Me2)O3': 5.8056721427658005,
#                 'xPT': 11.467656461384328,
#                 'Tolerance_Factor': 5.504437214914827,
#                 'Ionic_Displacements': 36.91586911102272}}},
#              'bandgap.csv': {'ori_feats2shap': {'avg_Density_(g/mL)': 0.38674949881126536,
#                'avg_Gordy_electonegativity': 0.11261082103418422,
#                'avg_Number_of_unfilled_d_valence_electrons': 0.039607106645460466,
#                'avg_abs_valence': 0.13361051966235904,
#                'avg_metallic_valence': 0.5456738027324444,
#                'avg_valence_d': 0.03745260536705348,
#                'sum_Density_(g/mL)': 0.035575623016375756,
#                'sum_heat_atomization(kJ/mol)': 0.0830820232385413,
#                'sum_valence_d': 0.07971885553369128,
#                'range_Density_(g/mL)': 0.04064611087913789,
#                'range_Nagle_electonegativity': 0.11111177320401179,
#                'range_heat_of_fusion_(kJ/mol)_': 0.08018168562426807},
#               'name': 'Bandgap',
#               'type': 'regression',
#               'target_col': 'target',
#               'Deletion': {'dcc': {'avg_Density_(g/mL)': 0.9230769230769231,
#                 'avg_Gordy_electonegativity': 0.9230769230769231,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.9230769230769231,
#                 'avg_abs_valence': 0.9230769230769231,
#                 'avg_metallic_valence': 0.9230769230769231,
#                 'avg_valence_d': 0.9230769230769231,
#                 'sum_Density_(g/mL)': 0.9230769230769231,
#                 'sum_heat_atomization(kJ/mol)': 0.9230769230769231,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.9230769230769231,
#                 'range_Nagle_electonegativity': 0.9230769230769231,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.9230769230769231},
#                'feats2shap': {'avg_Density_(g/mL)': 0.38227611360173613,
#                 'avg_Gordy_electonegativity': 0.09580309257117786,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.03507558267449261,
#                 'avg_abs_valence': 0.12888534296007426,
#                 'avg_metallic_valence': 0.5527874693668198,
#                 'avg_valence_d': 0.03520173159004285,
#                 'sum_Density_(g/mL)': 0.034907475280861605,
#                 'sum_heat_atomization(kJ/mol)': 0.0791954693436143,
#                 'sum_valence_d': 0.09439134984454328,
#                 'range_Density_(g/mL)': 0.041880476846755624,
#                 'range_Nagle_electonegativity': 0.11291699644171582,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07864897777623668}},
#               'AdditionLinear': {'dcc': {'avg_Density_(g/mL)': 0.38461538461538464,
#                 'avg_Gordy_electonegativity': 0.5384615384615384,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.07692307692307693,
#                 'avg_abs_valence': 0.5384615384615384,
#                 'avg_metallic_valence': 0.5384615384615384,
#                 'avg_valence_d': 0.46153846153846156,
#                 'sum_Density_(g/mL)': 0.07692307692307693,
#                 'sum_heat_atomization(kJ/mol)': 0.07692307692307693,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.5384615384615384,
#                 'range_Nagle_electonegativity': 0.46153846153846156,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.15384615384615385},
#                'feats2shap': {'avg_Density_(g/mL)': 0.34878720487265963,
#                 'avg_Gordy_electonegativity': 0.14312946297704135,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.030391818941649558,
#                 'avg_abs_valence': 0.08917200171062263,
#                 'avg_metallic_valence': 0.18283963170495154,
#                 'avg_valence_d': 0.03009900800421609,
#                 'sum_Density_(g/mL)': 0.2333078702096194,
#                 'sum_heat_atomization(kJ/mol)': 0.11580558947505692,
#                 'sum_valence_d': 0.050222078971994585,
#                 'range_Density_(g/mL)': 0.12154230360436732,
#                 'range_Nagle_electonegativity': 0.516267621779185,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.10151975273826404}},
#               'AdditionRand': {'dcc': {'avg_Density_(g/mL)': 0.5384615384615384,
#                 'avg_Gordy_electonegativity': 0.46153846153846156,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.07692307692307693,
#                 'avg_abs_valence': 0.38461538461538464,
#                 'avg_metallic_valence': 0.38461538461538464,
#                 'avg_valence_d': 0.3076923076923077,
#                 'sum_Density_(g/mL)': 0.07692307692307693,
#                 'sum_heat_atomization(kJ/mol)': 0.07692307692307693,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.46153846153846156,
#                 'range_Nagle_electonegativity': 0.46153846153846156,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07692307692307693},
#                'feats2shap': {'avg_Density_(g/mL)': 0.37869938500953193,
#                 'avg_Gordy_electonegativity': 0.10330576680600373,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.03957105664378946,
#                 'avg_abs_valence': 0.11823245210395389,
#                 'avg_metallic_valence': 0.5656223380040694,
#                 'avg_valence_d': 0.07674720397774493,
#                 'sum_Density_(g/mL)': 0.05351843862099998,
#                 'sum_heat_atomization(kJ/mol)': 0.12298016578723388,
#                 'sum_valence_d': 0.23700363323669366,
#                 'range_Density_(g/mL)': 0.04731719476514638,
#                 'range_Nagle_electonegativity': 0.1352056041988488,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.11403043722755256}},
#               'ReplacementLinear': {'dcc': {'avg_Density_(g/mL)': 0.3076923076923077,
#                 'avg_Gordy_electonegativity': 0.3076923076923077,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.15384615384615385,
#                 'avg_abs_valence': 0.5384615384615384,
#                 'avg_metallic_valence': 0.38461538461538464,
#                 'avg_valence_d': 0.38461538461538464,
#                 'sum_Density_(g/mL)': 0.07692307692307693,
#                 'sum_heat_atomization(kJ/mol)': 0.07692307692307693,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.3076923076923077,
#                 'range_Nagle_electonegativity': 0.46153846153846156,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07692307692307693},
#                'feats2shap': {'avg_Density_(g/mL)': 0.312803142937387,
#                 'avg_Gordy_electonegativity': 0.24239995889379876,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.027167408404834795,
#                 'avg_abs_valence': 0.08612094786588852,
#                 'avg_metallic_valence': 0.18674095048990155,
#                 'avg_valence_d': 0.02448749328322345,
#                 'sum_Density_(g/mL)': 0.03090261897774724,
#                 'sum_heat_atomization(kJ/mol)': 0.10661808921786221,
#                 'sum_valence_d': 0.22169943731476657,
#                 'range_Density_(g/mL)': 0.14444950357135972,
#                 'range_Nagle_electonegativity': 0.4144741119045575,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.1153464947619701}},
#               'ReplacementRand': {'dcc': {'avg_Density_(g/mL)': 0.46153846153846156,
#                 'avg_Gordy_electonegativity': 0.23076923076923078,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.07692307692307693,
#                 'avg_abs_valence': 0.15384615384615385,
#                 'avg_metallic_valence': 0.3076923076923077,
#                 'avg_valence_d': 0.38461538461538464,
#                 'sum_Density_(g/mL)': 0.07692307692307693,
#                 'sum_heat_atomization(kJ/mol)': 0.07692307692307693,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.3076923076923077,
#                 'range_Nagle_electonegativity': 0.38461538461538464,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07692307692307693},
#                'feats2shap': {'avg_Density_(g/mL)': 0.31169609547857263,
#                 'avg_Gordy_electonegativity': 0.11047906092097062,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.041450736528060736,
#                 'avg_abs_valence': 0.11852804685264147,
#                 'avg_metallic_valence': 0.4613749710496894,
#                 'avg_valence_d': 0.06793036687281194,
#                 'sum_Density_(g/mL)': 0.13333892938608494,
#                 'sum_heat_atomization(kJ/mol)': 0.11367450311578943,
#                 'sum_valence_d': 0.1646957090202283,
#                 'range_Density_(g/mL)': 0.07948873364132639,
#                 'range_Nagle_electonegativity': 0.24022308523447042,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.10721441167052005}}},
#              'BMDS_data.csv': {'ori_feats2shap': {'a_mono': 0.003366113320390514,
#                'a': 0.003965316024509296,
#                'b': 0.004353293532454283,
#                'DFT_energy_bi': 0.007216569231486068,
#                'magnetic_moment': 0.0,
#                'formation_energy': 0.00301907319933986,
#                'area': 0.00280292047870701,
#                'd': 0.003056690405491597,
#                'no_soc_bandgap': 0.7005548790673587,
#                'dielectric_constant': 0.00698323244332095,
#                'soc_energy': 0.04146214671132726,
#                'del_e_bilayer_bottom_and_mono': 0.0030584293119203104},
#               'name': 'BMDS',
#               'type': 'regression',
#               'target_col': 'soc_bandgap',
#               'Deletion': {'dcc': {'a_mono': 1.0,
#                 'a': 1.0,
#                 'b': 1.0,
#                 'DFT_energy_bi': 1.0,
#                 'magnetic_moment': 0.9230769230769231,
#                 'formation_energy': 1.0,
#                 'area': 1.0,
#                 'd': 1.0,
#                 'no_soc_bandgap': 1.0,
#                 'dielectric_constant': 0.9230769230769231,
#                 'soc_energy': 1.0,
#                 'del_e_bilayer_bottom_and_mono': 1.0},
#                'feats2shap': {'a_mono': 0.003388528671053236,
#                 'a': 0.004498684164401067,
#                 'b': 0.004371039958703638,
#                 'DFT_energy_bi': 0.006322623463068199,
#                 'magnetic_moment': 0.0,
#                 'formation_energy': 0.0033775734038413194,
#                 'area': 0.0029112489251213887,
#                 'd': 0.002325136247195615,
#                 'no_soc_bandgap': 0.689886848892953,
#                 'dielectric_constant': 0.009497424424896967,
#                 'soc_energy': 0.04153100835203226,
#                 'del_e_bilayer_bottom_and_mono': 0.0034515094364696653}},
#               'AdditionLinear': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.23076923076923078,
#                 'b': 0.23076923076923078,
#                 'DFT_energy_bi': 0.07692307692307693,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.07692307692307693,
#                 'area': 0.07692307692307693,
#                 'd': 0.07692307692307693,
#                 'no_soc_bandgap': 0.15384615384615385,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.0064903939736763745,
#                 'a': 0.009208097092485455,
#                 'b': 0.024849122387214657,
#                 'DFT_energy_bi': 0.017386736744351355,
#                 'magnetic_moment': 0.01234773490899672,
#                 'formation_energy': 0.009398962205453205,
#                 'area': 0.010631757861651785,
#                 'd': 0.003939276302962617,
#                 'no_soc_bandgap': 0.7833321513261986,
#                 'dielectric_constant': 0.021824693167294774,
#                 'soc_energy': 0.03693439728919072,
#                 'del_e_bilayer_bottom_and_mono': 0.006815879058207919}},
#               'AdditionRand': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.23076923076923078,
#                 'b': 0.23076923076923078,
#                 'DFT_energy_bi': 0.15384615384615385,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.07692307692307693,
#                 'area': 0.07692307692307693,
#                 'd': 0.15384615384615385,
#                 'no_soc_bandgap': 0.15384615384615385,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.008790095002584042,
#                 'a': 0.006195179214077751,
#                 'b': 0.008343307986473585,
#                 'DFT_energy_bi': 0.013116978283742805,
#                 'magnetic_moment': 0.020954735661190535,
#                 'formation_energy': 0.015299440511009572,
#                 'area': 0.018029855160616774,
#                 'd': 0.01496148906856853,
#                 'no_soc_bandgap': 0.7629288356100049,
#                 'dielectric_constant': 0.05026192184119079,
#                 'soc_energy': 0.057422641726905234,
#                 'del_e_bilayer_bottom_and_mono': 0.011512354017301517}},
#               'ReplacementLinear': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.15384615384615385,
#                 'b': 0.15384615384615385,
#                 'DFT_energy_bi': 0.15384615384615385,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.07692307692307693,
#                 'area': 0.07692307692307693,
#                 'd': 0.15384615384615385,
#                 'no_soc_bandgap': 0.15384615384615385,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.0036694459134691774,
#                 'a': 0.012502962663858969,
#                 'b': 0.008219646993151522,
#                 'DFT_energy_bi': 0.007608133158362422,
#                 'magnetic_moment': 0.0070541511652892205,
#                 'formation_energy': 0.023913286908527658,
#                 'area': 0.006592122941971795,
#                 'd': 0.0034396127356640595,
#                 'no_soc_bandgap': 0.7776238704740648,
#                 'dielectric_constant': 0.035256289520819724,
#                 'soc_energy': 0.050527549477707955,
#                 'del_e_bilayer_bottom_and_mono': 0.014598663764395087}},
#               'ReplacementRand': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.15384615384615385,
#                 'b': 0.15384615384615385,
#                 'DFT_energy_bi': 0.07692307692307693,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.07692307692307693,
#                 'area': 0.07692307692307693,
#                 'd': 0.07692307692307693,
#                 'no_soc_bandgap': 0.15384615384615385,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.008102874536678614,
#                 'a': 0.006243211971816898,
#                 'b': 0.0073424974141413045,
#                 'DFT_energy_bi': 0.012263033892027698,
#                 'magnetic_moment': 0.01502394405625472,
#                 'formation_energy': 0.010406287031176659,
#                 'area': 0.00822304245027199,
#                 'd': 0.012142411365015435,
#                 'no_soc_bandgap': 0.7856266926083538,
#                 'dielectric_constant': 0.036824941453591734,
#                 'soc_energy': 0.05042025531799636,
#                 'del_e_bilayer_bottom_and_mono': 0.008524540461964067}}},
#              'Crystal_structure.csv': {'ori_feats2shap': {'v(A)': 0.00928807805117576,
#                'v(B)': 0.008590939033111613,
#                'r(AXII)(Å)': 0.014293254707227978,
#                'r(AVI)(Å)': 0.01505931174813062,
#                'r(BVI)(Å)': 0.01816361031209468,
#                'EN(A)': 0.03062920334507453,
#                'EN(B)': 0.041057098775248,
#                'l(A-O)(Å)': 0.01676954859238621,
#                'l(B-O)(Å)': 0.015547435066267122,
#                'ΔENR': 0.022561250770963527,
#                'tG': 0.03321633640362814,
#                'τ': 0.04550646279639944,
#                'μ': 0.016420558105693362},
#               'name': 'Crystal Structure',
#               'type': 'classification',
#               'target_col': 'Lowest distortion',
#               'Deletion': {'dcc': {'v(A)': 1.0,
#                 'v(B)': 1.0,
#                 'r(AXII)(Å)': 1.0,
#                 'r(AVI)(Å)': 1.0,
#                 'r(BVI)(Å)': 1.0,
#                 'EN(A)': 1.0,
#                 'EN(B)': 1.0,
#                 'l(A-O)(Å)': 1.0,
#                 'l(B-O)(Å)': 1.0,
#                 'ΔENR': 1.0,
#                 'tG': 1.0,
#                 'τ': 1.0,
#                 'μ': 1.0},
#                'feats2shap': {'v(A)': 0.008810741996285584,
#                 'v(B)': 0.00920542807080994,
#                 'r(AXII)(Å)': 0.015468757057301392,
#                 'r(AVI)(Å)': 0.014227826789014337,
#                 'r(BVI)(Å)': 0.01626597475240206,
#                 'EN(A)': 0.032639057308883127,
#                 'EN(B)': 0.038254284808604364,
#                 'l(A-O)(Å)': 0.017568155006672366,
#                 'l(B-O)(Å)': 0.01423415755171675,
#                 'ΔENR': 0.021696389477840538,
#                 'tG': 0.03426379643938486,
#                 'τ': 0.045661695868372876,
#                 'μ': 0.016881632782572834}},
#               'AdditionLinear': {'dcc': {'v(A)': 0.7857142857142857,
#                 'v(B)': 0.7142857142857143,
#                 'r(AXII)(Å)': 0.8571428571428571,
#                 'r(AVI)(Å)': 0.21428571428571427,
#                 'r(BVI)(Å)': 0.5714285714285714,
#                 'EN(A)': 0.7857142857142857,
#                 'EN(B)': 0.7142857142857143,
#                 'l(A-O)(Å)': 0.7857142857142857,
#                 'l(B-O)(Å)': 0.7857142857142857,
#                 'ΔENR': 0.2857142857142857,
#                 'tG': 0.5714285714285714,
#                 'τ': 0.42857142857142855,
#                 'μ': 0.5714285714285714},
#                'feats2shap': {'v(A)': 0.010424465632284717,
#                 'v(B)': 0.009216590652556967,
#                 'r(AXII)(Å)': 0.015159501882321515,
#                 'r(AVI)(Å)': 0.017086785098482785,
#                 'r(BVI)(Å)': 0.017239887101940923,
#                 'EN(A)': 0.03270675400853059,
#                 'EN(B)': 0.039199469091045915,
#                 'l(A-O)(Å)': 0.015483254872796533,
#                 'l(B-O)(Å)': 0.015240459878364719,
#                 'ΔENR': 0.020989679797390876,
#                 'tG': 0.03371604447769173,
#                 'τ': 0.04604363898469486,
#                 'μ': 0.018553987556727315}},
#               'AdditionRand': {'dcc': {'v(A)': 0.35714285714285715,
#                 'v(B)': 0.42857142857142855,
#                 'r(AXII)(Å)': 0.5,
#                 'r(AVI)(Å)': 0.21428571428571427,
#                 'r(BVI)(Å)': 0.5714285714285714,
#                 'EN(A)': 0.7142857142857143,
#                 'EN(B)': 0.5714285714285714,
#                 'l(A-O)(Å)': 0.7142857142857143,
#                 'l(B-O)(Å)': 0.7857142857142857,
#                 'ΔENR': 0.2857142857142857,
#                 'tG': 0.5,
#                 'τ': 0.21428571428571427,
#                 'μ': 0.5714285714285714},
#                'feats2shap': {'v(A)': 0.009089781071233895,
#                 'v(B)': 0.010054862323485656,
#                 'r(AXII)(Å)': 0.015580309762616776,
#                 'r(AVI)(Å)': 0.017210720632091184,
#                 'r(BVI)(Å)': 0.019343306891618027,
#                 'EN(A)': 0.03121799870551132,
#                 'EN(B)': 0.03950724855087241,
#                 'l(A-O)(Å)': 0.01555230760736358,
#                 'l(B-O)(Å)': 0.01588537605228007,
#                 'ΔENR': 0.023197321836709275,
#                 'tG': 0.033077980947683105,
#                 'τ': 0.041490053134045926,
#                 'μ': 0.016922303150384482}},
#               'ReplacementLinear': {'dcc': {'v(A)': 0.42857142857142855,
#                 'v(B)': 0.2857142857142857,
#                 'r(AXII)(Å)': 0.14285714285714285,
#                 'r(AVI)(Å)': 0.2857142857142857,
#                 'r(BVI)(Å)': 0.35714285714285715,
#                 'EN(A)': 0.2857142857142857,
#                 'EN(B)': 0.42857142857142855,
#                 'l(A-O)(Å)': 0.2857142857142857,
#                 'l(B-O)(Å)': 0.35714285714285715,
#                 'ΔENR': 0.2857142857142857,
#                 'tG': 0.5,
#                 'τ': 0.2857142857142857,
#                 'μ': 0.2857142857142857},
#                'feats2shap': {'v(A)': 0.009787605423961116,
#                 'v(B)': 0.007013876804639244,
#                 'r(AXII)(Å)': 0.01715030173375464,
#                 'r(AVI)(Å)': 0.01796563234206906,
#                 'r(BVI)(Å)': 0.014438088787801262,
#                 'EN(A)': 0.035686917035092525,
#                 'EN(B)': 0.038919836506878046,
#                 'l(A-O)(Å)': 0.015794768025719032,
#                 'l(B-O)(Å)': 0.016559870671202594,
#                 'ΔENR': 0.02140880614704803,
#                 'tG': 0.031700469968179025,
#                 'τ': 0.0443069644602915,
#                 'μ': 0.01781956622765796}},
#               'ReplacementRand': {'dcc': {'v(A)': 0.5,
#                 'v(B)': 0.2857142857142857,
#                 'r(AXII)(Å)': 0.2857142857142857,
#                 'r(AVI)(Å)': 0.2857142857142857,
#                 'r(BVI)(Å)': 0.35714285714285715,
#                 'EN(A)': 0.35714285714285715,
#                 'EN(B)': 0.21428571428571427,
#                 'l(A-O)(Å)': 0.2857142857142857,
#                 'l(B-O)(Å)': 0.5,
#                 'ΔENR': 0.14285714285714285,
#                 'tG': 0.5714285714285714,
#                 'τ': 0.07142857142857142,
#                 'μ': 0.35714285714285715},
#                'feats2shap': {'v(A)': 0.0088894135707141,
#                 'v(B)': 0.007262723208090987,
#                 'r(AXII)(Å)': 0.017089765913381662,
#                 'r(AVI)(Å)': 0.01583667107870955,
#                 'r(BVI)(Å)': 0.017981501738568887,
#                 'EN(A)': 0.03060475048549736,
#                 'EN(B)': 0.03876308137896218,
#                 'l(A-O)(Å)': 0.017191207321955542,
#                 'l(B-O)(Å)': 0.014013360476267729,
#                 'ΔENR': 0.020641377363374923,
#                 'tG': 0.037704828189681294,
#                 'τ': 0.04732962514047932,
#                 'μ': 0.014435586552067134}}},
#              'Glass.csv': {'ori_feats2shap': {'RI': 0.037859991545018706,
#                'Na': 0.025386526591311877,
#                'Mg': 0.058506488488587395,
#                'Al': 0.050366751947213295,
#                'Si': 0.014770640346268021,
#                'K': 0.020324243126125522,
#                'Ca': 0.031106733133963962,
#                'Ba': 0.032559546525034226,
#                'Fe': 0.008634754652686791},
#               'name': 'Glass',
#               'type': 'classification',
#               'target_col': 'Type of glass',
#               'Deletion': {'dcc': {'RI': 0.4,
#                 'Na': 0.8,
#                 'Mg': 1.0,
#                 'Al': 0.8,
#                 'Si': 0.8,
#                 'K': 0.8,
#                 'Ca': 0.6,
#                 'Ba': 1.0,
#                 'Fe': 0.9},
#                'feats2shap': {'RI': 0.04092262655773734,
#                 'Na': 0.025502149168326226,
#                 'Mg': 0.059109921356054175,
#                 'Al': 0.04597248263301235,
#                 'Si': 0.013652058664297521,
#                 'K': 0.01980841269218983,
#                 'Ca': 0.0338193953893022,
#                 'Ba': 0.02794519874146063,
#                 'Fe': 0.010355458159443177}},
#               'AdditionLinear': {'dcc': {'RI': 0.2,
#                 'Na': 0.2,
#                 'Mg': 0.1,
#                 'Al': 0.3,
#                 'Si': 0.1,
#                 'K': 0.1,
#                 'Ca': 0.4,
#                 'Ba': 0.1,
#                 'Fe': 0.1},
#                'feats2shap': {'RI': 0.03729989948617758,
#                 'Na': 0.02418354641832969,
#                 'Mg': 0.06359923565955804,
#                 'Al': 0.04479283475737272,
#                 'Si': 0.015280699308936121,
#                 'K': 0.022052240464381354,
#                 'Ca': 0.030572157055885854,
#                 'Ba': 0.028273284204089574,
#                 'Fe': 0.009796602038296064}},
#               'AdditionRand': {'dcc': {'RI': 0.5,
#                 'Na': 0.3,
#                 'Mg': 0.1,
#                 'Al': 0.4,
#                 'Si': 0.2,
#                 'K': 0.1,
#                 'Ca': 0.6,
#                 'Ba': 0.1,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.03652529059269656,
#                 'Na': 0.027101052513460223,
#                 'Mg': 0.058516703523799334,
#                 'Al': 0.050769430882238585,
#                 'Si': 0.014871285730369777,
#                 'K': 0.021401433974334704,
#                 'Ca': 0.03066218452165087,
#                 'Ba': 0.025015479633957578,
#                 'Fe': 0.00992659965890528}},
#               'ReplacementLinear': {'dcc': {'RI': 0.3,
#                 'Na': 0.5,
#                 'Mg': 0.1,
#                 'Al': 0.3,
#                 'Si': 0.4,
#                 'K': 0.1,
#                 'Ca': 0.2,
#                 'Ba': 0.1,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.036790832721259346,
#                 'Na': 0.030186013789728766,
#                 'Mg': 0.06549389719495052,
#                 'Al': 0.0487308634001864,
#                 'Si': 0.014657137482486537,
#                 'K': 0.017543850925767,
#                 'Ca': 0.03084147444842451,
#                 'Ba': 0.0280612882325972,
#                 'Fe': 0.008342633326234897}},
#               'ReplacementRand': {'dcc': {'RI': 0.2,
#                 'Na': 0.5,
#                 'Mg': 0.1,
#                 'Al': 0.4,
#                 'Si': 0.3,
#                 'K': 0.1,
#                 'Ca': 0.2,
#                 'Ba': 0.1,
#                 'Fe': 0.1},
#                'feats2shap': {'RI': 0.037585102501942025,
#                 'Na': 0.022015398368833778,
#                 'Mg': 0.06738623009205659,
#                 'Al': 0.0443099031377737,
#                 'Si': 0.016149080755065336,
#                 'K': 0.021183963481963303,
#                 'Ca': 0.02885268644074598,
#                 'Ba': 0.030724370356067277,
#                 'Fe': 0.009275426507934796}}},
#              'PUE.csv': {'ori_feats2shap': {'ZS_CHS': 0.07208610019768472,
#                'ZS_R': 0.013958132892156003,
#                'ZS_log_Tr1K': 0.006903631445503145,
#                'ZS_log_Tr2K': 0.00881557172441453,
#                'PMStep': 0.0007424758525061988,
#                'Form_Method': 0.0010502969507552012,
#                'ZS_log_CSArea': 0.00702946402506858,
#                'ZS_log_StrainRate': 0.013377728425863274,
#                'ZS_log_PO_MW': 0.06258830317076215,
#                'ZS_log_FCVm': 0.13645203544301585,
#                'ZS_FCCED': 0.07534204358060362,
#                'ZS_log_Fchi': 0.01264861167444042,
#                'ZS_SS_TPSA_norm': 0.015052753265992917,
#                'ZS_SS_MolLogP_norm': 0.011297945684567195,
#                'ZS_HS_BertzCT': 0.030223438658344048,
#                'ZS_SS_VSA_EState8': 0.050845734315427764,
#                'ZS_SS_PEOE_VSA8': 0.012340758037346597,
#                'ZS_log_HS_NumNHCO_norm': 0.015389459071923515,
#                'ZS_FC_NumHAcceptors_norm': 0.017376917536886416,
#                'ZS_FC_RingCount_norm': 0.06483405605254663},
#               'name': 'PUE',
#               'type': 'regression',
#               'target_col': 'logYM',
#               'Deletion': {'dcc': {'ZS_CHS': 0.9047619047619048,
#                 'ZS_R': 1.0,
#                 'ZS_log_Tr1K': 1.0,
#                 'ZS_log_Tr2K': 1.0,
#                 'PMStep': 1.0,
#                 'Form_Method': 0.9523809523809523,
#                 'ZS_log_CSArea': 1.0,
#                 'ZS_log_StrainRate': 1.0,
#                 'ZS_log_PO_MW': 0.9523809523809523,
#                 'ZS_log_FCVm': 0.9523809523809523,
#                 'ZS_FCCED': 1.0,
#                 'ZS_log_Fchi': 1.0,
#                 'ZS_SS_TPSA_norm': 1.0,
#                 'ZS_SS_MolLogP_norm': 1.0,
#                 'ZS_HS_BertzCT': 1.0,
#                 'ZS_SS_VSA_EState8': 1.0,
#                 'ZS_SS_PEOE_VSA8': 0.9523809523809523,
#                 'ZS_log_HS_NumNHCO_norm': 1.0,
#                 'ZS_FC_NumHAcceptors_norm': 1.0,
#                 'ZS_FC_RingCount_norm': 1.0},
#                'feats2shap': {'ZS_CHS': 0.07754251201482165,
#                 'ZS_R': 0.008480409508719386,
#                 'ZS_log_Tr1K': 0.009237320133183418,
#                 'ZS_log_Tr2K': 0.004867524238199057,
#                 'PMStep': 0.0007018152884463628,
#                 'Form_Method': 0.0010887920119773606,
#                 'ZS_log_CSArea': 0.0064027508224809,
#                 'ZS_log_StrainRate': 0.013120060504343958,
#                 'ZS_log_PO_MW': 0.06532391898577464,
#                 'ZS_log_FCVm': 0.13051521252657236,
#                 'ZS_FCCED': 0.0735615327787324,
#                 'ZS_log_Fchi': 0.014475835754319315,
#                 'ZS_SS_TPSA_norm': 0.036738808820350105,
#                 'ZS_SS_MolLogP_norm': 0.006993643191749447,
#                 'ZS_HS_BertzCT': 0.04470579284754972,
#                 'ZS_SS_VSA_EState8': 0.04084074464265781,
#                 'ZS_SS_PEOE_VSA8': 0.008776940399750887,
#                 'ZS_log_HS_NumNHCO_norm': 0.012912863151770697,
#                 'ZS_FC_NumHAcceptors_norm': 0.015857944465756474,
#                 'ZS_FC_RingCount_norm': 0.054833416255596075}},
#               'AdditionLinear': {'dcc': {'ZS_CHS': 0.7619047619047619,
#                 'ZS_R': 0.42857142857142855,
#                 'ZS_log_Tr1K': 0.5238095238095238,
#                 'ZS_log_Tr2K': 0.6190476190476191,
#                 'PMStep': 0.047619047619047616,
#                 'Form_Method': 0.7619047619047619,
#                 'ZS_log_CSArea': 0.6190476190476191,
#                 'ZS_log_StrainRate': 0.7142857142857143,
#                 'ZS_log_PO_MW': 0.3333333333333333,
#                 'ZS_log_FCVm': 0.23809523809523808,
#                 'ZS_FCCED': 0.5238095238095238,
#                 'ZS_log_Fchi': 0.09523809523809523,
#                 'ZS_SS_TPSA_norm': 0.047619047619047616,
#                 'ZS_SS_MolLogP_norm': 0.19047619047619047,
#                 'ZS_HS_BertzCT': 0.47619047619047616,
#                 'ZS_SS_VSA_EState8': 0.5714285714285714,
#                 'ZS_SS_PEOE_VSA8': 0.6190476190476191,
#                 'ZS_log_HS_NumNHCO_norm': 0.7619047619047619,
#                 'ZS_FC_NumHAcceptors_norm': 0.7619047619047619,
#                 'ZS_FC_RingCount_norm': 0.5714285714285714},
#                'feats2shap': {'ZS_CHS': 0.08422878639353917,
#                 'ZS_R': 0.018115215759340667,
#                 'ZS_log_Tr1K': 0.005436551993728024,
#                 'ZS_log_Tr2K': 0.0076157664246530735,
#                 'PMStep': 0.0009767129047739283,
#                 'Form_Method': 0.0014473672797394208,
#                 'ZS_log_CSArea': 0.0052993097532456675,
#                 'ZS_log_StrainRate': 0.012858250880645114,
#                 'ZS_log_PO_MW': 0.02770118938468311,
#                 'ZS_log_FCVm': 0.12109377933389029,
#                 'ZS_FCCED': 0.03989696234652353,
#                 'ZS_log_Fchi': 0.01776904904362225,
#                 'ZS_SS_TPSA_norm': 0.019766704954613933,
#                 'ZS_SS_MolLogP_norm': 0.008078055884643784,
#                 'ZS_HS_BertzCT': 0.03617741070077262,
#                 'ZS_SS_VSA_EState8': 0.1103314750845637,
#                 'ZS_SS_PEOE_VSA8': 0.010311455788531442,
#                 'ZS_log_HS_NumNHCO_norm': 0.01781477696180358,
#                 'ZS_FC_NumHAcceptors_norm': 0.021129352992365295,
#                 'ZS_FC_RingCount_norm': 0.051959537452778815}},
#               'AdditionRand': {'dcc': {'ZS_CHS': 0.6666666666666666,
#                 'ZS_R': 0.38095238095238093,
#                 'ZS_log_Tr1K': 0.19047619047619047,
#                 'ZS_log_Tr2K': 0.6190476190476191,
#                 'PMStep': 0.047619047619047616,
#                 'Form_Method': 0.47619047619047616,
#                 'ZS_log_CSArea': 0.38095238095238093,
#                 'ZS_log_StrainRate': 0.5238095238095238,
#                 'ZS_log_PO_MW': 0.23809523809523808,
#                 'ZS_log_FCVm': 0.2857142857142857,
#                 'ZS_FCCED': 0.5714285714285714,
#                 'ZS_log_Fchi': 0.14285714285714285,
#                 'ZS_SS_TPSA_norm': 0.09523809523809523,
#                 'ZS_SS_MolLogP_norm': 0.047619047619047616,
#                 'ZS_HS_BertzCT': 0.23809523809523808,
#                 'ZS_SS_VSA_EState8': 0.3333333333333333,
#                 'ZS_SS_PEOE_VSA8': 0.38095238095238093,
#                 'ZS_log_HS_NumNHCO_norm': 0.6190476190476191,
#                 'ZS_FC_NumHAcceptors_norm': 0.38095238095238093,
#                 'ZS_FC_RingCount_norm': 0.5238095238095238},
#                'feats2shap': {'ZS_CHS': 0.05927630796253023,
#                 'ZS_R': 0.0074233434987146405,
#                 'ZS_log_Tr1K': 0.007407144304263983,
#                 'ZS_log_Tr2K': 0.009308311772921156,
#                 'PMStep': 0.0011999738692904727,
#                 'Form_Method': 0.002087655874193871,
#                 'ZS_log_CSArea': 0.006279394590130735,
#                 'ZS_log_StrainRate': 0.013897898421389844,
#                 'ZS_log_PO_MW': 0.08419885593946409,
#                 'ZS_log_FCVm': 0.13732463578527188,
#                 'ZS_FCCED': 0.046074996193506454,
#                 'ZS_log_Fchi': 0.015973430904155553,
#                 'ZS_SS_TPSA_norm': 0.014127939554989895,
#                 'ZS_SS_MolLogP_norm': 0.013412583665310514,
#                 'ZS_HS_BertzCT': 0.038152801773831915,
#                 'ZS_SS_VSA_EState8': 0.07189219860621121,
#                 'ZS_SS_PEOE_VSA8': 0.0091829981215836,
#                 'ZS_log_HS_NumNHCO_norm': 0.015780565388135527,
#                 'ZS_FC_NumHAcceptors_norm': 0.016994985139453425,
#                 'ZS_FC_RingCount_norm': 0.05153035405789707}},
#               'ReplacementLinear': {'dcc': {'ZS_CHS': 0.42857142857142855,
#                 'ZS_R': 0.09523809523809523,
#                 'ZS_log_Tr1K': 0.42857142857142855,
#                 'ZS_log_Tr2K': 0.5238095238095238,
#                 'PMStep': 0.09523809523809523,
#                 'Form_Method': 0.3333333333333333,
#                 'ZS_log_CSArea': 0.5238095238095238,
#                 'ZS_log_StrainRate': 0.6190476190476191,
#                 'ZS_log_PO_MW': 0.09523809523809523,
#                 'ZS_log_FCVm': 0.6190476190476191,
#                 'ZS_FCCED': 0.5238095238095238,
#                 'ZS_log_Fchi': 0.09523809523809523,
#                 'ZS_SS_TPSA_norm': 0.3333333333333333,
#                 'ZS_SS_MolLogP_norm': 0.047619047619047616,
#                 'ZS_HS_BertzCT': 0.2857142857142857,
#                 'ZS_SS_VSA_EState8': 0.2857142857142857,
#                 'ZS_SS_PEOE_VSA8': 0.2857142857142857,
#                 'ZS_log_HS_NumNHCO_norm': 0.42857142857142855,
#                 'ZS_FC_NumHAcceptors_norm': 0.42857142857142855,
#                 'ZS_FC_RingCount_norm': 0.3333333333333333},
#                'feats2shap': {'ZS_CHS': 0.06199958596140087,
#                 'ZS_R': 0.011684138016342905,
#                 'ZS_log_Tr1K': 0.008795842049081062,
#                 'ZS_log_Tr2K': 0.006253302405132326,
#                 'PMStep': 0.0018871575665582035,
#                 'Form_Method': 0.0016973911175370766,
#                 'ZS_log_CSArea': 0.005154746103349673,
#                 'ZS_log_StrainRate': 0.01470363987768934,
#                 'ZS_log_PO_MW': 0.08682852479322847,
#                 'ZS_log_FCVm': 0.10813760865886765,
#                 'ZS_FCCED': 0.0924112473357994,
#                 'ZS_log_Fchi': 0.013140642012662284,
#                 'ZS_SS_TPSA_norm': 0.013112466416755467,
#                 'ZS_SS_MolLogP_norm': 0.03129312274654956,
#                 'ZS_HS_BertzCT': 0.03462321818815738,
#                 'ZS_SS_VSA_EState8': 0.0566606239931008,
#                 'ZS_SS_PEOE_VSA8': 0.013311055382165867,
#                 'ZS_log_HS_NumNHCO_norm': 0.015409889369844377,
#                 'ZS_FC_NumHAcceptors_norm': 0.015929136965390178,
#                 'ZS_FC_RingCount_norm': 0.05633736086668456}},
#               'ReplacementRand': {'dcc': {'ZS_CHS': 0.6666666666666666,
#                 'ZS_R': 0.14285714285714285,
#                 'ZS_log_Tr1K': 0.6190476190476191,
#                 'ZS_log_Tr2K': 0.6190476190476191,
#                 'PMStep': 0.047619047619047616,
#                 'Form_Method': 0.38095238095238093,
#                 'ZS_log_CSArea': 0.19047619047619047,
#                 'ZS_log_StrainRate': 0.42857142857142855,
#                 'ZS_log_PO_MW': 0.2857142857142857,
#                 'ZS_log_FCVm': 0.23809523809523808,
#                 'ZS_FCCED': 0.47619047619047616,
#                 'ZS_log_Fchi': 0.14285714285714285,
#                 'ZS_SS_TPSA_norm': 0.19047619047619047,
#                 'ZS_SS_MolLogP_norm': 0.38095238095238093,
#                 'ZS_HS_BertzCT': 0.6666666666666666,
#                 'ZS_SS_VSA_EState8': 0.23809523809523808,
#                 'ZS_SS_PEOE_VSA8': 0.38095238095238093,
#                 'ZS_log_HS_NumNHCO_norm': 0.5238095238095238,
#                 'ZS_FC_NumHAcceptors_norm': 0.47619047619047616,
#                 'ZS_FC_RingCount_norm': 0.42857142857142855},
#                'feats2shap': {'ZS_CHS': 0.09554674433258976,
#                 'ZS_R': 0.019732058082147178,
#                 'ZS_log_Tr1K': 0.009729363278622765,
#                 'ZS_log_Tr2K': 0.00727100399775003,
#                 'PMStep': 0.0013489148979309595,
#                 'Form_Method': 0.001677388580262592,
#                 'ZS_log_CSArea': 0.007871394287363687,
#                 'ZS_log_StrainRate': 0.012135506393609349,
#                 'ZS_log_PO_MW': 0.027386112682155666,
#                 'ZS_log_FCVm': 0.08812962866667026,
#                 'ZS_FCCED': 0.13391845575244854,
#                 'ZS_log_Fchi': 0.030939516901441852,
#                 'ZS_SS_TPSA_norm': 0.013746356530901933,
#                 'ZS_SS_MolLogP_norm': 0.011234481747137346,
#                 'ZS_HS_BertzCT': 0.02590840661871539,
#                 'ZS_SS_VSA_EState8': 0.03828645824212566,
#                 'ZS_SS_PEOE_VSA8': 0.013411632150168391,
#                 'ZS_log_HS_NumNHCO_norm': 0.014763704652934315,
#                 'ZS_FC_NumHAcceptors_norm': 0.018677345529722972,
#                 'ZS_FC_RingCount_norm': 0.06997036828063548}}}})

# %%
# save to pickle file

import pickle

with open("results/dcc_fi_results-JS.pkl", "wb") as f:
    pickle.dump(results, f)

# %%
# read from pickle file
import pickle

results = {}

with open("results/dcc_fi_results-JS.pkl", "rb") as f:
    results = pickle.load(f)

results
# Out:
# defaultdict(dict,
#             {'Bala_classification_dataset.csv': {'ori_feats2shap': {'Compound': 0.03134094185329982,
#                'x(BiMe1Me2)O3': 0.03253681248549997,
#                'Me1': 0.03877389122758503,
#                'Me2': 0.03135248369332674,
#                'frac-Me1': 0.010455383934140304,
#                'frac-Me2': 0.012826707669024998,
#                'frac-Me3': 0.0014052899024165804,
#                'PT-content': 0.03145345210691547,
#                'Tolerance_Factor': 0.057509877941759366,
#                'Valence_Electron_Number': 0.022618344283104205,
#                'Martynov_Batsanov_Electronegativity': 0.05540413959655249,
#                'Ideal_Bond_Length_Sum': 0.03186445153895874,
#                'Mendeleev_Number': 0.0964075149296759},
#               'name': 'Bala Classification',
#               'type': 'classification',
#               'target_col': 'Formability',
#               'Deletion': {'dcc': {'Compound': 0.9285714285714286,
#                 'x(BiMe1Me2)O3': 0.6428571428571429,
#                 'Me1': 1.0,
#                 'Me2': 1.0,
#                 'frac-Me1': 0.9285714285714286,
#                 'frac-Me2': 0.9285714285714286,
#                 'frac-Me3': 1.0,
#                 'PT-content': 0.7142857142857143,
#                 'Tolerance_Factor': 0.8571428571428571,
#                 'Valence_Electron_Number': 0.8571428571428571,
#                 'Martynov_Batsanov_Electronegativity': 0.8571428571428571,
#                 'Ideal_Bond_Length_Sum': 0.8571428571428571,
#                 'Mendeleev_Number': 0.8571428571428571},
#                'feats2shap': {'Compound': 0.03425180133972411,
#                 'x(BiMe1Me2)O3': 0.03034763861106418,
#                 'Me1': 0.0410222257156124,
#                 'Me2': 0.035460634101638,
#                 'frac-Me1': 0.01001746663010742,
#                 'frac-Me2': 0.011319165370522558,
#                 'frac-Me3': 0.0018037689154344443,
#                 'PT-content': 0.03214071652487052,
#                 'Tolerance_Factor': 0.055406068957514765,
#                 'Valence_Electron_Number': 0.024436547115450583,
#                 'Martynov_Batsanov_Electronegativity': 0.054769086101220214,
#                 'Ideal_Bond_Length_Sum': 0.030560584577682116,
#                 'Mendeleev_Number': 0.09845912392823775}},
#               'AdditionLinear': {'dcc': {'Compound': 0.5714285714285714,
#                 'x(BiMe1Me2)O3': 0.5,
#                 'Me1': 0.5,
#                 'Me2': 0.5714285714285714,
#                 'frac-Me1': 0.14285714285714285,
#                 'frac-Me2': 0.14285714285714285,
#                 'frac-Me3': 0.07142857142857142,
#                 'PT-content': 0.6428571428571429,
#                 'Tolerance_Factor': 0.5,
#                 'Valence_Electron_Number': 0.07142857142857142,
#                 'Martynov_Batsanov_Electronegativity': 0.2857142857142857,
#                 'Ideal_Bond_Length_Sum': 0.42857142857142855,
#                 'Mendeleev_Number': 0.35714285714285715},
#                'feats2shap': {'Compound': 0.033378379700839345,
#                 'x(BiMe1Me2)O3': 0.02602609867550023,
#                 'Me1': 0.041593772648539515,
#                 'Me2': 0.026692816021186436,
#                 'frac-Me1': 0.011143956908246969,
#                 'frac-Me2': 0.013458436608697983,
#                 'frac-Me3': 0.0014131833453217683,
#                 'PT-content': 0.039075229246355495,
#                 'Tolerance_Factor': 0.052369809656346876,
#                 'Valence_Electron_Number': 0.028903467827353854,
#                 'Martynov_Batsanov_Electronegativity': 0.05175875663628261,
#                 'Ideal_Bond_Length_Sum': 0.03649487501265254,
#                 'Mendeleev_Number': 0.09070241614614072}},
#               'AdditionRand': {'dcc': {'Compound': 0.5,
#                 'x(BiMe1Me2)O3': 0.7857142857142857,
#                 'Me1': 0.6428571428571429,
#                 'Me2': 0.7857142857142857,
#                 'frac-Me1': 0.42857142857142855,
#                 'frac-Me2': 0.7857142857142857,
#                 'frac-Me3': 0.07142857142857142,
#                 'PT-content': 0.7857142857142857,
#                 'Tolerance_Factor': 0.7142857142857143,
#                 'Valence_Electron_Number': 0.07142857142857142,
#                 'Martynov_Batsanov_Electronegativity': 0.2857142857142857,
#                 'Ideal_Bond_Length_Sum': 0.6428571428571429,
#                 'Mendeleev_Number': 0.6428571428571429},
#                'feats2shap': {'Compound': 0.03237367183038764,
#                 'x(BiMe1Me2)O3': 0.029703847298212887,
#                 'Me1': 0.03795021905718757,
#                 'Me2': 0.03187494856030239,
#                 'frac-Me1': 0.011932693723223116,
#                 'frac-Me2': 0.01354744831047768,
#                 'frac-Me3': 0.001966956837157129,
#                 'PT-content': 0.04862691040230033,
#                 'Tolerance_Factor': 0.04749577859239998,
#                 'Valence_Electron_Number': 0.022279519413343746,
#                 'Martynov_Batsanov_Electronegativity': 0.057234182648493524,
#                 'Ideal_Bond_Length_Sum': 0.031200819134182455,
#                 'Mendeleev_Number': 0.08573856547104396}},
#               'ReplacementLinear': {'dcc': {'Compound': 0.35714285714285715,
#                 'x(BiMe1Me2)O3': 0.42857142857142855,
#                 'Me1': 0.35714285714285715,
#                 'Me2': 0.5,
#                 'frac-Me1': 0.07142857142857142,
#                 'frac-Me2': 0.07142857142857142,
#                 'frac-Me3': 0.07142857142857142,
#                 'PT-content': 0.5714285714285714,
#                 'Tolerance_Factor': 0.42857142857142855,
#                 'Valence_Electron_Number': 0.07142857142857142,
#                 'Martynov_Batsanov_Electronegativity': 0.07142857142857142,
#                 'Ideal_Bond_Length_Sum': 0.21428571428571427,
#                 'Mendeleev_Number': 0.14285714285714285},
#                'feats2shap': {'Compound': 0.03350006852174795,
#                 'x(BiMe1Me2)O3': 0.03298315287374744,
#                 'Me1': 0.0404180712514918,
#                 'Me2': 0.027322308283137826,
#                 'frac-Me1': 0.011110952553550341,
#                 'frac-Me2': 0.013777195406896299,
#                 'frac-Me3': 0.001993393275096361,
#                 'PT-content': 0.025582083443675963,
#                 'Tolerance_Factor': 0.06838803333100608,
#                 'Valence_Electron_Number': 0.021288993118643663,
#                 'Martynov_Batsanov_Electronegativity': 0.06419683003990889,
#                 'Ideal_Bond_Length_Sum': 0.030662388876434465,
#                 'Mendeleev_Number': 0.09078977440600747}},
#               'ReplacementRand': {'dcc': {'Compound': 0.2857142857142857,
#                 'x(BiMe1Me2)O3': 0.5714285714285714,
#                 'Me1': 0.6428571428571429,
#                 'Me2': 0.5,
#                 'frac-Me1': 0.07142857142857142,
#                 'frac-Me2': 0.14285714285714285,
#                 'frac-Me3': 0.07142857142857142,
#                 'PT-content': 0.6428571428571429,
#                 'Tolerance_Factor': 0.42857142857142855,
#                 'Valence_Electron_Number': 0.07142857142857142,
#                 'Martynov_Batsanov_Electronegativity': 0.5714285714285714,
#                 'Ideal_Bond_Length_Sum': 0.35714285714285715,
#                 'Mendeleev_Number': 0.5},
#                'feats2shap': {'Compound': 0.028193011463644176,
#                 'x(BiMe1Me2)O3': 0.02393609009831591,
#                 'Me1': 0.039720317663827664,
#                 'Me2': 0.03492340629007902,
#                 'frac-Me1': 0.009829595883158793,
#                 'frac-Me2': 0.011756582863871271,
#                 'frac-Me3': 0.0020162660450547994,
#                 'PT-content': 0.037582071687977205,
#                 'Tolerance_Factor': 0.06229915764199177,
#                 'Valence_Electron_Number': 0.021975282805471397,
#                 'Martynov_Batsanov_Electronegativity': 0.04882649934011821,
#                 'Ideal_Bond_Length_Sum': 0.031426847598187244,
#                 'Mendeleev_Number': 0.1106851484704363}}},
#              'Bala_regression_dataset.csv': {'ori_feats2shap': {'Compound': 20.60837120403372,
#                'xBi(Me1Me2)O3': 7.275054606853217,
#                'xPT': 5.9968442030385996,
#                'Tolerance_Factor': 4.654389571341294,
#                'Ionic_Displacements': 39.4761867419901},
#               'name': 'Bala Regression',
#               'type': 'regression',
#               'target_col': 'Ferroelectric_Tc_in_Kelvin',
#               'Deletion': {'dcc': {'Compound': 0.5,
#                 'xBi(Me1Me2)O3': 0.3333333333333333,
#                 'xPT': 0.16666666666666666,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 0.6666666666666666},
#                'feats2shap': {'Compound': 17.91687316171064,
#                 'xBi(Me1Me2)O3': 7.778495140013419,
#                 'xPT': 6.804528361057363,
#                 'Tolerance_Factor': 6.0214097357961345,
#                 'Ionic_Displacements': 35.48037735876476}},
#               'AdditionLinear': {'dcc': {'Compound': 0.6666666666666666,
#                 'xBi(Me1Me2)O3': 0.5,
#                 'xPT': 0.8333333333333334,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 0.16666666666666666},
#                'feats2shap': {'Compound': 22.650770196140797,
#                 'xBi(Me1Me2)O3': 7.885664024922341,
#                 'xPT': 6.97331587135653,
#                 'Tolerance_Factor': 6.553252853478748,
#                 'Ionic_Displacements': 38.22683877612467}},
#               'AdditionRand': {'dcc': {'Compound': 0.5,
#                 'xBi(Me1Me2)O3': 0.8333333333333334,
#                 'xPT': 0.6666666666666666,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 0.16666666666666666},
#                'feats2shap': {'Compound': 26.09138082836313,
#                 'xBi(Me1Me2)O3': 5.199258833710219,
#                 'xPT': 8.033171986288595,
#                 'Tolerance_Factor': 4.173595806977425,
#                 'Ionic_Displacements': 35.6554496437886}},
#               'ReplacementLinear': {'dcc': {'Compound': 0.8333333333333334,
#                 'xBi(Me1Me2)O3': 0.8333333333333334,
#                 'xPT': 0.8333333333333334,
#                 'Tolerance_Factor': 0.8333333333333334,
#                 'Ionic_Displacements': 0.16666666666666666},
#                'feats2shap': {'Compound': 26.04436587994631,
#                 'xBi(Me1Me2)O3': 8.051233669251735,
#                 'xPT': 5.002040540188696,
#                 'Tolerance_Factor': 10.724890044779537,
#                 'Ionic_Displacements': 37.60347596833333}},
#               'ReplacementRand': {'dcc': {'Compound': 0.8333333333333334,
#                 'xBi(Me1Me2)O3': 0.5,
#                 'xPT': 0.16666666666666666,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 0.5},
#                'feats2shap': {'Compound': 19.52307239932515,
#                 'xBi(Me1Me2)O3': 5.8056721427658005,
#                 'xPT': 11.467656461384328,
#                 'Tolerance_Factor': 5.504437214914827,
#                 'Ionic_Displacements': 36.91586911102272}}},
#              'bandgap.csv': {'ori_feats2shap': {'avg_Density_(g/mL)': 0.38674949881126536,
#                'avg_Gordy_electonegativity': 0.11261082103418422,
#                'avg_Number_of_unfilled_d_valence_electrons': 0.039607106645460466,
#                'avg_abs_valence': 0.13361051966235904,
#                'avg_metallic_valence': 0.5456738027324444,
#                'avg_valence_d': 0.03745260536705348,
#                'sum_Density_(g/mL)': 0.035575623016375756,
#                'sum_heat_atomization(kJ/mol)': 0.0830820232385413,
#                'sum_valence_d': 0.07971885553369128,
#                'range_Density_(g/mL)': 0.04064611087913789,
#                'range_Nagle_electonegativity': 0.11111177320401179,
#                'range_heat_of_fusion_(kJ/mol)_': 0.08018168562426807},
#               'name': 'Bandgap',
#               'type': 'regression',
#               'target_col': 'target',
#               'Deletion': {'dcc': {'avg_Density_(g/mL)': 0.9230769230769231,
#                 'avg_Gordy_electonegativity': 0.9230769230769231,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.9230769230769231,
#                 'avg_abs_valence': 0.9230769230769231,
#                 'avg_metallic_valence': 0.9230769230769231,
#                 'avg_valence_d': 0.9230769230769231,
#                 'sum_Density_(g/mL)': 0.9230769230769231,
#                 'sum_heat_atomization(kJ/mol)': 0.9230769230769231,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.9230769230769231,
#                 'range_Nagle_electonegativity': 0.9230769230769231,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.9230769230769231},
#                'feats2shap': {'avg_Density_(g/mL)': 0.38227611360173613,
#                 'avg_Gordy_electonegativity': 0.09580309257117786,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.03507558267449261,
#                 'avg_abs_valence': 0.12888534296007426,
#                 'avg_metallic_valence': 0.5527874693668198,
#                 'avg_valence_d': 0.03520173159004285,
#                 'sum_Density_(g/mL)': 0.034907475280861605,
#                 'sum_heat_atomization(kJ/mol)': 0.0791954693436143,
#                 'sum_valence_d': 0.09439134984454328,
#                 'range_Density_(g/mL)': 0.041880476846755624,
#                 'range_Nagle_electonegativity': 0.11291699644171582,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07864897777623668}},
#               'AdditionLinear': {'dcc': {'avg_Density_(g/mL)': 0.38461538461538464,
#                 'avg_Gordy_electonegativity': 0.5384615384615384,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.07692307692307693,
#                 'avg_abs_valence': 0.5384615384615384,
#                 'avg_metallic_valence': 0.5384615384615384,
#                 'avg_valence_d': 0.46153846153846156,
#                 'sum_Density_(g/mL)': 0.07692307692307693,
#                 'sum_heat_atomization(kJ/mol)': 0.07692307692307693,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.5384615384615384,
#                 'range_Nagle_electonegativity': 0.46153846153846156,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.15384615384615385},
#                'feats2shap': {'avg_Density_(g/mL)': 0.34878720487265963,
#                 'avg_Gordy_electonegativity': 0.14312946297704135,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.030391818941649558,
#                 'avg_abs_valence': 0.08917200171062263,
#                 'avg_metallic_valence': 0.18283963170495154,
#                 'avg_valence_d': 0.03009900800421609,
#                 'sum_Density_(g/mL)': 0.2333078702096194,
#                 'sum_heat_atomization(kJ/mol)': 0.11580558947505692,
#                 'sum_valence_d': 0.050222078971994585,
#                 'range_Density_(g/mL)': 0.12154230360436732,
#                 'range_Nagle_electonegativity': 0.516267621779185,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.10151975273826404}},
#               'AdditionRand': {'dcc': {'avg_Density_(g/mL)': 0.5384615384615384,
#                 'avg_Gordy_electonegativity': 0.46153846153846156,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.07692307692307693,
#                 'avg_abs_valence': 0.38461538461538464,
#                 'avg_metallic_valence': 0.38461538461538464,
#                 'avg_valence_d': 0.3076923076923077,
#                 'sum_Density_(g/mL)': 0.07692307692307693,
#                 'sum_heat_atomization(kJ/mol)': 0.07692307692307693,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.46153846153846156,
#                 'range_Nagle_electonegativity': 0.46153846153846156,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07692307692307693},
#                'feats2shap': {'avg_Density_(g/mL)': 0.37869938500953193,
#                 'avg_Gordy_electonegativity': 0.10330576680600373,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.03957105664378946,
#                 'avg_abs_valence': 0.11823245210395389,
#                 'avg_metallic_valence': 0.5656223380040694,
#                 'avg_valence_d': 0.07674720397774493,
#                 'sum_Density_(g/mL)': 0.05351843862099998,
#                 'sum_heat_atomization(kJ/mol)': 0.12298016578723388,
#                 'sum_valence_d': 0.23700363323669366,
#                 'range_Density_(g/mL)': 0.04731719476514638,
#                 'range_Nagle_electonegativity': 0.1352056041988488,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.11403043722755256}},
#               'ReplacementLinear': {'dcc': {'avg_Density_(g/mL)': 0.3076923076923077,
#                 'avg_Gordy_electonegativity': 0.3076923076923077,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.15384615384615385,
#                 'avg_abs_valence': 0.5384615384615384,
#                 'avg_metallic_valence': 0.38461538461538464,
#                 'avg_valence_d': 0.38461538461538464,
#                 'sum_Density_(g/mL)': 0.07692307692307693,
#                 'sum_heat_atomization(kJ/mol)': 0.07692307692307693,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.3076923076923077,
#                 'range_Nagle_electonegativity': 0.46153846153846156,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07692307692307693},
#                'feats2shap': {'avg_Density_(g/mL)': 0.312803142937387,
#                 'avg_Gordy_electonegativity': 0.24239995889379876,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.027167408404834795,
#                 'avg_abs_valence': 0.08612094786588852,
#                 'avg_metallic_valence': 0.18674095048990155,
#                 'avg_valence_d': 0.02448749328322345,
#                 'sum_Density_(g/mL)': 0.03090261897774724,
#                 'sum_heat_atomization(kJ/mol)': 0.10661808921786221,
#                 'sum_valence_d': 0.22169943731476657,
#                 'range_Density_(g/mL)': 0.14444950357135972,
#                 'range_Nagle_electonegativity': 0.4144741119045575,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.1153464947619701}},
#               'ReplacementRand': {'dcc': {'avg_Density_(g/mL)': 0.46153846153846156,
#                 'avg_Gordy_electonegativity': 0.23076923076923078,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.07692307692307693,
#                 'avg_abs_valence': 0.15384615384615385,
#                 'avg_metallic_valence': 0.3076923076923077,
#                 'avg_valence_d': 0.38461538461538464,
#                 'sum_Density_(g/mL)': 0.07692307692307693,
#                 'sum_heat_atomization(kJ/mol)': 0.07692307692307693,
#                 'sum_valence_d': 0.07692307692307693,
#                 'range_Density_(g/mL)': 0.3076923076923077,
#                 'range_Nagle_electonegativity': 0.38461538461538464,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07692307692307693},
#                'feats2shap': {'avg_Density_(g/mL)': 0.31169609547857263,
#                 'avg_Gordy_electonegativity': 0.11047906092097062,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.041450736528060736,
#                 'avg_abs_valence': 0.11852804685264147,
#                 'avg_metallic_valence': 0.4613749710496894,
#                 'avg_valence_d': 0.06793036687281194,
#                 'sum_Density_(g/mL)': 0.13333892938608494,
#                 'sum_heat_atomization(kJ/mol)': 0.11367450311578943,
#                 'sum_valence_d': 0.1646957090202283,
#                 'range_Density_(g/mL)': 0.07948873364132639,
#                 'range_Nagle_electonegativity': 0.24022308523447042,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.10721441167052005}}},
#              'BMDS_data.csv': {'ori_feats2shap': {'a_mono': 0.003366113320390514,
#                'a': 0.003965316024509296,
#                'b': 0.004353293532454283,
#                'DFT_energy_bi': 0.007216569231486068,
#                'magnetic_moment': 0.0,
#                'formation_energy': 0.00301907319933986,
#                'area': 0.00280292047870701,
#                'd': 0.003056690405491597,
#                'no_soc_bandgap': 0.7005548790673587,
#                'dielectric_constant': 0.00698323244332095,
#                'soc_energy': 0.04146214671132726,
#                'del_e_bilayer_bottom_and_mono': 0.0030584293119203104},
#               'name': 'BMDS',
#               'type': 'regression',
#               'target_col': 'soc_bandgap',
#               'Deletion': {'dcc': {'a_mono': 1.0,
#                 'a': 1.0,
#                 'b': 1.0,
#                 'DFT_energy_bi': 1.0,
#                 'magnetic_moment': 0.9230769230769231,
#                 'formation_energy': 1.0,
#                 'area': 1.0,
#                 'd': 1.0,
#                 'no_soc_bandgap': 1.0,
#                 'dielectric_constant': 0.9230769230769231,
#                 'soc_energy': 1.0,
#                 'del_e_bilayer_bottom_and_mono': 1.0},
#                'feats2shap': {'a_mono': 0.003388528671053236,
#                 'a': 0.004498684164401067,
#                 'b': 0.004371039958703638,
#                 'DFT_energy_bi': 0.006322623463068199,
#                 'magnetic_moment': 0.0,
#                 'formation_energy': 0.0033775734038413194,
#                 'area': 0.0029112489251213887,
#                 'd': 0.002325136247195615,
#                 'no_soc_bandgap': 0.689886848892953,
#                 'dielectric_constant': 0.009497424424896967,
#                 'soc_energy': 0.04153100835203226,
#                 'del_e_bilayer_bottom_and_mono': 0.0034515094364696653}},
#               'AdditionLinear': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.23076923076923078,
#                 'b': 0.23076923076923078,
#                 'DFT_energy_bi': 0.07692307692307693,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.07692307692307693,
#                 'area': 0.07692307692307693,
#                 'd': 0.07692307692307693,
#                 'no_soc_bandgap': 0.15384615384615385,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.0064903939736763745,
#                 'a': 0.009208097092485455,
#                 'b': 0.024849122387214657,
#                 'DFT_energy_bi': 0.017386736744351355,
#                 'magnetic_moment': 0.01234773490899672,
#                 'formation_energy': 0.009398962205453205,
#                 'area': 0.010631757861651785,
#                 'd': 0.003939276302962617,
#                 'no_soc_bandgap': 0.7833321513261986,
#                 'dielectric_constant': 0.021824693167294774,
#                 'soc_energy': 0.03693439728919072,
#                 'del_e_bilayer_bottom_and_mono': 0.006815879058207919}},
#               'AdditionRand': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.23076923076923078,
#                 'b': 0.23076923076923078,
#                 'DFT_energy_bi': 0.15384615384615385,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.07692307692307693,
#                 'area': 0.07692307692307693,
#                 'd': 0.15384615384615385,
#                 'no_soc_bandgap': 0.15384615384615385,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.008790095002584042,
#                 'a': 0.006195179214077751,
#                 'b': 0.008343307986473585,
#                 'DFT_energy_bi': 0.013116978283742805,
#                 'magnetic_moment': 0.020954735661190535,
#                 'formation_energy': 0.015299440511009572,
#                 'area': 0.018029855160616774,
#                 'd': 0.01496148906856853,
#                 'no_soc_bandgap': 0.7629288356100049,
#                 'dielectric_constant': 0.05026192184119079,
#                 'soc_energy': 0.057422641726905234,
#                 'del_e_bilayer_bottom_and_mono': 0.011512354017301517}},
#               'ReplacementLinear': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.15384615384615385,
#                 'b': 0.15384615384615385,
#                 'DFT_energy_bi': 0.15384615384615385,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.07692307692307693,
#                 'area': 0.07692307692307693,
#                 'd': 0.15384615384615385,
#                 'no_soc_bandgap': 0.15384615384615385,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.0036694459134691774,
#                 'a': 0.012502962663858969,
#                 'b': 0.008219646993151522,
#                 'DFT_energy_bi': 0.007608133158362422,
#                 'magnetic_moment': 0.0070541511652892205,
#                 'formation_energy': 0.023913286908527658,
#                 'area': 0.006592122941971795,
#                 'd': 0.0034396127356640595,
#                 'no_soc_bandgap': 0.7776238704740648,
#                 'dielectric_constant': 0.035256289520819724,
#                 'soc_energy': 0.050527549477707955,
#                 'del_e_bilayer_bottom_and_mono': 0.014598663764395087}},
#               'ReplacementRand': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.15384615384615385,
#                 'b': 0.15384615384615385,
#                 'DFT_energy_bi': 0.07692307692307693,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.07692307692307693,
#                 'area': 0.07692307692307693,
#                 'd': 0.07692307692307693,
#                 'no_soc_bandgap': 0.15384615384615385,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.008102874536678614,
#                 'a': 0.006243211971816898,
#                 'b': 0.0073424974141413045,
#                 'DFT_energy_bi': 0.012263033892027698,
#                 'magnetic_moment': 0.01502394405625472,
#                 'formation_energy': 0.010406287031176659,
#                 'area': 0.00822304245027199,
#                 'd': 0.012142411365015435,
#                 'no_soc_bandgap': 0.7856266926083538,
#                 'dielectric_constant': 0.036824941453591734,
#                 'soc_energy': 0.05042025531799636,
#                 'del_e_bilayer_bottom_and_mono': 0.008524540461964067}}},
#              'Crystal_structure.csv': {'ori_feats2shap': {'v(A)': 0.00928807805117576,
#                'v(B)': 0.008590939033111613,
#                'r(AXII)(Å)': 0.014293254707227978,
#                'r(AVI)(Å)': 0.01505931174813062,
#                'r(BVI)(Å)': 0.01816361031209468,
#                'EN(A)': 0.03062920334507453,
#                'EN(B)': 0.041057098775248,
#                'l(A-O)(Å)': 0.01676954859238621,
#                'l(B-O)(Å)': 0.015547435066267122,
#                'ΔENR': 0.022561250770963527,
#                'tG': 0.03321633640362814,
#                'τ': 0.04550646279639944,
#                'μ': 0.016420558105693362},
#               'name': 'Crystal Structure',
#               'type': 'classification',
#               'target_col': 'Lowest distortion',
#               'Deletion': {'dcc': {'v(A)': 1.0,
#                 'v(B)': 1.0,
#                 'r(AXII)(Å)': 1.0,
#                 'r(AVI)(Å)': 1.0,
#                 'r(BVI)(Å)': 1.0,
#                 'EN(A)': 1.0,
#                 'EN(B)': 1.0,
#                 'l(A-O)(Å)': 1.0,
#                 'l(B-O)(Å)': 1.0,
#                 'ΔENR': 1.0,
#                 'tG': 1.0,
#                 'τ': 1.0,
#                 'μ': 1.0},
#                'feats2shap': {'v(A)': 0.008810741996285584,
#                 'v(B)': 0.00920542807080994,
#                 'r(AXII)(Å)': 0.015468757057301392,
#                 'r(AVI)(Å)': 0.014227826789014337,
#                 'r(BVI)(Å)': 0.01626597475240206,
#                 'EN(A)': 0.032639057308883127,
#                 'EN(B)': 0.038254284808604364,
#                 'l(A-O)(Å)': 0.017568155006672366,
#                 'l(B-O)(Å)': 0.01423415755171675,
#                 'ΔENR': 0.021696389477840538,
#                 'tG': 0.03426379643938486,
#                 'τ': 0.045661695868372876,
#                 'μ': 0.016881632782572834}},
#               'AdditionLinear': {'dcc': {'v(A)': 0.7857142857142857,
#                 'v(B)': 0.7142857142857143,
#                 'r(AXII)(Å)': 0.8571428571428571,
#                 'r(AVI)(Å)': 0.21428571428571427,
#                 'r(BVI)(Å)': 0.5714285714285714,
#                 'EN(A)': 0.7857142857142857,
#                 'EN(B)': 0.7142857142857143,
#                 'l(A-O)(Å)': 0.7857142857142857,
#                 'l(B-O)(Å)': 0.7857142857142857,
#                 'ΔENR': 0.2857142857142857,
#                 'tG': 0.5714285714285714,
#                 'τ': 0.42857142857142855,
#                 'μ': 0.5714285714285714},
#                'feats2shap': {'v(A)': 0.010424465632284717,
#                 'v(B)': 0.009216590652556967,
#                 'r(AXII)(Å)': 0.015159501882321515,
#                 'r(AVI)(Å)': 0.017086785098482785,
#                 'r(BVI)(Å)': 0.017239887101940923,
#                 'EN(A)': 0.03270675400853059,
#                 'EN(B)': 0.039199469091045915,
#                 'l(A-O)(Å)': 0.015483254872796533,
#                 'l(B-O)(Å)': 0.015240459878364719,
#                 'ΔENR': 0.020989679797390876,
#                 'tG': 0.03371604447769173,
#                 'τ': 0.04604363898469486,
#                 'μ': 0.018553987556727315}},
#               'AdditionRand': {'dcc': {'v(A)': 0.35714285714285715,
#                 'v(B)': 0.42857142857142855,
#                 'r(AXII)(Å)': 0.5,
#                 'r(AVI)(Å)': 0.21428571428571427,
#                 'r(BVI)(Å)': 0.5714285714285714,
#                 'EN(A)': 0.7142857142857143,
#                 'EN(B)': 0.5714285714285714,
#                 'l(A-O)(Å)': 0.7142857142857143,
#                 'l(B-O)(Å)': 0.7857142857142857,
#                 'ΔENR': 0.2857142857142857,
#                 'tG': 0.5,
#                 'τ': 0.21428571428571427,
#                 'μ': 0.5714285714285714},
#                'feats2shap': {'v(A)': 0.009089781071233895,
#                 'v(B)': 0.010054862323485656,
#                 'r(AXII)(Å)': 0.015580309762616776,
#                 'r(AVI)(Å)': 0.017210720632091184,
#                 'r(BVI)(Å)': 0.019343306891618027,
#                 'EN(A)': 0.03121799870551132,
#                 'EN(B)': 0.03950724855087241,
#                 'l(A-O)(Å)': 0.01555230760736358,
#                 'l(B-O)(Å)': 0.01588537605228007,
#                 'ΔENR': 0.023197321836709275,
#                 'tG': 0.033077980947683105,
#                 'τ': 0.041490053134045926,
#                 'μ': 0.016922303150384482}},
#               'ReplacementLinear': {'dcc': {'v(A)': 0.42857142857142855,
#                 'v(B)': 0.2857142857142857,
#                 'r(AXII)(Å)': 0.14285714285714285,
#                 'r(AVI)(Å)': 0.2857142857142857,
#                 'r(BVI)(Å)': 0.35714285714285715,
#                 'EN(A)': 0.2857142857142857,
#                 'EN(B)': 0.42857142857142855,
#                 'l(A-O)(Å)': 0.2857142857142857,
#                 'l(B-O)(Å)': 0.35714285714285715,
#                 'ΔENR': 0.2857142857142857,
#                 'tG': 0.5,
#                 'τ': 0.2857142857142857,
#                 'μ': 0.2857142857142857},
#                'feats2shap': {'v(A)': 0.009787605423961116,
#                 'v(B)': 0.007013876804639244,
#                 'r(AXII)(Å)': 0.01715030173375464,
#                 'r(AVI)(Å)': 0.01796563234206906,
#                 'r(BVI)(Å)': 0.014438088787801262,
#                 'EN(A)': 0.035686917035092525,
#                 'EN(B)': 0.038919836506878046,
#                 'l(A-O)(Å)': 0.015794768025719032,
#                 'l(B-O)(Å)': 0.016559870671202594,
#                 'ΔENR': 0.02140880614704803,
#                 'tG': 0.031700469968179025,
#                 'τ': 0.0443069644602915,
#                 'μ': 0.01781956622765796}},
#               'ReplacementRand': {'dcc': {'v(A)': 0.5,
#                 'v(B)': 0.2857142857142857,
#                 'r(AXII)(Å)': 0.2857142857142857,
#                 'r(AVI)(Å)': 0.2857142857142857,
#                 'r(BVI)(Å)': 0.35714285714285715,
#                 'EN(A)': 0.35714285714285715,
#                 'EN(B)': 0.21428571428571427,
#                 'l(A-O)(Å)': 0.2857142857142857,
#                 'l(B-O)(Å)': 0.5,
#                 'ΔENR': 0.14285714285714285,
#                 'tG': 0.5714285714285714,
#                 'τ': 0.07142857142857142,
#                 'μ': 0.35714285714285715},
#                'feats2shap': {'v(A)': 0.0088894135707141,
#                 'v(B)': 0.007262723208090987,
#                 'r(AXII)(Å)': 0.017089765913381662,
#                 'r(AVI)(Å)': 0.01583667107870955,
#                 'r(BVI)(Å)': 0.017981501738568887,
#                 'EN(A)': 0.03060475048549736,
#                 'EN(B)': 0.03876308137896218,
#                 'l(A-O)(Å)': 0.017191207321955542,
#                 'l(B-O)(Å)': 0.014013360476267729,
#                 'ΔENR': 0.020641377363374923,
#                 'tG': 0.037704828189681294,
#                 'τ': 0.04732962514047932,
#                 'μ': 0.014435586552067134}}},
#              'Glass.csv': {'ori_feats2shap': {'RI': 0.037859991545018706,
#                'Na': 0.025386526591311877,
#                'Mg': 0.058506488488587395,
#                'Al': 0.050366751947213295,
#                'Si': 0.014770640346268021,
#                'K': 0.020324243126125522,
#                'Ca': 0.031106733133963962,
#                'Ba': 0.032559546525034226,
#                'Fe': 0.008634754652686791},
#               'name': 'Glass',
#               'type': 'classification',
#               'target_col': 'Type of glass',
#               'Deletion': {'dcc': {'RI': 0.4,
#                 'Na': 0.8,
#                 'Mg': 1.0,
#                 'Al': 0.8,
#                 'Si': 0.8,
#                 'K': 0.8,
#                 'Ca': 0.6,
#                 'Ba': 1.0,
#                 'Fe': 0.9},
#                'feats2shap': {'RI': 0.04092262655773734,
#                 'Na': 0.025502149168326226,
#                 'Mg': 0.059109921356054175,
#                 'Al': 0.04597248263301235,
#                 'Si': 0.013652058664297521,
#                 'K': 0.01980841269218983,
#                 'Ca': 0.0338193953893022,
#                 'Ba': 0.02794519874146063,
#                 'Fe': 0.010355458159443177}},
#               'AdditionLinear': {'dcc': {'RI': 0.2,
#                 'Na': 0.2,
#                 'Mg': 0.1,
#                 'Al': 0.3,
#                 'Si': 0.1,
#                 'K': 0.1,
#                 'Ca': 0.4,
#                 'Ba': 0.1,
#                 'Fe': 0.1},
#                'feats2shap': {'RI': 0.03729989948617758,
#                 'Na': 0.02418354641832969,
#                 'Mg': 0.06359923565955804,
#                 'Al': 0.04479283475737272,
#                 'Si': 0.015280699308936121,
#                 'K': 0.022052240464381354,
#                 'Ca': 0.030572157055885854,
#                 'Ba': 0.028273284204089574,
#                 'Fe': 0.009796602038296064}},
#               'AdditionRand': {'dcc': {'RI': 0.5,
#                 'Na': 0.3,
#                 'Mg': 0.1,
#                 'Al': 0.4,
#                 'Si': 0.2,
#                 'K': 0.1,
#                 'Ca': 0.6,
#                 'Ba': 0.1,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.03652529059269656,
#                 'Na': 0.027101052513460223,
#                 'Mg': 0.058516703523799334,
#                 'Al': 0.050769430882238585,
#                 'Si': 0.014871285730369777,
#                 'K': 0.021401433974334704,
#                 'Ca': 0.03066218452165087,
#                 'Ba': 0.025015479633957578,
#                 'Fe': 0.00992659965890528}},
#               'ReplacementLinear': {'dcc': {'RI': 0.3,
#                 'Na': 0.5,
#                 'Mg': 0.1,
#                 'Al': 0.3,
#                 'Si': 0.4,
#                 'K': 0.1,
#                 'Ca': 0.2,
#                 'Ba': 0.1,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.036790832721259346,
#                 'Na': 0.030186013789728766,
#                 'Mg': 0.06549389719495052,
#                 'Al': 0.0487308634001864,
#                 'Si': 0.014657137482486537,
#                 'K': 0.017543850925767,
#                 'Ca': 0.03084147444842451,
#                 'Ba': 0.0280612882325972,
#                 'Fe': 0.008342633326234897}},
#               'ReplacementRand': {'dcc': {'RI': 0.2,
#                 'Na': 0.5,
#                 'Mg': 0.1,
#                 'Al': 0.4,
#                 'Si': 0.3,
#                 'K': 0.1,
#                 'Ca': 0.2,
#                 'Ba': 0.1,
#                 'Fe': 0.1},
#                'feats2shap': {'RI': 0.037585102501942025,
#                 'Na': 0.022015398368833778,
#                 'Mg': 0.06738623009205659,
#                 'Al': 0.0443099031377737,
#                 'Si': 0.016149080755065336,
#                 'K': 0.021183963481963303,
#                 'Ca': 0.02885268644074598,
#                 'Ba': 0.030724370356067277,
#                 'Fe': 0.009275426507934796}}},
#              'PUE.csv': {'ori_feats2shap': {'ZS_CHS': 0.07208610019768472,
#                'ZS_R': 0.013958132892156003,
#                'ZS_log_Tr1K': 0.006903631445503145,
#                'ZS_log_Tr2K': 0.00881557172441453,
#                'PMStep': 0.0007424758525061988,
#                'Form_Method': 0.0010502969507552012,
#                'ZS_log_CSArea': 0.00702946402506858,
#                'ZS_log_StrainRate': 0.013377728425863274,
#                'ZS_log_PO_MW': 0.06258830317076215,
#                'ZS_log_FCVm': 0.13645203544301585,
#                'ZS_FCCED': 0.07534204358060362,
#                'ZS_log_Fchi': 0.01264861167444042,
#                'ZS_SS_TPSA_norm': 0.015052753265992917,
#                'ZS_SS_MolLogP_norm': 0.011297945684567195,
#                'ZS_HS_BertzCT': 0.030223438658344048,
#                'ZS_SS_VSA_EState8': 0.050845734315427764,
#                'ZS_SS_PEOE_VSA8': 0.012340758037346597,
#                'ZS_log_HS_NumNHCO_norm': 0.015389459071923515,
#                'ZS_FC_NumHAcceptors_norm': 0.017376917536886416,
#                'ZS_FC_RingCount_norm': 0.06483405605254663},
#               'name': 'PUE',
#               'type': 'regression',
#               'target_col': 'logYM',
#               'Deletion': {'dcc': {'ZS_CHS': 0.9047619047619048,
#                 'ZS_R': 1.0,
#                 'ZS_log_Tr1K': 1.0,
#                 'ZS_log_Tr2K': 1.0,
#                 'PMStep': 1.0,
#                 'Form_Method': 0.9523809523809523,
#                 'ZS_log_CSArea': 1.0,
#                 'ZS_log_StrainRate': 1.0,
#                 'ZS_log_PO_MW': 0.9523809523809523,
#                 'ZS_log_FCVm': 0.9523809523809523,
#                 'ZS_FCCED': 1.0,
#                 'ZS_log_Fchi': 1.0,
#                 'ZS_SS_TPSA_norm': 1.0,
#                 'ZS_SS_MolLogP_norm': 1.0,
#                 'ZS_HS_BertzCT': 1.0,
#                 'ZS_SS_VSA_EState8': 1.0,
#                 'ZS_SS_PEOE_VSA8': 0.9523809523809523,
#                 'ZS_log_HS_NumNHCO_norm': 1.0,
#                 'ZS_FC_NumHAcceptors_norm': 1.0,
#                 'ZS_FC_RingCount_norm': 1.0},
#                'feats2shap': {'ZS_CHS': 0.07754251201482165,
#                 'ZS_R': 0.008480409508719386,
#                 'ZS_log_Tr1K': 0.009237320133183418,
#                 'ZS_log_Tr2K': 0.004867524238199057,
#                 'PMStep': 0.0007018152884463628,
#                 'Form_Method': 0.0010887920119773606,
#                 'ZS_log_CSArea': 0.0064027508224809,
#                 'ZS_log_StrainRate': 0.013120060504343958,
#                 'ZS_log_PO_MW': 0.06532391898577464,
#                 'ZS_log_FCVm': 0.13051521252657236,
#                 'ZS_FCCED': 0.0735615327787324,
#                 'ZS_log_Fchi': 0.014475835754319315,
#                 'ZS_SS_TPSA_norm': 0.036738808820350105,
#                 'ZS_SS_MolLogP_norm': 0.006993643191749447,
#                 'ZS_HS_BertzCT': 0.04470579284754972,
#                 'ZS_SS_VSA_EState8': 0.04084074464265781,
#                 'ZS_SS_PEOE_VSA8': 0.008776940399750887,
#                 'ZS_log_HS_NumNHCO_norm': 0.012912863151770697,
#                 'ZS_FC_NumHAcceptors_norm': 0.015857944465756474,
#                 'ZS_FC_RingCount_norm': 0.054833416255596075}},
#               'AdditionLinear': {'dcc': {'ZS_CHS': 0.7619047619047619,
#                 'ZS_R': 0.42857142857142855,
#                 'ZS_log_Tr1K': 0.5238095238095238,
#                 'ZS_log_Tr2K': 0.6190476190476191,
#                 'PMStep': 0.047619047619047616,
#                 'Form_Method': 0.7619047619047619,
#                 'ZS_log_CSArea': 0.6190476190476191,
#                 'ZS_log_StrainRate': 0.7142857142857143,
#                 'ZS_log_PO_MW': 0.3333333333333333,
#                 'ZS_log_FCVm': 0.23809523809523808,
#                 'ZS_FCCED': 0.5238095238095238,
#                 'ZS_log_Fchi': 0.09523809523809523,
#                 'ZS_SS_TPSA_norm': 0.047619047619047616,
#                 'ZS_SS_MolLogP_norm': 0.19047619047619047,
#                 'ZS_HS_BertzCT': 0.47619047619047616,
#                 'ZS_SS_VSA_EState8': 0.5714285714285714,
#                 'ZS_SS_PEOE_VSA8': 0.6190476190476191,
#                 'ZS_log_HS_NumNHCO_norm': 0.7619047619047619,
#                 'ZS_FC_NumHAcceptors_norm': 0.7619047619047619,
#                 'ZS_FC_RingCount_norm': 0.5714285714285714},
#                'feats2shap': {'ZS_CHS': 0.08422878639353917,
#                 'ZS_R': 0.018115215759340667,
#                 'ZS_log_Tr1K': 0.005436551993728024,
#                 'ZS_log_Tr2K': 0.0076157664246530735,
#                 'PMStep': 0.0009767129047739283,
#                 'Form_Method': 0.0014473672797394208,
#                 'ZS_log_CSArea': 0.0052993097532456675,
#                 'ZS_log_StrainRate': 0.012858250880645114,
#                 'ZS_log_PO_MW': 0.02770118938468311,
#                 'ZS_log_FCVm': 0.12109377933389029,
#                 'ZS_FCCED': 0.03989696234652353,
#                 'ZS_log_Fchi': 0.01776904904362225,
#                 'ZS_SS_TPSA_norm': 0.019766704954613933,
#                 'ZS_SS_MolLogP_norm': 0.008078055884643784,
#                 'ZS_HS_BertzCT': 0.03617741070077262,
#                 'ZS_SS_VSA_EState8': 0.1103314750845637,
#                 'ZS_SS_PEOE_VSA8': 0.010311455788531442,
#                 'ZS_log_HS_NumNHCO_norm': 0.01781477696180358,
#                 'ZS_FC_NumHAcceptors_norm': 0.021129352992365295,
#                 'ZS_FC_RingCount_norm': 0.051959537452778815}},
#               'AdditionRand': {'dcc': {'ZS_CHS': 0.6666666666666666,
#                 'ZS_R': 0.38095238095238093,
#                 'ZS_log_Tr1K': 0.19047619047619047,
#                 'ZS_log_Tr2K': 0.6190476190476191,
#                 'PMStep': 0.047619047619047616,
#                 'Form_Method': 0.47619047619047616,
#                 'ZS_log_CSArea': 0.38095238095238093,
#                 'ZS_log_StrainRate': 0.5238095238095238,
#                 'ZS_log_PO_MW': 0.23809523809523808,
#                 'ZS_log_FCVm': 0.2857142857142857,
#                 'ZS_FCCED': 0.5714285714285714,
#                 'ZS_log_Fchi': 0.14285714285714285,
#                 'ZS_SS_TPSA_norm': 0.09523809523809523,
#                 'ZS_SS_MolLogP_norm': 0.047619047619047616,
#                 'ZS_HS_BertzCT': 0.23809523809523808,
#                 'ZS_SS_VSA_EState8': 0.3333333333333333,
#                 'ZS_SS_PEOE_VSA8': 0.38095238095238093,
#                 'ZS_log_HS_NumNHCO_norm': 0.6190476190476191,
#                 'ZS_FC_NumHAcceptors_norm': 0.38095238095238093,
#                 'ZS_FC_RingCount_norm': 0.5238095238095238},
#                'feats2shap': {'ZS_CHS': 0.05927630796253023,
#                 'ZS_R': 0.0074233434987146405,
#                 'ZS_log_Tr1K': 0.007407144304263983,
#                 'ZS_log_Tr2K': 0.009308311772921156,
#                 'PMStep': 0.0011999738692904727,
#                 'Form_Method': 0.002087655874193871,
#                 'ZS_log_CSArea': 0.006279394590130735,
#                 'ZS_log_StrainRate': 0.013897898421389844,
#                 'ZS_log_PO_MW': 0.08419885593946409,
#                 'ZS_log_FCVm': 0.13732463578527188,
#                 'ZS_FCCED': 0.046074996193506454,
#                 'ZS_log_Fchi': 0.015973430904155553,
#                 'ZS_SS_TPSA_norm': 0.014127939554989895,
#                 'ZS_SS_MolLogP_norm': 0.013412583665310514,
#                 'ZS_HS_BertzCT': 0.038152801773831915,
#                 'ZS_SS_VSA_EState8': 0.07189219860621121,
#                 'ZS_SS_PEOE_VSA8': 0.0091829981215836,
#                 'ZS_log_HS_NumNHCO_norm': 0.015780565388135527,
#                 'ZS_FC_NumHAcceptors_norm': 0.016994985139453425,
#                 'ZS_FC_RingCount_norm': 0.05153035405789707}},
#               'ReplacementLinear': {'dcc': {'ZS_CHS': 0.42857142857142855,
#                 'ZS_R': 0.09523809523809523,
#                 'ZS_log_Tr1K': 0.42857142857142855,
#                 'ZS_log_Tr2K': 0.5238095238095238,
#                 'PMStep': 0.09523809523809523,
#                 'Form_Method': 0.3333333333333333,
#                 'ZS_log_CSArea': 0.5238095238095238,
#                 'ZS_log_StrainRate': 0.6190476190476191,
#                 'ZS_log_PO_MW': 0.09523809523809523,
#                 'ZS_log_FCVm': 0.6190476190476191,
#                 'ZS_FCCED': 0.5238095238095238,
#                 'ZS_log_Fchi': 0.09523809523809523,
#                 'ZS_SS_TPSA_norm': 0.3333333333333333,
#                 'ZS_SS_MolLogP_norm': 0.047619047619047616,
#                 'ZS_HS_BertzCT': 0.2857142857142857,
#                 'ZS_SS_VSA_EState8': 0.2857142857142857,
#                 'ZS_SS_PEOE_VSA8': 0.2857142857142857,
#                 'ZS_log_HS_NumNHCO_norm': 0.42857142857142855,
#                 'ZS_FC_NumHAcceptors_norm': 0.42857142857142855,
#                 'ZS_FC_RingCount_norm': 0.3333333333333333},
#                'feats2shap': {'ZS_CHS': 0.06199958596140087,
#                 'ZS_R': 0.011684138016342905,
#                 'ZS_log_Tr1K': 0.008795842049081062,
#                 'ZS_log_Tr2K': 0.006253302405132326,
#                 'PMStep': 0.0018871575665582035,
#                 'Form_Method': 0.0016973911175370766,
#                 'ZS_log_CSArea': 0.005154746103349673,
#                 'ZS_log_StrainRate': 0.01470363987768934,
#                 'ZS_log_PO_MW': 0.08682852479322847,
#                 'ZS_log_FCVm': 0.10813760865886765,
#                 'ZS_FCCED': 0.0924112473357994,
#                 'ZS_log_Fchi': 0.013140642012662284,
#                 'ZS_SS_TPSA_norm': 0.013112466416755467,
#                 'ZS_SS_MolLogP_norm': 0.03129312274654956,
#                 'ZS_HS_BertzCT': 0.03462321818815738,
#                 'ZS_SS_VSA_EState8': 0.0566606239931008,
#                 'ZS_SS_PEOE_VSA8': 0.013311055382165867,
#                 'ZS_log_HS_NumNHCO_norm': 0.015409889369844377,
#                 'ZS_FC_NumHAcceptors_norm': 0.015929136965390178,
#                 'ZS_FC_RingCount_norm': 0.05633736086668456}},
#               'ReplacementRand': {'dcc': {'ZS_CHS': 0.6666666666666666,
#                 'ZS_R': 0.14285714285714285,
#                 'ZS_log_Tr1K': 0.6190476190476191,
#                 'ZS_log_Tr2K': 0.6190476190476191,
#                 'PMStep': 0.047619047619047616,
#                 'Form_Method': 0.38095238095238093,
#                 'ZS_log_CSArea': 0.19047619047619047,
#                 'ZS_log_StrainRate': 0.42857142857142855,
#                 'ZS_log_PO_MW': 0.2857142857142857,
#                 'ZS_log_FCVm': 0.23809523809523808,
#                 'ZS_FCCED': 0.47619047619047616,
#                 'ZS_log_Fchi': 0.14285714285714285,
#                 'ZS_SS_TPSA_norm': 0.19047619047619047,
#                 'ZS_SS_MolLogP_norm': 0.38095238095238093,
#                 'ZS_HS_BertzCT': 0.6666666666666666,
#                 'ZS_SS_VSA_EState8': 0.23809523809523808,
#                 'ZS_SS_PEOE_VSA8': 0.38095238095238093,
#                 'ZS_log_HS_NumNHCO_norm': 0.5238095238095238,
#                 'ZS_FC_NumHAcceptors_norm': 0.47619047619047616,
#                 'ZS_FC_RingCount_norm': 0.42857142857142855},
#                'feats2shap': {'ZS_CHS': 0.09554674433258976,
#                 'ZS_R': 0.019732058082147178,
#                 'ZS_log_Tr1K': 0.009729363278622765,
#                 'ZS_log_Tr2K': 0.00727100399775003,
#                 'PMStep': 0.0013489148979309595,
#                 'Form_Method': 0.001677388580262592,
#                 'ZS_log_CSArea': 0.007871394287363687,
#                 'ZS_log_StrainRate': 0.012135506393609349,
#                 'ZS_log_PO_MW': 0.027386112682155666,
#                 'ZS_log_FCVm': 0.08812962866667026,
#                 'ZS_FCCED': 0.13391845575244854,
#                 'ZS_log_Fchi': 0.030939516901441852,
#                 'ZS_SS_TPSA_norm': 0.013746356530901933,
#                 'ZS_SS_MolLogP_norm': 0.011234481747137346,
#                 'ZS_HS_BertzCT': 0.02590840661871539,
#                 'ZS_SS_VSA_EState8': 0.03828645824212566,
#                 'ZS_SS_PEOE_VSA8': 0.013411632150168391,
#                 'ZS_log_HS_NumNHCO_norm': 0.014763704652934315,
#                 'ZS_FC_NumHAcceptors_norm': 0.018677345529722972,
#                 'ZS_FC_RingCount_norm': 0.06997036828063548}}}})

# %%
from enum import Enum

class PerturbationType(Enum):
    Deletion = "Deletion"
    AdditionLinear = "AdditionLinear"
    AdditionRand = "AdditionRand"
    ReplacementLinear = "ReplacementLinear"
    ReplacementRand = "ReplacementRand"

# %%
results.keys()
# Out:
# dict_keys(['Bala_classification_dataset.csv', 'Bala_regression_dataset.csv', 'bandgap.csv', 'BMDS_data.csv', 'Crystal_structure.csv', 'Glass.csv', 'PUE.csv'])

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D



markers = ["o", "s", "D", "v", "^"]
labels = [
    "Deletion",
    r"$Addition_{Linear}$",
    r"$Addition_{Random}$",
    r"$Replacement_{Linear}$",
    r"$Replacement_{Random}$",
]
dataset2colors = {}
colors = ["#ff595e","#1982c4","#6a4c93","#d677b8", "#222222"]
for k in results.keys():
    
    dataset_name = results[k]["name"]
    task_type = results[k]["type"]
    target_col = results[k]["target_col"]
    if task_type == "classification":
        fig, ax = plt.subplots(figsize=(12, 8))
        color = colors.pop(0)
        dataset2colors[dataset_name] = color
        for ptb_type in PerturbationType:
            if ptb_type.value not in results[k]:
                continue
            dcc_val = results[k][ptb_type.value]["dcc"]
            feats2shap = results[k][ptb_type.value]["feats2shap"]
            feats = list(feats2shap.keys())
            shape_values = [feats2shap[f] for f in feats]
            shape_values = np.array(shape_values)
            shape_values = shape_values / np.max(shape_values)  # Normalize to [0, 1]
            dcc_values = [dcc_val[f] for f in feats]
            plt.scatter(
                dcc_values,
                shape_values,
                marker=markers[list(PerturbationType).index(ptb_type)],
                s=100,
                color=color,
                label=f"{dataset_name}",
            )
        plt.xlabel(r"$DCC_{f_i}$")
        plt.ylabel(r"$SHAP_{f_i}$")

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


markers = ["o", "s", "D", "v", "^"]
labels = [
    "Deletion",
    r"$Addition_{Linear}$",
    r"$Addition_{Random}$",
    r"$Replacement_{Linear}$",
    r"$Replacement_{Random}$",
]
dataset2colors = {}
colors = ["#ff595e","#1982c4","#6a4c93","#d677b8", "#222222"]
for k in results.keys():
    dataset_name = results[k]["name"]
    task_type = results[k]["type"]
    target_col = results[k]["target_col"]
    if task_type == "regression":
        fig, ax = plt.subplots(figsize=(12, 8))
        color = colors.pop(0)
        dataset2colors[dataset_name] = color
        for ptb_type in PerturbationType:
            if ptb_type.value not in results[k]:
                continue
            dcc_val = results[k][ptb_type.value]["dcc"]
            feats2shap = results[k][ptb_type.value]["feats2shap"]
            feats = list(feats2shap.keys())
            shape_values = [feats2shap[f] for f in feats]
            shape_values = np.array(shape_values)
            shape_values = shape_values / np.max(shape_values)  # Normalize to [0, 1]
            dcc_values = [dcc_val[f] for f in feats]
            plt.scatter(
                dcc_values,
                shape_values,
                marker=markers[list(PerturbationType).index(ptb_type)],
                s=100,
                color=color,
                label=f"{dataset_name}",
            )

        plt.xlabel(r"$DCC_{f_i}$")
        plt.ylabel(r"$SHAP_{f_i}$")
