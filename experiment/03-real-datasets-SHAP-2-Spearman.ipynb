# %%
from DCC import *
from Utils import *
from Plots import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path
from collections import defaultdict

# %%
init_plotting()

# %%
dataset2name = {
    "Bala_classification_dataset.csv": "Bala Classification",
    "Bala_regression_dataset.csv": "Bala Regression",
    "bandgap.csv": "Bandgap",
    "BMDS_data.csv": "BMDS",
    "Crystal_structure.csv": "Crystal Structure",
    "Glass.csv": "Glass",
    "PUE.csv": "PUE",
}

# %%
from enum import Enum
from sklearn.datasets import make_classification


class PerturbationType(Enum):
    Deletion = "Deletion"
    AdditionLinear = "AdditionLinear"
    AdditionRand = "AdditionRand"
    ReplacementLinear = "ReplacementLinear"
    ReplacementRand = "ReplacementRand"


def generate_random_according_df(
    n: int, m: int, df: pd.DataFrame, task_type=None, target_col=None
):
    cols = df.columns
    new_data = []
    for i in range(n):
        new_row = []
        for j in range(m):
            new_row.append(random.uniform(df[cols[j]].min(), df[cols[j]].max()))
        new_data.append(new_row)
    new_df = pd.DataFrame(new_data, columns=cols)
    if task_type == "classification":
        if target_col is not None:
            new_df[target_col] = np.random.choice(
                df[target_col].unique(), size=n, replace=True
            )
    return new_df


def generate_linear_according_df(
    n: int, m: int, df: pd.DataFrame, task_type=None, target_col=None
):
    if task_type == "classification":
        # Generate a classification dataset
        X, y = make_classification(
            n_samples=n,
            n_features=m - 1,
            n_classes=len(df[target_col].unique()),
            n_informative= (m - 1) // 2,
        )[:2]
    else:
        X, y = make_regression(
            n_samples=n, n_features=m - 1, noise=0.1
        )[:2]

    X_cols = [x for x in df.columns if x != target_col]
    df_linear = pd.DataFrame(X, columns=X_cols)
    df_linear[target_col] = y
    # normalize the data to the range of df
    for col in df.columns:
        min_val = df[col].min()
        max_val = df[col].max()
        df_linear[col] = (df_linear[col] - df_linear[col].min()) / (
            df_linear[col].max() - df_linear[col].min()
        ) * (max_val - min_val) + min_val

    return df_linear


def dcc_exp(
    data: pd.DataFrame,
    ptb_type: PerturbationType,
    task_type,
    target_col,
    ratio=0.1,
    eps=0.04,
    corr_func=spearman_matrix,
):
    eps /= 2
    n, m = data.shape
    if ptb_type == PerturbationType.Deletion:
        perturbed_data = data.sample(frac=1 - ratio)
    elif ptb_type == PerturbationType.AdditionLinear:
        df_linear = generate_linear_according_df(
            n // 20, m, data, task_type, target_col
        )
        perturbed_data = pd.concat([data, df_linear], ignore_index=True)
    elif ptb_type == PerturbationType.AdditionRand:
        df_rand = generate_random_according_df(n // 20, m, data, task_type, target_col)
        perturbed_data = pd.concat([data, df_rand], ignore_index=True)
    elif ptb_type == PerturbationType.ReplacementLinear:
        df_linear = generate_linear_according_df(
            n // 20, m, data, task_type, target_col
        )
        perturbed_data = random_replace_rows(data, df_linear)
    elif ptb_type == PerturbationType.ReplacementRand:
        df_rand = generate_random_according_df(n // 20, m, data, task_type, target_col)
        perturbed_data = random_replace_rows(data, df_rand)
    else:
        raise ValueError(f"Unknown perturbation type: {ptb_type}")

    return dcc_diff_features(data, perturbed_data, target_col, eps=eps, corr_func=corr_func), perturbed_data

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import r2_score, accuracy_score
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from joblib import Parallel, delayed
import shap

dataset_dir = Path("processed_data")
datasets = list(dataset_dir.glob("*.csv"))
dataset_config = {
    "Bala_classification_dataset.csv": {
        "target_col": "Formability",
        "type": "classification",
    },
    "Bala_regression_dataset.csv": {
        "target_col": "Ferroelectric_Tc_in_Kelvin",
        "type": "regression",
    },
    "bandgap.csv": {
        "target_col": "target",
        "type": "regression",
    },
    "BMDS_data.csv": {
        "target_col": "soc_bandgap",
        "type": "regression",
    },
    "Crystal_structure.csv": {
        "target_col": "Lowest distortion",
        "type": "classification",
    },
    "Glass.csv": {
        "target_col": "Type of glass",
        "type": "classification",
    },
    "PUE.csv": {
        "target_col": "logYM",
        "type": "regression",
    },
}
def get_shap_values(df, target_col, type):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    if type == "regression":
        model = RandomForestRegressor(n_estimators=500, random_state=42)
    elif type == "classification":
        model = RandomForestClassifier(n_estimators=500, random_state=42)
    else:
        raise ValueError("type must be either 'regression' or 'classification'")
    model.fit(X, y)

    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X)
    # shap.summary_plot(shap_values, X, plot_type="bar")
    if type == "classification":
        # For classification, shap_values is a list of arrays, one for each class
        # We take the mean absolute value across all classes
        mean_abs_shap = np.mean(np.mean(np.abs(shap_values), axis=0), axis=1)
    else:
        mean_abs_shap = np.mean(np.abs(shap_values), axis=0)
    # print(f"Mean absolute SHAP values: {mean_abs_shap}")
    feats2shap = {col: mean_abs_shap[i] for i, col in enumerate(X.columns)}
    return feats2shap

# %%
results = defaultdict(dict)

dataset_dir = Path("processed_data")
for d in dataset_dir.glob("*.csv"):
    print(d.name)
    df = pd.read_csv(d)
    target_col = dataset_config[d.name]["target_col"]
    task_type = dataset_config[d.name]["type"]
    feats2shap = get_shap_values(df, target_col, task_type)
    results[d.name]["ori_feats2shap"] = feats2shap
    results[d.name]["name"] = dataset2name[d.name]
    results[d.name]["type"] = task_type
    results[d.name]["target_col"] = target_col

    results[d.name][PerturbationType.Deletion.value] = {}
    results[d.name][PerturbationType.AdditionLinear.value] = {}
    results[d.name][PerturbationType.AdditionRand.value] = {}
    results[d.name][PerturbationType.ReplacementLinear.value] = {}
    results[d.name][PerturbationType.ReplacementRand.value] = {}


    for ptb_type in PerturbationType:
        print(f"Perturbation type: {ptb_type.value}")
        dcc_val, perturbed_df = dcc_exp(df, ptb_type,task_type, target_col,ratio=0.1, eps=0.04)
        feats2shap = get_shap_values(perturbed_df, target_col, task_type)
        results[d.name][ptb_type.value]["dcc"] = dcc_val
        results[d.name][ptb_type.value]["feats2shap"] = feats2shap
# Out:
# Bala_classification_dataset.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# Bala_regression_dataset.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# bandgap.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# BMDS_data.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# Crystal_structure.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# Glass.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand
# PUE.csv
# Perturbation type: Deletion
# Perturbation type: AdditionLinear
# Perturbation type: AdditionRand
# Perturbation type: ReplacementLinear
# Perturbation type: ReplacementRand

# %%
results
# Out:
# defaultdict(dict,
#             {'Bala_classification_dataset.csv': {'ori_feats2shap': {'Compound': 0.03134094185329982,
#                'x(BiMe1Me2)O3': 0.03253681248549997,
#                'Me1': 0.03877389122758503,
#                'Me2': 0.03135248369332674,
#                'frac-Me1': 0.010455383934140304,
#                'frac-Me2': 0.012826707669024998,
#                'frac-Me3': 0.0014052899024165804,
#                'PT-content': 0.03145345210691547,
#                'Tolerance_Factor': 0.057509877941759366,
#                'Valence_Electron_Number': 0.022618344283104205,
#                'Martynov_Batsanov_Electronegativity': 0.05540413959655249,
#                'Ideal_Bond_Length_Sum': 0.03186445153895874,
#                'Mendeleev_Number': 0.0964075149296759},
#               'name': 'Bala Classification',
#               'type': 'classification',
#               'target_col': 'Formability',
#               'Deletion': {'dcc': {'Compound': 0.6428571428571429,
#                 'x(BiMe1Me2)O3': 0.7857142857142857,
#                 'Me1': 0.6428571428571429,
#                 'Me2': 0.35714285714285715,
#                 'frac-Me1': 0.6428571428571429,
#                 'frac-Me2': 0.42857142857142855,
#                 'frac-Me3': 0.7142857142857143,
#                 'PT-content': 0.7857142857142857,
#                 'Tolerance_Factor': 0.7857142857142857,
#                 'Valence_Electron_Number': 0.6428571428571429,
#                 'Martynov_Batsanov_Electronegativity': 0.5714285714285714,
#                 'Ideal_Bond_Length_Sum': 0.5714285714285714,
#                 'Mendeleev_Number': 0.5},
#                'feats2shap': {'Compound': 0.033517656933908443,
#                 'x(BiMe1Me2)O3': 0.026866350895225547,
#                 'Me1': 0.042658340318095345,
#                 'Me2': 0.026995748372673135,
#                 'frac-Me1': 0.010133439704339376,
#                 'frac-Me2': 0.010291424424433936,
#                 'frac-Me3': 0.0009665679408935992,
#                 'PT-content': 0.029120689183255836,
#                 'Tolerance_Factor': 0.05066038292786182,
#                 'Valence_Electron_Number': 0.023905058128641604,
#                 'Martynov_Batsanov_Electronegativity': 0.06450746430073478,
#                 'Ideal_Bond_Length_Sum': 0.03152836513802734,
#                 'Mendeleev_Number': 0.09787048559355582}},
#               'AdditionLinear': {'dcc': {'Compound': 0.7142857142857143,
#                 'x(BiMe1Me2)O3': 0.42857142857142855,
#                 'Me1': 0.42857142857142855,
#                 'Me2': 0.6428571428571429,
#                 'frac-Me1': 0.21428571428571427,
#                 'frac-Me2': 0.35714285714285715,
#                 'frac-Me3': 0.21428571428571427,
#                 'PT-content': 0.35714285714285715,
#                 'Tolerance_Factor': 0.35714285714285715,
#                 'Valence_Electron_Number': 0.35714285714285715,
#                 'Martynov_Batsanov_Electronegativity': 0.42857142857142855,
#                 'Ideal_Bond_Length_Sum': 0.42857142857142855,
#                 'Mendeleev_Number': 0.5714285714285714},
#                'feats2shap': {'Compound': 0.03022055322778982,
#                 'x(BiMe1Me2)O3': 0.043316701500888274,
#                 'Me1': 0.043658567717199975,
#                 'Me2': 0.03286489940515389,
#                 'frac-Me1': 0.009293024093798537,
#                 'frac-Me2': 0.013101624689919197,
#                 'frac-Me3': 0.0018561297918639101,
#                 'PT-content': 0.03327328153984393,
#                 'Tolerance_Factor': 0.04623847310464392,
#                 'Valence_Electron_Number': 0.02298601591444748,
#                 'Martynov_Batsanov_Electronegativity': 0.04209818228051446,
#                 'Ideal_Bond_Length_Sum': 0.03393429869311795,
#                 'Mendeleev_Number': 0.09972272144694766}},
#               'AdditionRand': {'dcc': {'Compound': 0.6428571428571429,
#                 'x(BiMe1Me2)O3': 0.5,
#                 'Me1': 0.21428571428571427,
#                 'Me2': 0.7857142857142857,
#                 'frac-Me1': 0.5,
#                 'frac-Me2': 0.5,
#                 'frac-Me3': 0.35714285714285715,
#                 'PT-content': 0.35714285714285715,
#                 'Tolerance_Factor': 0.21428571428571427,
#                 'Valence_Electron_Number': 0.5,
#                 'Martynov_Batsanov_Electronegativity': 0.6428571428571429,
#                 'Ideal_Bond_Length_Sum': 0.35714285714285715,
#                 'Mendeleev_Number': 0.35714285714285715},
#                'feats2shap': {'Compound': 0.0323989256024947,
#                 'x(BiMe1Me2)O3': 0.0294709017714744,
#                 'Me1': 0.0423319043518517,
#                 'Me2': 0.03338239698799714,
#                 'frac-Me1': 0.009231872258677047,
#                 'frac-Me2': 0.012209001176274098,
#                 'frac-Me3': 0.0016356906988158606,
#                 'PT-content': 0.03068792302712542,
#                 'Tolerance_Factor': 0.057679248018890544,
#                 'Valence_Electron_Number': 0.01961705845849955,
#                 'Martynov_Batsanov_Electronegativity': 0.053680690972184544,
#                 'Ideal_Bond_Length_Sum': 0.03363725036790906,
#                 'Mendeleev_Number': 0.08796230736114583}},
#               'ReplacementLinear': {'dcc': {'Compound': 0.5714285714285714,
#                 'x(BiMe1Me2)O3': 0.2857142857142857,
#                 'Me1': 0.35714285714285715,
#                 'Me2': 0.6428571428571429,
#                 'frac-Me1': 0.2857142857142857,
#                 'frac-Me2': 0.42857142857142855,
#                 'frac-Me3': 0.2857142857142857,
#                 'PT-content': 0.2857142857142857,
#                 'Tolerance_Factor': 0.42857142857142855,
#                 'Valence_Electron_Number': 0.42857142857142855,
#                 'Martynov_Batsanov_Electronegativity': 0.2857142857142857,
#                 'Ideal_Bond_Length_Sum': 0.6428571428571429,
#                 'Mendeleev_Number': 0.5714285714285714},
#                'feats2shap': {'Compound': 0.031474444100499765,
#                 'x(BiMe1Me2)O3': 0.03803725983530302,
#                 'Me1': 0.041430824682360964,
#                 'Me2': 0.031227415321724766,
#                 'frac-Me1': 0.011766221641678327,
#                 'frac-Me2': 0.013130403514810762,
#                 'frac-Me3': 0.0014936679037280444,
#                 'PT-content': 0.02894254525203705,
#                 'Tolerance_Factor': 0.050781338565253215,
#                 'Valence_Electron_Number': 0.025584762370265572,
#                 'Martynov_Batsanov_Electronegativity': 0.05024639089979388,
#                 'Ideal_Bond_Length_Sum': 0.028870348034839968,
#                 'Mendeleev_Number': 0.10212013033049189}},
#               'ReplacementRand': {'dcc': {'Compound': 0.7142857142857143,
#                 'x(BiMe1Me2)O3': 0.35714285714285715,
#                 'Me1': 0.5714285714285714,
#                 'Me2': 0.8571428571428571,
#                 'frac-Me1': 0.42857142857142855,
#                 'frac-Me2': 0.6428571428571429,
#                 'frac-Me3': 0.35714285714285715,
#                 'PT-content': 0.35714285714285715,
#                 'Tolerance_Factor': 0.6428571428571429,
#                 'Valence_Electron_Number': 0.42857142857142855,
#                 'Martynov_Batsanov_Electronegativity': 0.5,
#                 'Ideal_Bond_Length_Sum': 0.42857142857142855,
#                 'Mendeleev_Number': 0.42857142857142855},
#                'feats2shap': {'Compound': 0.029491393396971953,
#                 'x(BiMe1Me2)O3': 0.021933746732286957,
#                 'Me1': 0.03573129122151374,
#                 'Me2': 0.035137916288045176,
#                 'frac-Me1': 0.010501566135442677,
#                 'frac-Me2': 0.01301298455547939,
#                 'frac-Me3': 0.0016862379098106287,
#                 'PT-content': 0.04918094352446667,
#                 'Tolerance_Factor': 0.04841903554129742,
#                 'Valence_Electron_Number': 0.020154281958859772,
#                 'Martynov_Batsanov_Electronegativity': 0.05626780662351458,
#                 'Ideal_Bond_Length_Sum': 0.031156190497321188,
#                 'Mendeleev_Number': 0.09798294959658552}}},
#              'Bala_regression_dataset.csv': {'ori_feats2shap': {'Compound': 20.60837120403372,
#                'xBi(Me1Me2)O3': 7.275054606853217,
#                'xPT': 5.9968442030385996,
#                'Tolerance_Factor': 4.654389571341294,
#                'Ionic_Displacements': 39.4761867419901},
#               'name': 'Bala Regression',
#               'type': 'regression',
#               'target_col': 'Ferroelectric_Tc_in_Kelvin',
#               'Deletion': {'dcc': {'Compound': 1.0,
#                 'xBi(Me1Me2)O3': 0.6666666666666666,
#                 'xPT': 0.6666666666666666,
#                 'Tolerance_Factor': 0.8333333333333334,
#                 'Ionic_Displacements': 0.3333333333333333},
#                'feats2shap': {'Compound': 17.78995002353839,
#                 'xBi(Me1Me2)O3': 5.960133103428065,
#                 'xPT': 6.546317704283488,
#                 'Tolerance_Factor': 4.646907973954259,
#                 'Ionic_Displacements': 43.80306723636768}},
#               'AdditionLinear': {'dcc': {'Compound': 0.3333333333333333,
#                 'xBi(Me1Me2)O3': 0.5,
#                 'xPT': 0.3333333333333333,
#                 'Tolerance_Factor': 0.16666666666666666,
#                 'Ionic_Displacements': 0.3333333333333333},
#                'feats2shap': {'Compound': 19.23700290851543,
#                 'xBi(Me1Me2)O3': 6.194661581790523,
#                 'xPT': 9.12748894064553,
#                 'Tolerance_Factor': 4.688599715100634,
#                 'Ionic_Displacements': 46.68988742319213}},
#               'AdditionRand': {'dcc': {'Compound': 1.0,
#                 'xBi(Me1Me2)O3': 0.8333333333333334,
#                 'xPT': 0.6666666666666666,
#                 'Tolerance_Factor': 0.5,
#                 'Ionic_Displacements': 0.3333333333333333},
#                'feats2shap': {'Compound': 21.732045636420775,
#                 'xBi(Me1Me2)O3': 7.589713622482878,
#                 'xPT': 7.59849424265557,
#                 'Tolerance_Factor': 4.654570637355388,
#                 'Ionic_Displacements': 41.970778052953875}},
#               'ReplacementLinear': {'dcc': {'Compound': 0.5,
#                 'xBi(Me1Me2)O3': 0.3333333333333333,
#                 'xPT': 0.5,
#                 'Tolerance_Factor': 0.5,
#                 'Ionic_Displacements': 0.6666666666666666},
#                'feats2shap': {'Compound': 29.47464198817763,
#                 'xBi(Me1Me2)O3': 7.311686348442236,
#                 'xPT': 4.757598882454978,
#                 'Tolerance_Factor': 6.290759725754179,
#                 'Ionic_Displacements': 41.407747549475054}},
#               'ReplacementRand': {'dcc': {'Compound': 0.5,
#                 'xBi(Me1Me2)O3': 0.6666666666666666,
#                 'xPT': 0.5,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 1.0},
#                'feats2shap': {'Compound': 16.251833852341797,
#                 'xBi(Me1Me2)O3': 11.893281796149846,
#                 'xPT': 6.738306022818705,
#                 'Tolerance_Factor': 6.619341540456568,
#                 'Ionic_Displacements': 44.91067548816813}}},
#              'bandgap.csv': {'ori_feats2shap': {'avg_Density_(g/mL)': 0.38674949881126536,
#                'avg_Gordy_electonegativity': 0.11261082103418422,
#                'avg_Number_of_unfilled_d_valence_electrons': 0.039607106645460466,
#                'avg_abs_valence': 0.13361051966235904,
#                'avg_metallic_valence': 0.5456738027324444,
#                'avg_valence_d': 0.03745260536705348,
#                'sum_Density_(g/mL)': 0.035575623016375756,
#                'sum_heat_atomization(kJ/mol)': 0.0830820232385413,
#                'sum_valence_d': 0.07971885553369128,
#                'range_Density_(g/mL)': 0.04064611087913789,
#                'range_Nagle_electonegativity': 0.11111177320401179,
#                'range_heat_of_fusion_(kJ/mol)_': 0.08018168562426807},
#               'name': 'Bandgap',
#               'type': 'regression',
#               'target_col': 'target',
#               'Deletion': {'dcc': {'avg_Density_(g/mL)': 1.0,
#                 'avg_Gordy_electonegativity': 1.0,
#                 'avg_Number_of_unfilled_d_valence_electrons': 1.0,
#                 'avg_abs_valence': 1.0,
#                 'avg_metallic_valence': 1.0,
#                 'avg_valence_d': 1.0,
#                 'sum_Density_(g/mL)': 1.0,
#                 'sum_heat_atomization(kJ/mol)': 1.0,
#                 'sum_valence_d': 1.0,
#                 'range_Density_(g/mL)': 1.0,
#                 'range_Nagle_electonegativity': 1.0,
#                 'range_heat_of_fusion_(kJ/mol)_': 1.0},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3822185550504754,
#                 'avg_Gordy_electonegativity': 0.11937439471170468,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.034589232426453696,
#                 'avg_abs_valence': 0.12855991486167503,
#                 'avg_metallic_valence': 0.5387725113024064,
#                 'avg_valence_d': 0.03628646409222577,
#                 'sum_Density_(g/mL)': 0.03878731794526063,
#                 'sum_heat_atomization(kJ/mol)': 0.08273826513298965,
#                 'sum_valence_d': 0.07328354579884963,
#                 'range_Density_(g/mL)': 0.03819208777432057,
#                 'range_Nagle_electonegativity': 0.11678246725205298,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.08175699660249258}},
#               'AdditionLinear': {'dcc': {'avg_Density_(g/mL)': 0.38461538461538464,
#                 'avg_Gordy_electonegativity': 0.46153846153846156,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.46153846153846156,
#                 'avg_abs_valence': 0.6923076923076923,
#                 'avg_metallic_valence': 0.46153846153846156,
#                 'avg_valence_d': 0.38461538461538464,
#                 'sum_Density_(g/mL)': 0.3076923076923077,
#                 'sum_heat_atomization(kJ/mol)': 0.23076923076923078,
#                 'sum_valence_d': 0.3076923076923077,
#                 'range_Density_(g/mL)': 0.46153846153846156,
#                 'range_Nagle_electonegativity': 0.38461538461538464,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.15384615384615385},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3562799087136445,
#                 'avg_Gordy_electonegativity': 0.11582142911111741,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.025165856002953856,
#                 'avg_abs_valence': 0.08991209312246348,
#                 'avg_metallic_valence': 0.15706211396094305,
#                 'avg_valence_d': 0.06032485982101824,
#                 'sum_Density_(g/mL)': 0.04255129087406314,
#                 'sum_heat_atomization(kJ/mol)': 0.16933000093887096,
#                 'sum_valence_d': 0.12456299509248944,
#                 'range_Density_(g/mL)': 0.12716613298321006,
#                 'range_Nagle_electonegativity': 0.6147219202860513,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.1217565146673304}},
#               'AdditionRand': {'dcc': {'avg_Density_(g/mL)': 0.3076923076923077,
#                 'avg_Gordy_electonegativity': 0.5384615384615384,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.38461538461538464,
#                 'avg_abs_valence': 0.6923076923076923,
#                 'avg_metallic_valence': 0.5384615384615384,
#                 'avg_valence_d': 0.46153846153846156,
#                 'sum_Density_(g/mL)': 0.46153846153846156,
#                 'sum_heat_atomization(kJ/mol)': 0.38461538461538464,
#                 'sum_valence_d': 0.5384615384615384,
#                 'range_Density_(g/mL)': 0.9230769230769231,
#                 'range_Nagle_electonegativity': 0.38461538461538464,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.46153846153846156},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3169127636534753,
#                 'avg_Gordy_electonegativity': 0.09628148204319195,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.05543771452888935,
#                 'avg_abs_valence': 0.11400754040828096,
#                 'avg_metallic_valence': 0.514334166338007,
#                 'avg_valence_d': 0.05003358911913514,
#                 'sum_Density_(g/mL)': 0.07086393713061422,
#                 'sum_heat_atomization(kJ/mol)': 0.09822264723292731,
#                 'sum_valence_d': 0.12862978197811287,
#                 'range_Density_(g/mL)': 0.0585663527253674,
#                 'range_Nagle_electonegativity': 0.20178284003420024,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.1318635254177276}},
#               'ReplacementLinear': {'dcc': {'avg_Density_(g/mL)': 0.23076923076923078,
#                 'avg_Gordy_electonegativity': 0.46153846153846156,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.38461538461538464,
#                 'avg_abs_valence': 0.23076923076923078,
#                 'avg_metallic_valence': 0.23076923076923078,
#                 'avg_valence_d': 0.38461538461538464,
#                 'sum_Density_(g/mL)': 0.15384615384615385,
#                 'sum_heat_atomization(kJ/mol)': 0.23076923076923078,
#                 'sum_valence_d': 0.23076923076923078,
#                 'range_Density_(g/mL)': 0.3076923076923077,
#                 'range_Nagle_electonegativity': 0.38461538461538464,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07692307692307693},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3325108484934074,
#                 'avg_Gordy_electonegativity': 0.14340644096757751,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.02780583441000542,
#                 'avg_abs_valence': 0.0940814269938272,
#                 'avg_metallic_valence': 0.24318340378376202,
#                 'avg_valence_d': 0.027516648861810603,
#                 'sum_Density_(g/mL)': 0.09319576626664146,
#                 'sum_heat_atomization(kJ/mol)': 0.10476026264613313,
#                 'sum_valence_d': 0.2019521064545984,
#                 'range_Density_(g/mL)': 0.11442894851443809,
#                 'range_Nagle_electonegativity': 0.4183239953317484,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.13306839239240617}},
#               'ReplacementRand': {'dcc': {'avg_Density_(g/mL)': 0.23076923076923078,
#                 'avg_Gordy_electonegativity': 0.3076923076923077,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.23076923076923078,
#                 'avg_abs_valence': 0.15384615384615385,
#                 'avg_metallic_valence': 0.46153846153846156,
#                 'avg_valence_d': 0.23076923076923078,
#                 'sum_Density_(g/mL)': 0.38461538461538464,
#                 'sum_heat_atomization(kJ/mol)': 0.23076923076923078,
#                 'sum_valence_d': 0.23076923076923078,
#                 'range_Density_(g/mL)': 0.3076923076923077,
#                 'range_Nagle_electonegativity': 0.46153846153846156,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.3076923076923077},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3969758019479689,
#                 'avg_Gordy_electonegativity': 0.0924459898443898,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.04267929319713231,
#                 'avg_abs_valence': 0.12488394422994209,
#                 'avg_metallic_valence': 0.4949109123743366,
#                 'avg_valence_d': 0.09438857785391644,
#                 'sum_Density_(g/mL)': 0.06885380359839749,
#                 'sum_heat_atomization(kJ/mol)': 0.0996247308120017,
#                 'sum_valence_d': 0.22575731205063368,
#                 'range_Density_(g/mL)': 0.0525656504036136,
#                 'range_Nagle_electonegativity': 0.19690274882632994,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.12462813992468408}}},
#              'BMDS_data.csv': {'ori_feats2shap': {'a_mono': 0.003366113320390514,
#                'a': 0.003965316024509296,
#                'b': 0.004353293532454283,
#                'DFT_energy_bi': 0.007216569231486068,
#                'magnetic_moment': 0.0,
#                'formation_energy': 0.00301907319933986,
#                'area': 0.00280292047870701,
#                'd': 0.003056690405491597,
#                'no_soc_bandgap': 0.7005548790673587,
#                'dielectric_constant': 0.00698323244332095,
#                'soc_energy': 0.04146214671132726,
#                'del_e_bilayer_bottom_and_mono': 0.0030584293119203104},
#               'name': 'BMDS',
#               'type': 'regression',
#               'target_col': 'soc_bandgap',
#               'Deletion': {'dcc': {'a_mono': 0.6153846153846154,
#                 'a': 0.6153846153846154,
#                 'b': 0.6153846153846154,
#                 'DFT_energy_bi': 0.9230769230769231,
#                 'magnetic_moment': 0.9230769230769231,
#                 'formation_energy': 1.0,
#                 'area': 0.6153846153846154,
#                 'd': 0.6923076923076923,
#                 'no_soc_bandgap': 0.6923076923076923,
#                 'dielectric_constant': 1.0,
#                 'soc_energy': 0.5384615384615384,
#                 'del_e_bilayer_bottom_and_mono': 0.6923076923076923},
#                'feats2shap': {'a_mono': 0.003660839597180405,
#                 'a': 0.004502236269130717,
#                 'b': 0.0042620155341479265,
#                 'DFT_energy_bi': 0.005221601485307654,
#                 'magnetic_moment': 0.0,
#                 'formation_energy': 0.0028195238400014274,
#                 'area': 0.0028092964902196042,
#                 'd': 0.0024452762042547313,
#                 'no_soc_bandgap': 0.6981986589685392,
#                 'dielectric_constant': 0.007680280997059157,
#                 'soc_energy': 0.035105705194850886,
#                 'del_e_bilayer_bottom_and_mono': 0.0031216609715175947}},
#               'AdditionLinear': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.38461538461538464,
#                 'b': 0.38461538461538464,
#                 'DFT_energy_bi': 0.07692307692307693,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.46153846153846156,
#                 'area': 0.15384615384615385,
#                 'd': 0.23076923076923078,
#                 'no_soc_bandgap': 0.38461538461538464,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.004289143435548923,
#                 'a': 0.008260258196006655,
#                 'b': 0.005613145213277118,
#                 'DFT_energy_bi': 0.011614456882514635,
#                 'magnetic_moment': 0.0021354332223135425,
#                 'formation_energy': 0.007176690698115669,
#                 'area': 0.012452855023280926,
#                 'd': 0.0038335776354517016,
#                 'no_soc_bandgap': 0.7822568074606266,
#                 'dielectric_constant': 0.01296463790021293,
#                 'soc_energy': 0.050818619464833306,
#                 'del_e_bilayer_bottom_and_mono': 0.02544340751489901}},
#               'AdditionRand': {'dcc': {'a_mono': 0.3076923076923077,
#                 'a': 0.38461538461538464,
#                 'b': 0.07692307692307693,
#                 'DFT_energy_bi': 0.23076923076923078,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.3076923076923077,
#                 'area': 0.07692307692307693,
#                 'd': 0.3076923076923077,
#                 'no_soc_bandgap': 0.3076923076923077,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.23076923076923078,
#                 'del_e_bilayer_bottom_and_mono': 0.15384615384615385},
#                'feats2shap': {'a_mono': 0.006106304401169701,
#                 'a': 0.0060301463228854876,
#                 'b': 0.010112715350318092,
#                 'DFT_energy_bi': 0.008951975264751067,
#                 'magnetic_moment': 0.02336615844535039,
#                 'formation_energy': 0.02499268928451826,
#                 'area': 0.015737299307791847,
#                 'd': 0.005521535322243108,
#                 'no_soc_bandgap': 0.7609565158911296,
#                 'dielectric_constant': 0.02914326930857252,
#                 'soc_energy': 0.042042555681126206,
#                 'del_e_bilayer_bottom_and_mono': 0.02282720051218011}},
#               'ReplacementLinear': {'dcc': {'a_mono': 0.3076923076923077,
#                 'a': 0.15384615384615385,
#                 'b': 0.23076923076923078,
#                 'DFT_energy_bi': 0.23076923076923078,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.38461538461538464,
#                 'area': 0.15384615384615385,
#                 'd': 0.15384615384615385,
#                 'no_soc_bandgap': 0.3076923076923077,
#                 'dielectric_constant': 0.15384615384615385,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.008407138623453757,
#                 'a': 0.008955520220959802,
#                 'b': 0.01049428670043192,
#                 'DFT_energy_bi': 0.008502474791646779,
#                 'magnetic_moment': 0.004988978433738693,
#                 'formation_energy': 0.015781253388454874,
#                 'area': 0.007773713506071885,
#                 'd': 0.005916922256569084,
#                 'no_soc_bandgap': 0.7676310139803086,
#                 'dielectric_constant': 0.06092754469777821,
#                 'soc_energy': 0.04747231216645891,
#                 'del_e_bilayer_bottom_and_mono': 0.012165826158120568}},
#               'ReplacementRand': {'dcc': {'a_mono': 0.38461538461538464,
#                 'a': 0.23076923076923078,
#                 'b': 0.23076923076923078,
#                 'DFT_energy_bi': 0.15384615384615385,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.38461538461538464,
#                 'area': 0.15384615384615385,
#                 'd': 0.23076923076923078,
#                 'no_soc_bandgap': 0.38461538461538464,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.15384615384615385,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.009768142930776517,
#                 'a': 0.007985311731188233,
#                 'b': 0.005177515185803972,
#                 'DFT_energy_bi': 0.006746118420620767,
#                 'magnetic_moment': 0.0069763126999827455,
#                 'formation_energy': 0.013554380707264455,
#                 'area': 0.016844032528164396,
#                 'd': 0.011872086910603022,
#                 'no_soc_bandgap': 0.7304451736920567,
#                 'dielectric_constant': 0.046615965665087924,
#                 'soc_energy': 0.047847554188706544,
#                 'del_e_bilayer_bottom_and_mono': 0.03669486428867764}}},
#              'Crystal_structure.csv': {'ori_feats2shap': {'v(A)': 0.00928807805117576,
#                'v(B)': 0.008590939033111613,
#                'r(AXII)(Å)': 0.014293254707227978,
#                'r(AVI)(Å)': 0.01505931174813062,
#                'r(BVI)(Å)': 0.01816361031209468,
#                'EN(A)': 0.03062920334507453,
#                'EN(B)': 0.041057098775248,
#                'l(A-O)(Å)': 0.01676954859238621,
#                'l(B-O)(Å)': 0.015547435066267122,
#                'ΔENR': 0.022561250770963527,
#                'tG': 0.03321633640362814,
#                'τ': 0.04550646279639944,
#                'μ': 0.016420558105693362},
#               'name': 'Crystal Structure',
#               'type': 'classification',
#               'target_col': 'Lowest distortion',
#               'Deletion': {'dcc': {'v(A)': 1.0,
#                 'v(B)': 1.0,
#                 'r(AXII)(Å)': 1.0,
#                 'r(AVI)(Å)': 0.9285714285714286,
#                 'r(BVI)(Å)': 1.0,
#                 'EN(A)': 0.9285714285714286,
#                 'EN(B)': 1.0,
#                 'l(A-O)(Å)': 0.9285714285714286,
#                 'l(B-O)(Å)': 1.0,
#                 'ΔENR': 1.0,
#                 'tG': 1.0,
#                 'τ': 0.9285714285714286,
#                 'μ': 1.0},
#                'feats2shap': {'v(A)': 0.00852148020059792,
#                 'v(B)': 0.008114109412602011,
#                 'r(AXII)(Å)': 0.014372128180042736,
#                 'r(AVI)(Å)': 0.01689696966249032,
#                 'r(BVI)(Å)': 0.016948940252324112,
#                 'EN(A)': 0.032179646894952736,
#                 'EN(B)': 0.039433952608909924,
#                 'l(A-O)(Å)': 0.01604704092018399,
#                 'l(B-O)(Å)': 0.013809211831225365,
#                 'ΔENR': 0.020741638889733637,
#                 'tG': 0.032953311987912605,
#                 'τ': 0.04692818174425393,
#                 'μ': 0.016779080778369253}},
#               'AdditionLinear': {'dcc': {'v(A)': 0.7142857142857143,
#                 'v(B)': 0.6428571428571429,
#                 'r(AXII)(Å)': 0.35714285714285715,
#                 'r(AVI)(Å)': 0.35714285714285715,
#                 'r(BVI)(Å)': 0.5,
#                 'EN(A)': 0.2857142857142857,
#                 'EN(B)': 0.7142857142857143,
#                 'l(A-O)(Å)': 0.5714285714285714,
#                 'l(B-O)(Å)': 0.5714285714285714,
#                 'ΔENR': 0.42857142857142855,
#                 'tG': 0.42857142857142855,
#                 'τ': 0.5,
#                 'μ': 0.35714285714285715},
#                'feats2shap': {'v(A)': 0.008852084062414238,
#                 'v(B)': 0.010115154124280734,
#                 'r(AXII)(Å)': 0.015529525763111398,
#                 'r(AVI)(Å)': 0.018739407007789977,
#                 'r(BVI)(Å)': 0.017188093804673288,
#                 'EN(A)': 0.03380811858077807,
#                 'EN(B)': 0.04051106233962738,
#                 'l(A-O)(Å)': 0.015651751184764345,
#                 'l(B-O)(Å)': 0.015485600404456797,
#                 'ΔENR': 0.02089814560671976,
#                 'tG': 0.03363732187062638,
#                 'τ': 0.042415324076373155,
#                 'μ': 0.018516760067995876}},
#               'AdditionRand': {'dcc': {'v(A)': 0.5714285714285714,
#                 'v(B)': 0.5714285714285714,
#                 'r(AXII)(Å)': 0.5,
#                 'r(AVI)(Å)': 0.5714285714285714,
#                 'r(BVI)(Å)': 0.42857142857142855,
#                 'EN(A)': 0.21428571428571427,
#                 'EN(B)': 0.6428571428571429,
#                 'l(A-O)(Å)': 0.5,
#                 'l(B-O)(Å)': 0.5,
#                 'ΔENR': 0.6428571428571429,
#                 'tG': 0.42857142857142855,
#                 'τ': 0.5714285714285714,
#                 'μ': 0.6428571428571429},
#                'feats2shap': {'v(A)': 0.009807461229704401,
#                 'v(B)': 0.011741555125314815,
#                 'r(AXII)(Å)': 0.015600911435392975,
#                 'r(AVI)(Å)': 0.016966590189813363,
#                 'r(BVI)(Å)': 0.017556984885762995,
#                 'EN(A)': 0.03029521997654311,
#                 'EN(B)': 0.037172447623147704,
#                 'l(A-O)(Å)': 0.017505036193135228,
#                 'l(B-O)(Å)': 0.014296154021949966,
#                 'ΔENR': 0.02167546527585715,
#                 'tG': 0.02996303531057496,
#                 'τ': 0.044295830288600194,
#                 'μ': 0.019415354047052646}},
#               'ReplacementLinear': {'dcc': {'v(A)': 0.35714285714285715,
#                 'v(B)': 0.42857142857142855,
#                 'r(AXII)(Å)': 0.42857142857142855,
#                 'r(AVI)(Å)': 0.5,
#                 'r(BVI)(Å)': 0.5714285714285714,
#                 'EN(A)': 0.5714285714285714,
#                 'EN(B)': 0.6428571428571429,
#                 'l(A-O)(Å)': 0.42857142857142855,
#                 'l(B-O)(Å)': 0.7142857142857143,
#                 'ΔENR': 0.35714285714285715,
#                 'tG': 0.5714285714285714,
#                 'τ': 0.42857142857142855,
#                 'μ': 0.5714285714285714},
#                'feats2shap': {'v(A)': 0.00937773673024605,
#                 'v(B)': 0.009515634435694467,
#                 'r(AXII)(Å)': 0.013242333573481521,
#                 'r(AVI)(Å)': 0.018741790180441368,
#                 'r(BVI)(Å)': 0.0222084987935467,
#                 'EN(A)': 0.03388568653278934,
#                 'EN(B)': 0.03581795446745039,
#                 'l(A-O)(Å)': 0.017034514612887935,
#                 'l(B-O)(Å)': 0.014669587970837051,
#                 'ΔENR': 0.023041655190272955,
#                 'tG': 0.0345350304739084,
#                 'τ': 0.044550714566577033,
#                 'μ': 0.014937292830720887}},
#               'ReplacementRand': {'dcc': {'v(A)': 0.5,
#                 'v(B)': 0.6428571428571429,
#                 'r(AXII)(Å)': 0.5,
#                 'r(AVI)(Å)': 0.5714285714285714,
#                 'r(BVI)(Å)': 0.7142857142857143,
#                 'EN(A)': 0.5,
#                 'EN(B)': 0.8571428571428571,
#                 'l(A-O)(Å)': 0.5,
#                 'l(B-O)(Å)': 0.35714285714285715,
#                 'ΔENR': 0.5,
#                 'tG': 0.42857142857142855,
#                 'τ': 0.42857142857142855,
#                 'μ': 0.5714285714285714},
#                'feats2shap': {'v(A)': 0.012900031004366572,
#                 'v(B)': 0.008582918759092941,
#                 'r(AXII)(Å)': 0.013779882752754099,
#                 'r(AVI)(Å)': 0.016317520583576762,
#                 'r(BVI)(Å)': 0.01935657738721506,
#                 'EN(A)': 0.030432199281862554,
#                 'EN(B)': 0.03572279826437676,
#                 'l(A-O)(Å)': 0.01742115728719097,
#                 'l(B-O)(Å)': 0.014857071496426275,
#                 'ΔENR': 0.02519177775860246,
#                 'tG': 0.03195975186128303,
#                 'τ': 0.043719241354260446,
#                 'μ': 0.016043010498876135}}},
#              'Glass.csv': {'ori_feats2shap': {'RI': 0.037859991545018706,
#                'Na': 0.025386526591311877,
#                'Mg': 0.058506488488587395,
#                'Al': 0.050366751947213295,
#                'Si': 0.014770640346268021,
#                'K': 0.020324243126125522,
#                'Ca': 0.031106733133963962,
#                'Ba': 0.032559546525034226,
#                'Fe': 0.008634754652686791},
#               'name': 'Glass',
#               'type': 'classification',
#               'target_col': 'Type of glass',
#               'Deletion': {'dcc': {'RI': 0.7,
#                 'Na': 0.8,
#                 'Mg': 0.5,
#                 'Al': 0.5,
#                 'Si': 0.4,
#                 'K': 0.3,
#                 'Ca': 0.9,
#                 'Ba': 0.5,
#                 'Fe': 0.4},
#                'feats2shap': {'RI': 0.033188937162155124,
#                 'Na': 0.02625616795511972,
#                 'Mg': 0.058132839461599826,
#                 'Al': 0.053364939145103284,
#                 'Si': 0.015495627980867226,
#                 'K': 0.021321564584769182,
#                 'Ca': 0.029501764279697643,
#                 'Ba': 0.03469712137469943,
#                 'Fe': 0.008996850277645477}},
#               'AdditionLinear': {'dcc': {'RI': 0.2,
#                 'Na': 0.6,
#                 'Mg': 0.5,
#                 'Al': 0.4,
#                 'Si': 0.4,
#                 'K': 0.3,
#                 'Ca': 0.3,
#                 'Ba': 0.4,
#                 'Fe': 0.4},
#                'feats2shap': {'RI': 0.03663471417963698,
#                 'Na': 0.03009662024370331,
#                 'Mg': 0.05958415311041503,
#                 'Al': 0.04832084093658994,
#                 'Si': 0.014091735539010294,
#                 'K': 0.02000549330268315,
#                 'Ca': 0.031128438822892623,
#                 'Ba': 0.0281698383761865,
#                 'Fe': 0.009673430269251859}},
#               'AdditionRand': {'dcc': {'RI': 0.1,
#                 'Na': 0.2,
#                 'Mg': 0.2,
#                 'Al': 0.4,
#                 'Si': 0.4,
#                 'K': 0.3,
#                 'Ca': 0.3,
#                 'Ba': 0.2,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.03732760264756417,
#                 'Na': 0.026236340854922376,
#                 'Mg': 0.062136410185348045,
#                 'Al': 0.049493281183046904,
#                 'Si': 0.014648224701657027,
#                 'K': 0.019299835580669677,
#                 'Ca': 0.030357330442766377,
#                 'Ba': 0.02948796414536924,
#                 'Fe': 0.009377520422386598}},
#               'ReplacementLinear': {'dcc': {'RI': 0.2,
#                 'Na': 0.3,
#                 'Mg': 0.5,
#                 'Al': 0.4,
#                 'Si': 0.5,
#                 'K': 0.4,
#                 'Ca': 0.6,
#                 'Ba': 0.4,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.0373242458833268,
#                 'Na': 0.025741519350446513,
#                 'Mg': 0.06522450953752668,
#                 'Al': 0.04618853779617529,
#                 'Si': 0.01559316447131337,
#                 'K': 0.020723059120661854,
#                 'Ca': 0.027354487867688817,
#                 'Ba': 0.028285675386546232,
#                 'Fe': 0.009277614136421631}},
#               'ReplacementRand': {'dcc': {'RI': 0.2,
#                 'Na': 0.4,
#                 'Mg': 0.3,
#                 'Al': 0.4,
#                 'Si': 0.4,
#                 'K': 0.3,
#                 'Ca': 0.5,
#                 'Ba': 0.4,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.0330841330124917,
#                 'Na': 0.02395439333646422,
#                 'Mg': 0.05999142293339215,
#                 'Al': 0.04932604737732424,
#                 'Si': 0.014517433837539917,
#                 'K': 0.019337244818590317,
#                 'Ca': 0.031453775087613677,
#                 'Ba': 0.03284518794726335,
#                 'Fe': 0.008365645642235632}}},
#              'PUE.csv': {'ori_feats2shap': {'ZS_CHS': 0.07208610019768472,
#                'ZS_R': 0.013958132892156003,
#                'ZS_log_Tr1K': 0.006903631445503145,
#                'ZS_log_Tr2K': 0.00881557172441453,
#                'PMStep': 0.0007424758525061988,
#                'Form_Method': 0.0010502969507552012,
#                'ZS_log_CSArea': 0.00702946402506858,
#                'ZS_log_StrainRate': 0.013377728425863274,
#                'ZS_log_PO_MW': 0.06258830317076215,
#                'ZS_log_FCVm': 0.13645203544301585,
#                'ZS_FCCED': 0.07534204358060362,
#                'ZS_log_Fchi': 0.01264861167444042,
#                'ZS_SS_TPSA_norm': 0.015052753265992917,
#                'ZS_SS_MolLogP_norm': 0.011297945684567195,
#                'ZS_HS_BertzCT': 0.030223438658344048,
#                'ZS_SS_VSA_EState8': 0.050845734315427764,
#                'ZS_SS_PEOE_VSA8': 0.012340758037346597,
#                'ZS_log_HS_NumNHCO_norm': 0.015389459071923515,
#                'ZS_FC_NumHAcceptors_norm': 0.017376917536886416,
#                'ZS_FC_RingCount_norm': 0.06483405605254663},
#               'name': 'PUE',
#               'type': 'regression',
#               'target_col': 'logYM',
#               'Deletion': {'dcc': {'ZS_CHS': 0.6190476190476191,
#                 'ZS_R': 0.8571428571428571,
#                 'ZS_log_Tr1K': 0.6666666666666666,
#                 'ZS_log_Tr2K': 0.9047619047619048,
#                 'PMStep': 0.8095238095238095,
#                 'Form_Method': 0.8571428571428571,
#                 'ZS_log_CSArea': 0.42857142857142855,
#                 'ZS_log_StrainRate': 0.8095238095238095,
#                 'ZS_log_PO_MW': 0.7619047619047619,
#                 'ZS_log_FCVm': 0.6666666666666666,
#                 'ZS_FCCED': 0.5714285714285714,
#                 'ZS_log_Fchi': 0.6666666666666666,
#                 'ZS_SS_TPSA_norm': 0.6666666666666666,
#                 'ZS_SS_MolLogP_norm': 0.5238095238095238,
#                 'ZS_HS_BertzCT': 0.6666666666666666,
#                 'ZS_SS_VSA_EState8': 0.42857142857142855,
#                 'ZS_SS_PEOE_VSA8': 0.47619047619047616,
#                 'ZS_log_HS_NumNHCO_norm': 0.47619047619047616,
#                 'ZS_FC_NumHAcceptors_norm': 0.7142857142857143,
#                 'ZS_FC_RingCount_norm': 0.8095238095238095},
#                'feats2shap': {'ZS_CHS': 0.07375956003594454,
#                 'ZS_R': 0.012611434407544453,
#                 'ZS_log_Tr1K': 0.005400504919452204,
#                 'ZS_log_Tr2K': 0.004217719360969881,
#                 'PMStep': 0.0009136786446696674,
#                 'Form_Method': 0.0012059828693440759,
#                 'ZS_log_CSArea': 0.006013438908219755,
#                 'ZS_log_StrainRate': 0.010051179453535111,
#                 'ZS_log_PO_MW': 0.06504000898278285,
#                 'ZS_log_FCVm': 0.1235230165381517,
#                 'ZS_FCCED': 0.05707944765847244,
#                 'ZS_log_Fchi': 0.015324756181228756,
#                 'ZS_SS_TPSA_norm': 0.012663014809360076,
#                 'ZS_SS_MolLogP_norm': 0.013255438107182747,
#                 'ZS_HS_BertzCT': 0.03759337178624037,
#                 'ZS_SS_VSA_EState8': 0.049477600558126944,
#                 'ZS_SS_PEOE_VSA8': 0.011256787732382633,
#                 'ZS_log_HS_NumNHCO_norm': 0.012849946839141107,
#                 'ZS_FC_NumHAcceptors_norm': 0.017452223122182028,
#                 'ZS_FC_RingCount_norm': 0.0550209039650677}},
#               'AdditionLinear': {'dcc': {'ZS_CHS': 0.38095238095238093,
#                 'ZS_R': 0.6190476190476191,
#                 'ZS_log_Tr1K': 0.47619047619047616,
#                 'ZS_log_Tr2K': 0.38095238095238093,
#                 'PMStep': 0.7142857142857143,
#                 'Form_Method': 0.47619047619047616,
#                 'ZS_log_CSArea': 0.42857142857142855,
#                 'ZS_log_StrainRate': 0.7142857142857143,
#                 'ZS_log_PO_MW': 0.5714285714285714,
#                 'ZS_log_FCVm': 0.5238095238095238,
#                 'ZS_FCCED': 0.42857142857142855,
#                 'ZS_log_Fchi': 0.3333333333333333,
#                 'ZS_SS_TPSA_norm': 0.38095238095238093,
#                 'ZS_SS_MolLogP_norm': 0.3333333333333333,
#                 'ZS_HS_BertzCT': 0.7142857142857143,
#                 'ZS_SS_VSA_EState8': 0.3333333333333333,
#                 'ZS_SS_PEOE_VSA8': 0.8571428571428571,
#                 'ZS_log_HS_NumNHCO_norm': 0.3333333333333333,
#                 'ZS_FC_NumHAcceptors_norm': 0.2857142857142857,
#                 'ZS_FC_RingCount_norm': 0.8095238095238095},
#                'feats2shap': {'ZS_CHS': 0.09836477435392701,
#                 'ZS_R': 0.015582394799682252,
#                 'ZS_log_Tr1K': 0.006155791833211572,
#                 'ZS_log_Tr2K': 0.00892098035647866,
#                 'PMStep': 0.001490635523212113,
#                 'Form_Method': 0.0012124287623132325,
#                 'ZS_log_CSArea': 0.006071758750008501,
#                 'ZS_log_StrainRate': 0.0109106983558331,
#                 'ZS_log_PO_MW': 0.03961382683423885,
#                 'ZS_log_FCVm': 0.07206868943686484,
#                 'ZS_FCCED': 0.147481650749589,
#                 'ZS_log_Fchi': 0.02164877088645111,
#                 'ZS_SS_TPSA_norm': 0.019755564298216885,
#                 'ZS_SS_MolLogP_norm': 0.026753141155246227,
#                 'ZS_HS_BertzCT': 0.05603350989421714,
#                 'ZS_SS_VSA_EState8': 0.05754483143101657,
#                 'ZS_SS_PEOE_VSA8': 0.007842580019427338,
#                 'ZS_log_HS_NumNHCO_norm': 0.015113551680574008,
#                 'ZS_FC_NumHAcceptors_norm': 0.013728535276499474,
#                 'ZS_FC_RingCount_norm': 0.031025832026004615}},
#               'AdditionRand': {'dcc': {'ZS_CHS': 0.3333333333333333,
#                 'ZS_R': 0.6190476190476191,
#                 'ZS_log_Tr1K': 0.38095238095238093,
#                 'ZS_log_Tr2K': 0.5238095238095238,
#                 'PMStep': 0.7619047619047619,
#                 'Form_Method': 0.6666666666666666,
#                 'ZS_log_CSArea': 0.47619047619047616,
#                 'ZS_log_StrainRate': 0.5238095238095238,
#                 'ZS_log_PO_MW': 0.47619047619047616,
#                 'ZS_log_FCVm': 0.42857142857142855,
#                 'ZS_FCCED': 0.42857142857142855,
#                 'ZS_log_Fchi': 0.19047619047619047,
#                 'ZS_SS_TPSA_norm': 0.42857142857142855,
#                 'ZS_SS_MolLogP_norm': 0.38095238095238093,
#                 'ZS_HS_BertzCT': 0.38095238095238093,
#                 'ZS_SS_VSA_EState8': 0.47619047619047616,
#                 'ZS_SS_PEOE_VSA8': 0.7619047619047619,
#                 'ZS_log_HS_NumNHCO_norm': 0.23809523809523808,
#                 'ZS_FC_NumHAcceptors_norm': 0.23809523809523808,
#                 'ZS_FC_RingCount_norm': 0.7619047619047619},
#                'feats2shap': {'ZS_CHS': 0.05815495495362814,
#                 'ZS_R': 0.017563132345258702,
#                 'ZS_log_Tr1K': 0.0069510931722255535,
#                 'ZS_log_Tr2K': 0.010876815873454428,
#                 'PMStep': 0.0020251780617110667,
#                 'Form_Method': 0.0019526594222835367,
#                 'ZS_log_CSArea': 0.004836125286264192,
#                 'ZS_log_StrainRate': 0.011759739776608907,
#                 'ZS_log_PO_MW': 0.03908781590028663,
#                 'ZS_log_FCVm': 0.14740575778240167,
#                 'ZS_FCCED': 0.051464227023617935,
#                 'ZS_log_Fchi': 0.011581385752699134,
#                 'ZS_SS_TPSA_norm': 0.015571988483378395,
#                 'ZS_SS_MolLogP_norm': 0.016541739896001526,
#                 'ZS_HS_BertzCT': 0.03619211949207246,
#                 'ZS_SS_VSA_EState8': 0.09905603304612176,
#                 'ZS_SS_PEOE_VSA8': 0.010022631604292603,
#                 'ZS_log_HS_NumNHCO_norm': 0.013863958672813382,
#                 'ZS_FC_NumHAcceptors_norm': 0.01822307395472775,
#                 'ZS_FC_RingCount_norm': 0.051102714046307444}},
#               'ReplacementLinear': {'dcc': {'ZS_CHS': 0.23809523809523808,
#                 'ZS_R': 0.19047619047619047,
#                 'ZS_log_Tr1K': 0.2857142857142857,
#                 'ZS_log_Tr2K': 0.2857142857142857,
#                 'PMStep': 0.5238095238095238,
#                 'Form_Method': 0.3333333333333333,
#                 'ZS_log_CSArea': 0.2857142857142857,
#                 'ZS_log_StrainRate': 0.6666666666666666,
#                 'ZS_log_PO_MW': 0.14285714285714285,
#                 'ZS_log_FCVm': 0.38095238095238093,
#                 'ZS_FCCED': 0.3333333333333333,
#                 'ZS_log_Fchi': 0.19047619047619047,
#                 'ZS_SS_TPSA_norm': 0.3333333333333333,
#                 'ZS_SS_MolLogP_norm': 0.38095238095238093,
#                 'ZS_HS_BertzCT': 0.2857142857142857,
#                 'ZS_SS_VSA_EState8': 0.3333333333333333,
#                 'ZS_SS_PEOE_VSA8': 0.7142857142857143,
#                 'ZS_log_HS_NumNHCO_norm': 0.2857142857142857,
#                 'ZS_FC_NumHAcceptors_norm': 0.7142857142857143,
#                 'ZS_FC_RingCount_norm': 0.38095238095238093},
#                'feats2shap': {'ZS_CHS': 0.05489123568219731,
#                 'ZS_R': 0.013288851603623988,
#                 'ZS_log_Tr1K': 0.0072095494920921405,
#                 'ZS_log_Tr2K': 0.009204432477500147,
#                 'PMStep': 0.001265917238028908,
#                 'Form_Method': 0.0011174129693387502,
#                 'ZS_log_CSArea': 0.0076661931960570005,
#                 'ZS_log_StrainRate': 0.01582844671441121,
#                 'ZS_log_PO_MW': 0.031496834588182754,
#                 'ZS_log_FCVm': 0.16057320873702102,
#                 'ZS_FCCED': 0.06964953382188015,
#                 'ZS_log_Fchi': 0.018795824887276685,
#                 'ZS_SS_TPSA_norm': 0.01806627725417563,
#                 'ZS_SS_MolLogP_norm': 0.02020811700048651,
#                 'ZS_HS_BertzCT': 0.034143656255907484,
#                 'ZS_SS_VSA_EState8': 0.05103198132724819,
#                 'ZS_SS_PEOE_VSA8': 0.009294854677186758,
#                 'ZS_log_HS_NumNHCO_norm': 0.016882654315823312,
#                 'ZS_FC_NumHAcceptors_norm': 0.024258142740094264,
#                 'ZS_FC_RingCount_norm': 0.051416832621001024}},
#               'ReplacementRand': {'dcc': {'ZS_CHS': 0.3333333333333333,
#                 'ZS_R': 0.6666666666666666,
#                 'ZS_log_Tr1K': 0.23809523809523808,
#                 'ZS_log_Tr2K': 0.2857142857142857,
#                 'PMStep': 0.5714285714285714,
#                 'Form_Method': 0.6190476190476191,
#                 'ZS_log_CSArea': 0.3333333333333333,
#                 'ZS_log_StrainRate': 0.3333333333333333,
#                 'ZS_log_PO_MW': 0.3333333333333333,
#                 'ZS_log_FCVm': 0.38095238095238093,
#                 'ZS_FCCED': 0.19047619047619047,
#                 'ZS_log_Fchi': 0.09523809523809523,
#                 'ZS_SS_TPSA_norm': 0.2857142857142857,
#                 'ZS_SS_MolLogP_norm': 0.42857142857142855,
#                 'ZS_HS_BertzCT': 0.3333333333333333,
#                 'ZS_SS_VSA_EState8': 0.2857142857142857,
#                 'ZS_SS_PEOE_VSA8': 0.6190476190476191,
#                 'ZS_log_HS_NumNHCO_norm': 0.38095238095238093,
#                 'ZS_FC_NumHAcceptors_norm': 0.2857142857142857,
#                 'ZS_FC_RingCount_norm': 0.5714285714285714},
#                'feats2shap': {'ZS_CHS': 0.0554630105361472,
#                 'ZS_R': 0.00740796289674214,
#                 'ZS_log_Tr1K': 0.008253670174576806,
#                 'ZS_log_Tr2K': 0.0053932797297286455,
#                 'PMStep': 0.0027800401109139756,
#                 'Form_Method': 0.003631800870067804,
#                 'ZS_log_CSArea': 0.007638010373967619,
#                 'ZS_log_StrainRate': 0.014633556864128755,
#                 'ZS_log_PO_MW': 0.0910933308252096,
#                 'ZS_log_FCVm': 0.1292116571579141,
#                 'ZS_FCCED': 0.03191638459295454,
#                 'ZS_log_Fchi': 0.03421075789543984,
#                 'ZS_SS_TPSA_norm': 0.019533294317465512,
#                 'ZS_SS_MolLogP_norm': 0.014426558789625505,
#                 'ZS_HS_BertzCT': 0.03904798667520507,
#                 'ZS_SS_VSA_EState8': 0.08168839333872506,
#                 'ZS_SS_PEOE_VSA8': 0.008435860677179474,
#                 'ZS_log_HS_NumNHCO_norm': 0.018764175086559014,
#                 'ZS_FC_NumHAcceptors_norm': 0.01795376767422288,
#                 'ZS_FC_RingCount_norm': 0.05413662965152595}}}})

# %%
# save to pickle file

import pickle

with open("results/dcc_fi_results-s.pkl", "wb") as f:
    pickle.dump(results, f)

# %%
# read from pickle file
import pickle

results = {}

with open("results/dcc_fi_results-s.pkl", "rb") as f:
    results = pickle.load(f)

results
# Out:
# defaultdict(dict,
#             {'Bala_classification_dataset.csv': {'ori_feats2shap': {'Compound': 0.03134094185329982,
#                'x(BiMe1Me2)O3': 0.03253681248549997,
#                'Me1': 0.03877389122758503,
#                'Me2': 0.03135248369332674,
#                'frac-Me1': 0.010455383934140304,
#                'frac-Me2': 0.012826707669024998,
#                'frac-Me3': 0.0014052899024165804,
#                'PT-content': 0.03145345210691547,
#                'Tolerance_Factor': 0.057509877941759366,
#                'Valence_Electron_Number': 0.022618344283104205,
#                'Martynov_Batsanov_Electronegativity': 0.05540413959655249,
#                'Ideal_Bond_Length_Sum': 0.03186445153895874,
#                'Mendeleev_Number': 0.0964075149296759},
#               'name': 'Bala Classification',
#               'type': 'classification',
#               'target_col': 'Formability',
#               'Deletion': {'dcc': {'Compound': 0.6428571428571429,
#                 'x(BiMe1Me2)O3': 0.7857142857142857,
#                 'Me1': 0.6428571428571429,
#                 'Me2': 0.35714285714285715,
#                 'frac-Me1': 0.6428571428571429,
#                 'frac-Me2': 0.42857142857142855,
#                 'frac-Me3': 0.7142857142857143,
#                 'PT-content': 0.7857142857142857,
#                 'Tolerance_Factor': 0.7857142857142857,
#                 'Valence_Electron_Number': 0.6428571428571429,
#                 'Martynov_Batsanov_Electronegativity': 0.5714285714285714,
#                 'Ideal_Bond_Length_Sum': 0.5714285714285714,
#                 'Mendeleev_Number': 0.5},
#                'feats2shap': {'Compound': 0.033517656933908443,
#                 'x(BiMe1Me2)O3': 0.026866350895225547,
#                 'Me1': 0.042658340318095345,
#                 'Me2': 0.026995748372673135,
#                 'frac-Me1': 0.010133439704339376,
#                 'frac-Me2': 0.010291424424433936,
#                 'frac-Me3': 0.0009665679408935992,
#                 'PT-content': 0.029120689183255836,
#                 'Tolerance_Factor': 0.05066038292786182,
#                 'Valence_Electron_Number': 0.023905058128641604,
#                 'Martynov_Batsanov_Electronegativity': 0.06450746430073478,
#                 'Ideal_Bond_Length_Sum': 0.03152836513802734,
#                 'Mendeleev_Number': 0.09787048559355582}},
#               'AdditionLinear': {'dcc': {'Compound': 0.7142857142857143,
#                 'x(BiMe1Me2)O3': 0.42857142857142855,
#                 'Me1': 0.42857142857142855,
#                 'Me2': 0.6428571428571429,
#                 'frac-Me1': 0.21428571428571427,
#                 'frac-Me2': 0.35714285714285715,
#                 'frac-Me3': 0.21428571428571427,
#                 'PT-content': 0.35714285714285715,
#                 'Tolerance_Factor': 0.35714285714285715,
#                 'Valence_Electron_Number': 0.35714285714285715,
#                 'Martynov_Batsanov_Electronegativity': 0.42857142857142855,
#                 'Ideal_Bond_Length_Sum': 0.42857142857142855,
#                 'Mendeleev_Number': 0.5714285714285714},
#                'feats2shap': {'Compound': 0.03022055322778982,
#                 'x(BiMe1Me2)O3': 0.043316701500888274,
#                 'Me1': 0.043658567717199975,
#                 'Me2': 0.03286489940515389,
#                 'frac-Me1': 0.009293024093798537,
#                 'frac-Me2': 0.013101624689919197,
#                 'frac-Me3': 0.0018561297918639101,
#                 'PT-content': 0.03327328153984393,
#                 'Tolerance_Factor': 0.04623847310464392,
#                 'Valence_Electron_Number': 0.02298601591444748,
#                 'Martynov_Batsanov_Electronegativity': 0.04209818228051446,
#                 'Ideal_Bond_Length_Sum': 0.03393429869311795,
#                 'Mendeleev_Number': 0.09972272144694766}},
#               'AdditionRand': {'dcc': {'Compound': 0.6428571428571429,
#                 'x(BiMe1Me2)O3': 0.5,
#                 'Me1': 0.21428571428571427,
#                 'Me2': 0.7857142857142857,
#                 'frac-Me1': 0.5,
#                 'frac-Me2': 0.5,
#                 'frac-Me3': 0.35714285714285715,
#                 'PT-content': 0.35714285714285715,
#                 'Tolerance_Factor': 0.21428571428571427,
#                 'Valence_Electron_Number': 0.5,
#                 'Martynov_Batsanov_Electronegativity': 0.6428571428571429,
#                 'Ideal_Bond_Length_Sum': 0.35714285714285715,
#                 'Mendeleev_Number': 0.35714285714285715},
#                'feats2shap': {'Compound': 0.0323989256024947,
#                 'x(BiMe1Me2)O3': 0.0294709017714744,
#                 'Me1': 0.0423319043518517,
#                 'Me2': 0.03338239698799714,
#                 'frac-Me1': 0.009231872258677047,
#                 'frac-Me2': 0.012209001176274098,
#                 'frac-Me3': 0.0016356906988158606,
#                 'PT-content': 0.03068792302712542,
#                 'Tolerance_Factor': 0.057679248018890544,
#                 'Valence_Electron_Number': 0.01961705845849955,
#                 'Martynov_Batsanov_Electronegativity': 0.053680690972184544,
#                 'Ideal_Bond_Length_Sum': 0.03363725036790906,
#                 'Mendeleev_Number': 0.08796230736114583}},
#               'ReplacementLinear': {'dcc': {'Compound': 0.5714285714285714,
#                 'x(BiMe1Me2)O3': 0.2857142857142857,
#                 'Me1': 0.35714285714285715,
#                 'Me2': 0.6428571428571429,
#                 'frac-Me1': 0.2857142857142857,
#                 'frac-Me2': 0.42857142857142855,
#                 'frac-Me3': 0.2857142857142857,
#                 'PT-content': 0.2857142857142857,
#                 'Tolerance_Factor': 0.42857142857142855,
#                 'Valence_Electron_Number': 0.42857142857142855,
#                 'Martynov_Batsanov_Electronegativity': 0.2857142857142857,
#                 'Ideal_Bond_Length_Sum': 0.6428571428571429,
#                 'Mendeleev_Number': 0.5714285714285714},
#                'feats2shap': {'Compound': 0.031474444100499765,
#                 'x(BiMe1Me2)O3': 0.03803725983530302,
#                 'Me1': 0.041430824682360964,
#                 'Me2': 0.031227415321724766,
#                 'frac-Me1': 0.011766221641678327,
#                 'frac-Me2': 0.013130403514810762,
#                 'frac-Me3': 0.0014936679037280444,
#                 'PT-content': 0.02894254525203705,
#                 'Tolerance_Factor': 0.050781338565253215,
#                 'Valence_Electron_Number': 0.025584762370265572,
#                 'Martynov_Batsanov_Electronegativity': 0.05024639089979388,
#                 'Ideal_Bond_Length_Sum': 0.028870348034839968,
#                 'Mendeleev_Number': 0.10212013033049189}},
#               'ReplacementRand': {'dcc': {'Compound': 0.7142857142857143,
#                 'x(BiMe1Me2)O3': 0.35714285714285715,
#                 'Me1': 0.5714285714285714,
#                 'Me2': 0.8571428571428571,
#                 'frac-Me1': 0.42857142857142855,
#                 'frac-Me2': 0.6428571428571429,
#                 'frac-Me3': 0.35714285714285715,
#                 'PT-content': 0.35714285714285715,
#                 'Tolerance_Factor': 0.6428571428571429,
#                 'Valence_Electron_Number': 0.42857142857142855,
#                 'Martynov_Batsanov_Electronegativity': 0.5,
#                 'Ideal_Bond_Length_Sum': 0.42857142857142855,
#                 'Mendeleev_Number': 0.42857142857142855},
#                'feats2shap': {'Compound': 0.029491393396971953,
#                 'x(BiMe1Me2)O3': 0.021933746732286957,
#                 'Me1': 0.03573129122151374,
#                 'Me2': 0.035137916288045176,
#                 'frac-Me1': 0.010501566135442677,
#                 'frac-Me2': 0.01301298455547939,
#                 'frac-Me3': 0.0016862379098106287,
#                 'PT-content': 0.04918094352446667,
#                 'Tolerance_Factor': 0.04841903554129742,
#                 'Valence_Electron_Number': 0.020154281958859772,
#                 'Martynov_Batsanov_Electronegativity': 0.05626780662351458,
#                 'Ideal_Bond_Length_Sum': 0.031156190497321188,
#                 'Mendeleev_Number': 0.09798294959658552}}},
#              'Bala_regression_dataset.csv': {'ori_feats2shap': {'Compound': 20.60837120403372,
#                'xBi(Me1Me2)O3': 7.275054606853217,
#                'xPT': 5.9968442030385996,
#                'Tolerance_Factor': 4.654389571341294,
#                'Ionic_Displacements': 39.4761867419901},
#               'name': 'Bala Regression',
#               'type': 'regression',
#               'target_col': 'Ferroelectric_Tc_in_Kelvin',
#               'Deletion': {'dcc': {'Compound': 1.0,
#                 'xBi(Me1Me2)O3': 0.6666666666666666,
#                 'xPT': 0.6666666666666666,
#                 'Tolerance_Factor': 0.8333333333333334,
#                 'Ionic_Displacements': 0.3333333333333333},
#                'feats2shap': {'Compound': 17.78995002353839,
#                 'xBi(Me1Me2)O3': 5.960133103428065,
#                 'xPT': 6.546317704283488,
#                 'Tolerance_Factor': 4.646907973954259,
#                 'Ionic_Displacements': 43.80306723636768}},
#               'AdditionLinear': {'dcc': {'Compound': 0.3333333333333333,
#                 'xBi(Me1Me2)O3': 0.5,
#                 'xPT': 0.3333333333333333,
#                 'Tolerance_Factor': 0.16666666666666666,
#                 'Ionic_Displacements': 0.3333333333333333},
#                'feats2shap': {'Compound': 19.23700290851543,
#                 'xBi(Me1Me2)O3': 6.194661581790523,
#                 'xPT': 9.12748894064553,
#                 'Tolerance_Factor': 4.688599715100634,
#                 'Ionic_Displacements': 46.68988742319213}},
#               'AdditionRand': {'dcc': {'Compound': 1.0,
#                 'xBi(Me1Me2)O3': 0.8333333333333334,
#                 'xPT': 0.6666666666666666,
#                 'Tolerance_Factor': 0.5,
#                 'Ionic_Displacements': 0.3333333333333333},
#                'feats2shap': {'Compound': 21.732045636420775,
#                 'xBi(Me1Me2)O3': 7.589713622482878,
#                 'xPT': 7.59849424265557,
#                 'Tolerance_Factor': 4.654570637355388,
#                 'Ionic_Displacements': 41.970778052953875}},
#               'ReplacementLinear': {'dcc': {'Compound': 0.5,
#                 'xBi(Me1Me2)O3': 0.3333333333333333,
#                 'xPT': 0.5,
#                 'Tolerance_Factor': 0.5,
#                 'Ionic_Displacements': 0.6666666666666666},
#                'feats2shap': {'Compound': 29.47464198817763,
#                 'xBi(Me1Me2)O3': 7.311686348442236,
#                 'xPT': 4.757598882454978,
#                 'Tolerance_Factor': 6.290759725754179,
#                 'Ionic_Displacements': 41.407747549475054}},
#               'ReplacementRand': {'dcc': {'Compound': 0.5,
#                 'xBi(Me1Me2)O3': 0.6666666666666666,
#                 'xPT': 0.5,
#                 'Tolerance_Factor': 0.6666666666666666,
#                 'Ionic_Displacements': 1.0},
#                'feats2shap': {'Compound': 16.251833852341797,
#                 'xBi(Me1Me2)O3': 11.893281796149846,
#                 'xPT': 6.738306022818705,
#                 'Tolerance_Factor': 6.619341540456568,
#                 'Ionic_Displacements': 44.91067548816813}}},
#              'bandgap.csv': {'ori_feats2shap': {'avg_Density_(g/mL)': 0.38674949881126536,
#                'avg_Gordy_electonegativity': 0.11261082103418422,
#                'avg_Number_of_unfilled_d_valence_electrons': 0.039607106645460466,
#                'avg_abs_valence': 0.13361051966235904,
#                'avg_metallic_valence': 0.5456738027324444,
#                'avg_valence_d': 0.03745260536705348,
#                'sum_Density_(g/mL)': 0.035575623016375756,
#                'sum_heat_atomization(kJ/mol)': 0.0830820232385413,
#                'sum_valence_d': 0.07971885553369128,
#                'range_Density_(g/mL)': 0.04064611087913789,
#                'range_Nagle_electonegativity': 0.11111177320401179,
#                'range_heat_of_fusion_(kJ/mol)_': 0.08018168562426807},
#               'name': 'Bandgap',
#               'type': 'regression',
#               'target_col': 'target',
#               'Deletion': {'dcc': {'avg_Density_(g/mL)': 1.0,
#                 'avg_Gordy_electonegativity': 1.0,
#                 'avg_Number_of_unfilled_d_valence_electrons': 1.0,
#                 'avg_abs_valence': 1.0,
#                 'avg_metallic_valence': 1.0,
#                 'avg_valence_d': 1.0,
#                 'sum_Density_(g/mL)': 1.0,
#                 'sum_heat_atomization(kJ/mol)': 1.0,
#                 'sum_valence_d': 1.0,
#                 'range_Density_(g/mL)': 1.0,
#                 'range_Nagle_electonegativity': 1.0,
#                 'range_heat_of_fusion_(kJ/mol)_': 1.0},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3822185550504754,
#                 'avg_Gordy_electonegativity': 0.11937439471170468,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.034589232426453696,
#                 'avg_abs_valence': 0.12855991486167503,
#                 'avg_metallic_valence': 0.5387725113024064,
#                 'avg_valence_d': 0.03628646409222577,
#                 'sum_Density_(g/mL)': 0.03878731794526063,
#                 'sum_heat_atomization(kJ/mol)': 0.08273826513298965,
#                 'sum_valence_d': 0.07328354579884963,
#                 'range_Density_(g/mL)': 0.03819208777432057,
#                 'range_Nagle_electonegativity': 0.11678246725205298,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.08175699660249258}},
#               'AdditionLinear': {'dcc': {'avg_Density_(g/mL)': 0.38461538461538464,
#                 'avg_Gordy_electonegativity': 0.46153846153846156,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.46153846153846156,
#                 'avg_abs_valence': 0.6923076923076923,
#                 'avg_metallic_valence': 0.46153846153846156,
#                 'avg_valence_d': 0.38461538461538464,
#                 'sum_Density_(g/mL)': 0.3076923076923077,
#                 'sum_heat_atomization(kJ/mol)': 0.23076923076923078,
#                 'sum_valence_d': 0.3076923076923077,
#                 'range_Density_(g/mL)': 0.46153846153846156,
#                 'range_Nagle_electonegativity': 0.38461538461538464,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.15384615384615385},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3562799087136445,
#                 'avg_Gordy_electonegativity': 0.11582142911111741,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.025165856002953856,
#                 'avg_abs_valence': 0.08991209312246348,
#                 'avg_metallic_valence': 0.15706211396094305,
#                 'avg_valence_d': 0.06032485982101824,
#                 'sum_Density_(g/mL)': 0.04255129087406314,
#                 'sum_heat_atomization(kJ/mol)': 0.16933000093887096,
#                 'sum_valence_d': 0.12456299509248944,
#                 'range_Density_(g/mL)': 0.12716613298321006,
#                 'range_Nagle_electonegativity': 0.6147219202860513,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.1217565146673304}},
#               'AdditionRand': {'dcc': {'avg_Density_(g/mL)': 0.3076923076923077,
#                 'avg_Gordy_electonegativity': 0.5384615384615384,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.38461538461538464,
#                 'avg_abs_valence': 0.6923076923076923,
#                 'avg_metallic_valence': 0.5384615384615384,
#                 'avg_valence_d': 0.46153846153846156,
#                 'sum_Density_(g/mL)': 0.46153846153846156,
#                 'sum_heat_atomization(kJ/mol)': 0.38461538461538464,
#                 'sum_valence_d': 0.5384615384615384,
#                 'range_Density_(g/mL)': 0.9230769230769231,
#                 'range_Nagle_electonegativity': 0.38461538461538464,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.46153846153846156},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3169127636534753,
#                 'avg_Gordy_electonegativity': 0.09628148204319195,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.05543771452888935,
#                 'avg_abs_valence': 0.11400754040828096,
#                 'avg_metallic_valence': 0.514334166338007,
#                 'avg_valence_d': 0.05003358911913514,
#                 'sum_Density_(g/mL)': 0.07086393713061422,
#                 'sum_heat_atomization(kJ/mol)': 0.09822264723292731,
#                 'sum_valence_d': 0.12862978197811287,
#                 'range_Density_(g/mL)': 0.0585663527253674,
#                 'range_Nagle_electonegativity': 0.20178284003420024,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.1318635254177276}},
#               'ReplacementLinear': {'dcc': {'avg_Density_(g/mL)': 0.23076923076923078,
#                 'avg_Gordy_electonegativity': 0.46153846153846156,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.38461538461538464,
#                 'avg_abs_valence': 0.23076923076923078,
#                 'avg_metallic_valence': 0.23076923076923078,
#                 'avg_valence_d': 0.38461538461538464,
#                 'sum_Density_(g/mL)': 0.15384615384615385,
#                 'sum_heat_atomization(kJ/mol)': 0.23076923076923078,
#                 'sum_valence_d': 0.23076923076923078,
#                 'range_Density_(g/mL)': 0.3076923076923077,
#                 'range_Nagle_electonegativity': 0.38461538461538464,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.07692307692307693},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3325108484934074,
#                 'avg_Gordy_electonegativity': 0.14340644096757751,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.02780583441000542,
#                 'avg_abs_valence': 0.0940814269938272,
#                 'avg_metallic_valence': 0.24318340378376202,
#                 'avg_valence_d': 0.027516648861810603,
#                 'sum_Density_(g/mL)': 0.09319576626664146,
#                 'sum_heat_atomization(kJ/mol)': 0.10476026264613313,
#                 'sum_valence_d': 0.2019521064545984,
#                 'range_Density_(g/mL)': 0.11442894851443809,
#                 'range_Nagle_electonegativity': 0.4183239953317484,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.13306839239240617}},
#               'ReplacementRand': {'dcc': {'avg_Density_(g/mL)': 0.23076923076923078,
#                 'avg_Gordy_electonegativity': 0.3076923076923077,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.23076923076923078,
#                 'avg_abs_valence': 0.15384615384615385,
#                 'avg_metallic_valence': 0.46153846153846156,
#                 'avg_valence_d': 0.23076923076923078,
#                 'sum_Density_(g/mL)': 0.38461538461538464,
#                 'sum_heat_atomization(kJ/mol)': 0.23076923076923078,
#                 'sum_valence_d': 0.23076923076923078,
#                 'range_Density_(g/mL)': 0.3076923076923077,
#                 'range_Nagle_electonegativity': 0.46153846153846156,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.3076923076923077},
#                'feats2shap': {'avg_Density_(g/mL)': 0.3969758019479689,
#                 'avg_Gordy_electonegativity': 0.0924459898443898,
#                 'avg_Number_of_unfilled_d_valence_electrons': 0.04267929319713231,
#                 'avg_abs_valence': 0.12488394422994209,
#                 'avg_metallic_valence': 0.4949109123743366,
#                 'avg_valence_d': 0.09438857785391644,
#                 'sum_Density_(g/mL)': 0.06885380359839749,
#                 'sum_heat_atomization(kJ/mol)': 0.0996247308120017,
#                 'sum_valence_d': 0.22575731205063368,
#                 'range_Density_(g/mL)': 0.0525656504036136,
#                 'range_Nagle_electonegativity': 0.19690274882632994,
#                 'range_heat_of_fusion_(kJ/mol)_': 0.12462813992468408}}},
#              'BMDS_data.csv': {'ori_feats2shap': {'a_mono': 0.003366113320390514,
#                'a': 0.003965316024509296,
#                'b': 0.004353293532454283,
#                'DFT_energy_bi': 0.007216569231486068,
#                'magnetic_moment': 0.0,
#                'formation_energy': 0.00301907319933986,
#                'area': 0.00280292047870701,
#                'd': 0.003056690405491597,
#                'no_soc_bandgap': 0.7005548790673587,
#                'dielectric_constant': 0.00698323244332095,
#                'soc_energy': 0.04146214671132726,
#                'del_e_bilayer_bottom_and_mono': 0.0030584293119203104},
#               'name': 'BMDS',
#               'type': 'regression',
#               'target_col': 'soc_bandgap',
#               'Deletion': {'dcc': {'a_mono': 0.6153846153846154,
#                 'a': 0.6153846153846154,
#                 'b': 0.6153846153846154,
#                 'DFT_energy_bi': 0.9230769230769231,
#                 'magnetic_moment': 0.9230769230769231,
#                 'formation_energy': 1.0,
#                 'area': 0.6153846153846154,
#                 'd': 0.6923076923076923,
#                 'no_soc_bandgap': 0.6923076923076923,
#                 'dielectric_constant': 1.0,
#                 'soc_energy': 0.5384615384615384,
#                 'del_e_bilayer_bottom_and_mono': 0.6923076923076923},
#                'feats2shap': {'a_mono': 0.003660839597180405,
#                 'a': 0.004502236269130717,
#                 'b': 0.0042620155341479265,
#                 'DFT_energy_bi': 0.005221601485307654,
#                 'magnetic_moment': 0.0,
#                 'formation_energy': 0.0028195238400014274,
#                 'area': 0.0028092964902196042,
#                 'd': 0.0024452762042547313,
#                 'no_soc_bandgap': 0.6981986589685392,
#                 'dielectric_constant': 0.007680280997059157,
#                 'soc_energy': 0.035105705194850886,
#                 'del_e_bilayer_bottom_and_mono': 0.0031216609715175947}},
#               'AdditionLinear': {'dcc': {'a_mono': 0.23076923076923078,
#                 'a': 0.38461538461538464,
#                 'b': 0.38461538461538464,
#                 'DFT_energy_bi': 0.07692307692307693,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.46153846153846156,
#                 'area': 0.15384615384615385,
#                 'd': 0.23076923076923078,
#                 'no_soc_bandgap': 0.38461538461538464,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.004289143435548923,
#                 'a': 0.008260258196006655,
#                 'b': 0.005613145213277118,
#                 'DFT_energy_bi': 0.011614456882514635,
#                 'magnetic_moment': 0.0021354332223135425,
#                 'formation_energy': 0.007176690698115669,
#                 'area': 0.012452855023280926,
#                 'd': 0.0038335776354517016,
#                 'no_soc_bandgap': 0.7822568074606266,
#                 'dielectric_constant': 0.01296463790021293,
#                 'soc_energy': 0.050818619464833306,
#                 'del_e_bilayer_bottom_and_mono': 0.02544340751489901}},
#               'AdditionRand': {'dcc': {'a_mono': 0.3076923076923077,
#                 'a': 0.38461538461538464,
#                 'b': 0.07692307692307693,
#                 'DFT_energy_bi': 0.23076923076923078,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.3076923076923077,
#                 'area': 0.07692307692307693,
#                 'd': 0.3076923076923077,
#                 'no_soc_bandgap': 0.3076923076923077,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.23076923076923078,
#                 'del_e_bilayer_bottom_and_mono': 0.15384615384615385},
#                'feats2shap': {'a_mono': 0.006106304401169701,
#                 'a': 0.0060301463228854876,
#                 'b': 0.010112715350318092,
#                 'DFT_energy_bi': 0.008951975264751067,
#                 'magnetic_moment': 0.02336615844535039,
#                 'formation_energy': 0.02499268928451826,
#                 'area': 0.015737299307791847,
#                 'd': 0.005521535322243108,
#                 'no_soc_bandgap': 0.7609565158911296,
#                 'dielectric_constant': 0.02914326930857252,
#                 'soc_energy': 0.042042555681126206,
#                 'del_e_bilayer_bottom_and_mono': 0.02282720051218011}},
#               'ReplacementLinear': {'dcc': {'a_mono': 0.3076923076923077,
#                 'a': 0.15384615384615385,
#                 'b': 0.23076923076923078,
#                 'DFT_energy_bi': 0.23076923076923078,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.38461538461538464,
#                 'area': 0.15384615384615385,
#                 'd': 0.15384615384615385,
#                 'no_soc_bandgap': 0.3076923076923077,
#                 'dielectric_constant': 0.15384615384615385,
#                 'soc_energy': 0.07692307692307693,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.008407138623453757,
#                 'a': 0.008955520220959802,
#                 'b': 0.01049428670043192,
#                 'DFT_energy_bi': 0.008502474791646779,
#                 'magnetic_moment': 0.004988978433738693,
#                 'formation_energy': 0.015781253388454874,
#                 'area': 0.007773713506071885,
#                 'd': 0.005916922256569084,
#                 'no_soc_bandgap': 0.7676310139803086,
#                 'dielectric_constant': 0.06092754469777821,
#                 'soc_energy': 0.04747231216645891,
#                 'del_e_bilayer_bottom_and_mono': 0.012165826158120568}},
#               'ReplacementRand': {'dcc': {'a_mono': 0.38461538461538464,
#                 'a': 0.23076923076923078,
#                 'b': 0.23076923076923078,
#                 'DFT_energy_bi': 0.15384615384615385,
#                 'magnetic_moment': 0.07692307692307693,
#                 'formation_energy': 0.38461538461538464,
#                 'area': 0.15384615384615385,
#                 'd': 0.23076923076923078,
#                 'no_soc_bandgap': 0.38461538461538464,
#                 'dielectric_constant': 0.07692307692307693,
#                 'soc_energy': 0.15384615384615385,
#                 'del_e_bilayer_bottom_and_mono': 0.07692307692307693},
#                'feats2shap': {'a_mono': 0.009768142930776517,
#                 'a': 0.007985311731188233,
#                 'b': 0.005177515185803972,
#                 'DFT_energy_bi': 0.006746118420620767,
#                 'magnetic_moment': 0.0069763126999827455,
#                 'formation_energy': 0.013554380707264455,
#                 'area': 0.016844032528164396,
#                 'd': 0.011872086910603022,
#                 'no_soc_bandgap': 0.7304451736920567,
#                 'dielectric_constant': 0.046615965665087924,
#                 'soc_energy': 0.047847554188706544,
#                 'del_e_bilayer_bottom_and_mono': 0.03669486428867764}}},
#              'Crystal_structure.csv': {'ori_feats2shap': {'v(A)': 0.00928807805117576,
#                'v(B)': 0.008590939033111613,
#                'r(AXII)(Å)': 0.014293254707227978,
#                'r(AVI)(Å)': 0.01505931174813062,
#                'r(BVI)(Å)': 0.01816361031209468,
#                'EN(A)': 0.03062920334507453,
#                'EN(B)': 0.041057098775248,
#                'l(A-O)(Å)': 0.01676954859238621,
#                'l(B-O)(Å)': 0.015547435066267122,
#                'ΔENR': 0.022561250770963527,
#                'tG': 0.03321633640362814,
#                'τ': 0.04550646279639944,
#                'μ': 0.016420558105693362},
#               'name': 'Crystal Structure',
#               'type': 'classification',
#               'target_col': 'Lowest distortion',
#               'Deletion': {'dcc': {'v(A)': 1.0,
#                 'v(B)': 1.0,
#                 'r(AXII)(Å)': 1.0,
#                 'r(AVI)(Å)': 0.9285714285714286,
#                 'r(BVI)(Å)': 1.0,
#                 'EN(A)': 0.9285714285714286,
#                 'EN(B)': 1.0,
#                 'l(A-O)(Å)': 0.9285714285714286,
#                 'l(B-O)(Å)': 1.0,
#                 'ΔENR': 1.0,
#                 'tG': 1.0,
#                 'τ': 0.9285714285714286,
#                 'μ': 1.0},
#                'feats2shap': {'v(A)': 0.00852148020059792,
#                 'v(B)': 0.008114109412602011,
#                 'r(AXII)(Å)': 0.014372128180042736,
#                 'r(AVI)(Å)': 0.01689696966249032,
#                 'r(BVI)(Å)': 0.016948940252324112,
#                 'EN(A)': 0.032179646894952736,
#                 'EN(B)': 0.039433952608909924,
#                 'l(A-O)(Å)': 0.01604704092018399,
#                 'l(B-O)(Å)': 0.013809211831225365,
#                 'ΔENR': 0.020741638889733637,
#                 'tG': 0.032953311987912605,
#                 'τ': 0.04692818174425393,
#                 'μ': 0.016779080778369253}},
#               'AdditionLinear': {'dcc': {'v(A)': 0.7142857142857143,
#                 'v(B)': 0.6428571428571429,
#                 'r(AXII)(Å)': 0.35714285714285715,
#                 'r(AVI)(Å)': 0.35714285714285715,
#                 'r(BVI)(Å)': 0.5,
#                 'EN(A)': 0.2857142857142857,
#                 'EN(B)': 0.7142857142857143,
#                 'l(A-O)(Å)': 0.5714285714285714,
#                 'l(B-O)(Å)': 0.5714285714285714,
#                 'ΔENR': 0.42857142857142855,
#                 'tG': 0.42857142857142855,
#                 'τ': 0.5,
#                 'μ': 0.35714285714285715},
#                'feats2shap': {'v(A)': 0.008852084062414238,
#                 'v(B)': 0.010115154124280734,
#                 'r(AXII)(Å)': 0.015529525763111398,
#                 'r(AVI)(Å)': 0.018739407007789977,
#                 'r(BVI)(Å)': 0.017188093804673288,
#                 'EN(A)': 0.03380811858077807,
#                 'EN(B)': 0.04051106233962738,
#                 'l(A-O)(Å)': 0.015651751184764345,
#                 'l(B-O)(Å)': 0.015485600404456797,
#                 'ΔENR': 0.02089814560671976,
#                 'tG': 0.03363732187062638,
#                 'τ': 0.042415324076373155,
#                 'μ': 0.018516760067995876}},
#               'AdditionRand': {'dcc': {'v(A)': 0.5714285714285714,
#                 'v(B)': 0.5714285714285714,
#                 'r(AXII)(Å)': 0.5,
#                 'r(AVI)(Å)': 0.5714285714285714,
#                 'r(BVI)(Å)': 0.42857142857142855,
#                 'EN(A)': 0.21428571428571427,
#                 'EN(B)': 0.6428571428571429,
#                 'l(A-O)(Å)': 0.5,
#                 'l(B-O)(Å)': 0.5,
#                 'ΔENR': 0.6428571428571429,
#                 'tG': 0.42857142857142855,
#                 'τ': 0.5714285714285714,
#                 'μ': 0.6428571428571429},
#                'feats2shap': {'v(A)': 0.009807461229704401,
#                 'v(B)': 0.011741555125314815,
#                 'r(AXII)(Å)': 0.015600911435392975,
#                 'r(AVI)(Å)': 0.016966590189813363,
#                 'r(BVI)(Å)': 0.017556984885762995,
#                 'EN(A)': 0.03029521997654311,
#                 'EN(B)': 0.037172447623147704,
#                 'l(A-O)(Å)': 0.017505036193135228,
#                 'l(B-O)(Å)': 0.014296154021949966,
#                 'ΔENR': 0.02167546527585715,
#                 'tG': 0.02996303531057496,
#                 'τ': 0.044295830288600194,
#                 'μ': 0.019415354047052646}},
#               'ReplacementLinear': {'dcc': {'v(A)': 0.35714285714285715,
#                 'v(B)': 0.42857142857142855,
#                 'r(AXII)(Å)': 0.42857142857142855,
#                 'r(AVI)(Å)': 0.5,
#                 'r(BVI)(Å)': 0.5714285714285714,
#                 'EN(A)': 0.5714285714285714,
#                 'EN(B)': 0.6428571428571429,
#                 'l(A-O)(Å)': 0.42857142857142855,
#                 'l(B-O)(Å)': 0.7142857142857143,
#                 'ΔENR': 0.35714285714285715,
#                 'tG': 0.5714285714285714,
#                 'τ': 0.42857142857142855,
#                 'μ': 0.5714285714285714},
#                'feats2shap': {'v(A)': 0.00937773673024605,
#                 'v(B)': 0.009515634435694467,
#                 'r(AXII)(Å)': 0.013242333573481521,
#                 'r(AVI)(Å)': 0.018741790180441368,
#                 'r(BVI)(Å)': 0.0222084987935467,
#                 'EN(A)': 0.03388568653278934,
#                 'EN(B)': 0.03581795446745039,
#                 'l(A-O)(Å)': 0.017034514612887935,
#                 'l(B-O)(Å)': 0.014669587970837051,
#                 'ΔENR': 0.023041655190272955,
#                 'tG': 0.0345350304739084,
#                 'τ': 0.044550714566577033,
#                 'μ': 0.014937292830720887}},
#               'ReplacementRand': {'dcc': {'v(A)': 0.5,
#                 'v(B)': 0.6428571428571429,
#                 'r(AXII)(Å)': 0.5,
#                 'r(AVI)(Å)': 0.5714285714285714,
#                 'r(BVI)(Å)': 0.7142857142857143,
#                 'EN(A)': 0.5,
#                 'EN(B)': 0.8571428571428571,
#                 'l(A-O)(Å)': 0.5,
#                 'l(B-O)(Å)': 0.35714285714285715,
#                 'ΔENR': 0.5,
#                 'tG': 0.42857142857142855,
#                 'τ': 0.42857142857142855,
#                 'μ': 0.5714285714285714},
#                'feats2shap': {'v(A)': 0.012900031004366572,
#                 'v(B)': 0.008582918759092941,
#                 'r(AXII)(Å)': 0.013779882752754099,
#                 'r(AVI)(Å)': 0.016317520583576762,
#                 'r(BVI)(Å)': 0.01935657738721506,
#                 'EN(A)': 0.030432199281862554,
#                 'EN(B)': 0.03572279826437676,
#                 'l(A-O)(Å)': 0.01742115728719097,
#                 'l(B-O)(Å)': 0.014857071496426275,
#                 'ΔENR': 0.02519177775860246,
#                 'tG': 0.03195975186128303,
#                 'τ': 0.043719241354260446,
#                 'μ': 0.016043010498876135}}},
#              'Glass.csv': {'ori_feats2shap': {'RI': 0.037859991545018706,
#                'Na': 0.025386526591311877,
#                'Mg': 0.058506488488587395,
#                'Al': 0.050366751947213295,
#                'Si': 0.014770640346268021,
#                'K': 0.020324243126125522,
#                'Ca': 0.031106733133963962,
#                'Ba': 0.032559546525034226,
#                'Fe': 0.008634754652686791},
#               'name': 'Glass',
#               'type': 'classification',
#               'target_col': 'Type of glass',
#               'Deletion': {'dcc': {'RI': 0.7,
#                 'Na': 0.8,
#                 'Mg': 0.5,
#                 'Al': 0.5,
#                 'Si': 0.4,
#                 'K': 0.3,
#                 'Ca': 0.9,
#                 'Ba': 0.5,
#                 'Fe': 0.4},
#                'feats2shap': {'RI': 0.033188937162155124,
#                 'Na': 0.02625616795511972,
#                 'Mg': 0.058132839461599826,
#                 'Al': 0.053364939145103284,
#                 'Si': 0.015495627980867226,
#                 'K': 0.021321564584769182,
#                 'Ca': 0.029501764279697643,
#                 'Ba': 0.03469712137469943,
#                 'Fe': 0.008996850277645477}},
#               'AdditionLinear': {'dcc': {'RI': 0.2,
#                 'Na': 0.6,
#                 'Mg': 0.5,
#                 'Al': 0.4,
#                 'Si': 0.4,
#                 'K': 0.3,
#                 'Ca': 0.3,
#                 'Ba': 0.4,
#                 'Fe': 0.4},
#                'feats2shap': {'RI': 0.03663471417963698,
#                 'Na': 0.03009662024370331,
#                 'Mg': 0.05958415311041503,
#                 'Al': 0.04832084093658994,
#                 'Si': 0.014091735539010294,
#                 'K': 0.02000549330268315,
#                 'Ca': 0.031128438822892623,
#                 'Ba': 0.0281698383761865,
#                 'Fe': 0.009673430269251859}},
#               'AdditionRand': {'dcc': {'RI': 0.1,
#                 'Na': 0.2,
#                 'Mg': 0.2,
#                 'Al': 0.4,
#                 'Si': 0.4,
#                 'K': 0.3,
#                 'Ca': 0.3,
#                 'Ba': 0.2,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.03732760264756417,
#                 'Na': 0.026236340854922376,
#                 'Mg': 0.062136410185348045,
#                 'Al': 0.049493281183046904,
#                 'Si': 0.014648224701657027,
#                 'K': 0.019299835580669677,
#                 'Ca': 0.030357330442766377,
#                 'Ba': 0.02948796414536924,
#                 'Fe': 0.009377520422386598}},
#               'ReplacementLinear': {'dcc': {'RI': 0.2,
#                 'Na': 0.3,
#                 'Mg': 0.5,
#                 'Al': 0.4,
#                 'Si': 0.5,
#                 'K': 0.4,
#                 'Ca': 0.6,
#                 'Ba': 0.4,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.0373242458833268,
#                 'Na': 0.025741519350446513,
#                 'Mg': 0.06522450953752668,
#                 'Al': 0.04618853779617529,
#                 'Si': 0.01559316447131337,
#                 'K': 0.020723059120661854,
#                 'Ca': 0.027354487867688817,
#                 'Ba': 0.028285675386546232,
#                 'Fe': 0.009277614136421631}},
#               'ReplacementRand': {'dcc': {'RI': 0.2,
#                 'Na': 0.4,
#                 'Mg': 0.3,
#                 'Al': 0.4,
#                 'Si': 0.4,
#                 'K': 0.3,
#                 'Ca': 0.5,
#                 'Ba': 0.4,
#                 'Fe': 0.3},
#                'feats2shap': {'RI': 0.0330841330124917,
#                 'Na': 0.02395439333646422,
#                 'Mg': 0.05999142293339215,
#                 'Al': 0.04932604737732424,
#                 'Si': 0.014517433837539917,
#                 'K': 0.019337244818590317,
#                 'Ca': 0.031453775087613677,
#                 'Ba': 0.03284518794726335,
#                 'Fe': 0.008365645642235632}}},
#              'PUE.csv': {'ori_feats2shap': {'ZS_CHS': 0.07208610019768472,
#                'ZS_R': 0.013958132892156003,
#                'ZS_log_Tr1K': 0.006903631445503145,
#                'ZS_log_Tr2K': 0.00881557172441453,
#                'PMStep': 0.0007424758525061988,
#                'Form_Method': 0.0010502969507552012,
#                'ZS_log_CSArea': 0.00702946402506858,
#                'ZS_log_StrainRate': 0.013377728425863274,
#                'ZS_log_PO_MW': 0.06258830317076215,
#                'ZS_log_FCVm': 0.13645203544301585,
#                'ZS_FCCED': 0.07534204358060362,
#                'ZS_log_Fchi': 0.01264861167444042,
#                'ZS_SS_TPSA_norm': 0.015052753265992917,
#                'ZS_SS_MolLogP_norm': 0.011297945684567195,
#                'ZS_HS_BertzCT': 0.030223438658344048,
#                'ZS_SS_VSA_EState8': 0.050845734315427764,
#                'ZS_SS_PEOE_VSA8': 0.012340758037346597,
#                'ZS_log_HS_NumNHCO_norm': 0.015389459071923515,
#                'ZS_FC_NumHAcceptors_norm': 0.017376917536886416,
#                'ZS_FC_RingCount_norm': 0.06483405605254663},
#               'name': 'PUE',
#               'type': 'regression',
#               'target_col': 'logYM',
#               'Deletion': {'dcc': {'ZS_CHS': 0.6190476190476191,
#                 'ZS_R': 0.8571428571428571,
#                 'ZS_log_Tr1K': 0.6666666666666666,
#                 'ZS_log_Tr2K': 0.9047619047619048,
#                 'PMStep': 0.8095238095238095,
#                 'Form_Method': 0.8571428571428571,
#                 'ZS_log_CSArea': 0.42857142857142855,
#                 'ZS_log_StrainRate': 0.8095238095238095,
#                 'ZS_log_PO_MW': 0.7619047619047619,
#                 'ZS_log_FCVm': 0.6666666666666666,
#                 'ZS_FCCED': 0.5714285714285714,
#                 'ZS_log_Fchi': 0.6666666666666666,
#                 'ZS_SS_TPSA_norm': 0.6666666666666666,
#                 'ZS_SS_MolLogP_norm': 0.5238095238095238,
#                 'ZS_HS_BertzCT': 0.6666666666666666,
#                 'ZS_SS_VSA_EState8': 0.42857142857142855,
#                 'ZS_SS_PEOE_VSA8': 0.47619047619047616,
#                 'ZS_log_HS_NumNHCO_norm': 0.47619047619047616,
#                 'ZS_FC_NumHAcceptors_norm': 0.7142857142857143,
#                 'ZS_FC_RingCount_norm': 0.8095238095238095},
#                'feats2shap': {'ZS_CHS': 0.07375956003594454,
#                 'ZS_R': 0.012611434407544453,
#                 'ZS_log_Tr1K': 0.005400504919452204,
#                 'ZS_log_Tr2K': 0.004217719360969881,
#                 'PMStep': 0.0009136786446696674,
#                 'Form_Method': 0.0012059828693440759,
#                 'ZS_log_CSArea': 0.006013438908219755,
#                 'ZS_log_StrainRate': 0.010051179453535111,
#                 'ZS_log_PO_MW': 0.06504000898278285,
#                 'ZS_log_FCVm': 0.1235230165381517,
#                 'ZS_FCCED': 0.05707944765847244,
#                 'ZS_log_Fchi': 0.015324756181228756,
#                 'ZS_SS_TPSA_norm': 0.012663014809360076,
#                 'ZS_SS_MolLogP_norm': 0.013255438107182747,
#                 'ZS_HS_BertzCT': 0.03759337178624037,
#                 'ZS_SS_VSA_EState8': 0.049477600558126944,
#                 'ZS_SS_PEOE_VSA8': 0.011256787732382633,
#                 'ZS_log_HS_NumNHCO_norm': 0.012849946839141107,
#                 'ZS_FC_NumHAcceptors_norm': 0.017452223122182028,
#                 'ZS_FC_RingCount_norm': 0.0550209039650677}},
#               'AdditionLinear': {'dcc': {'ZS_CHS': 0.38095238095238093,
#                 'ZS_R': 0.6190476190476191,
#                 'ZS_log_Tr1K': 0.47619047619047616,
#                 'ZS_log_Tr2K': 0.38095238095238093,
#                 'PMStep': 0.7142857142857143,
#                 'Form_Method': 0.47619047619047616,
#                 'ZS_log_CSArea': 0.42857142857142855,
#                 'ZS_log_StrainRate': 0.7142857142857143,
#                 'ZS_log_PO_MW': 0.5714285714285714,
#                 'ZS_log_FCVm': 0.5238095238095238,
#                 'ZS_FCCED': 0.42857142857142855,
#                 'ZS_log_Fchi': 0.3333333333333333,
#                 'ZS_SS_TPSA_norm': 0.38095238095238093,
#                 'ZS_SS_MolLogP_norm': 0.3333333333333333,
#                 'ZS_HS_BertzCT': 0.7142857142857143,
#                 'ZS_SS_VSA_EState8': 0.3333333333333333,
#                 'ZS_SS_PEOE_VSA8': 0.8571428571428571,
#                 'ZS_log_HS_NumNHCO_norm': 0.3333333333333333,
#                 'ZS_FC_NumHAcceptors_norm': 0.2857142857142857,
#                 'ZS_FC_RingCount_norm': 0.8095238095238095},
#                'feats2shap': {'ZS_CHS': 0.09836477435392701,
#                 'ZS_R': 0.015582394799682252,
#                 'ZS_log_Tr1K': 0.006155791833211572,
#                 'ZS_log_Tr2K': 0.00892098035647866,
#                 'PMStep': 0.001490635523212113,
#                 'Form_Method': 0.0012124287623132325,
#                 'ZS_log_CSArea': 0.006071758750008501,
#                 'ZS_log_StrainRate': 0.0109106983558331,
#                 'ZS_log_PO_MW': 0.03961382683423885,
#                 'ZS_log_FCVm': 0.07206868943686484,
#                 'ZS_FCCED': 0.147481650749589,
#                 'ZS_log_Fchi': 0.02164877088645111,
#                 'ZS_SS_TPSA_norm': 0.019755564298216885,
#                 'ZS_SS_MolLogP_norm': 0.026753141155246227,
#                 'ZS_HS_BertzCT': 0.05603350989421714,
#                 'ZS_SS_VSA_EState8': 0.05754483143101657,
#                 'ZS_SS_PEOE_VSA8': 0.007842580019427338,
#                 'ZS_log_HS_NumNHCO_norm': 0.015113551680574008,
#                 'ZS_FC_NumHAcceptors_norm': 0.013728535276499474,
#                 'ZS_FC_RingCount_norm': 0.031025832026004615}},
#               'AdditionRand': {'dcc': {'ZS_CHS': 0.3333333333333333,
#                 'ZS_R': 0.6190476190476191,
#                 'ZS_log_Tr1K': 0.38095238095238093,
#                 'ZS_log_Tr2K': 0.5238095238095238,
#                 'PMStep': 0.7619047619047619,
#                 'Form_Method': 0.6666666666666666,
#                 'ZS_log_CSArea': 0.47619047619047616,
#                 'ZS_log_StrainRate': 0.5238095238095238,
#                 'ZS_log_PO_MW': 0.47619047619047616,
#                 'ZS_log_FCVm': 0.42857142857142855,
#                 'ZS_FCCED': 0.42857142857142855,
#                 'ZS_log_Fchi': 0.19047619047619047,
#                 'ZS_SS_TPSA_norm': 0.42857142857142855,
#                 'ZS_SS_MolLogP_norm': 0.38095238095238093,
#                 'ZS_HS_BertzCT': 0.38095238095238093,
#                 'ZS_SS_VSA_EState8': 0.47619047619047616,
#                 'ZS_SS_PEOE_VSA8': 0.7619047619047619,
#                 'ZS_log_HS_NumNHCO_norm': 0.23809523809523808,
#                 'ZS_FC_NumHAcceptors_norm': 0.23809523809523808,
#                 'ZS_FC_RingCount_norm': 0.7619047619047619},
#                'feats2shap': {'ZS_CHS': 0.05815495495362814,
#                 'ZS_R': 0.017563132345258702,
#                 'ZS_log_Tr1K': 0.0069510931722255535,
#                 'ZS_log_Tr2K': 0.010876815873454428,
#                 'PMStep': 0.0020251780617110667,
#                 'Form_Method': 0.0019526594222835367,
#                 'ZS_log_CSArea': 0.004836125286264192,
#                 'ZS_log_StrainRate': 0.011759739776608907,
#                 'ZS_log_PO_MW': 0.03908781590028663,
#                 'ZS_log_FCVm': 0.14740575778240167,
#                 'ZS_FCCED': 0.051464227023617935,
#                 'ZS_log_Fchi': 0.011581385752699134,
#                 'ZS_SS_TPSA_norm': 0.015571988483378395,
#                 'ZS_SS_MolLogP_norm': 0.016541739896001526,
#                 'ZS_HS_BertzCT': 0.03619211949207246,
#                 'ZS_SS_VSA_EState8': 0.09905603304612176,
#                 'ZS_SS_PEOE_VSA8': 0.010022631604292603,
#                 'ZS_log_HS_NumNHCO_norm': 0.013863958672813382,
#                 'ZS_FC_NumHAcceptors_norm': 0.01822307395472775,
#                 'ZS_FC_RingCount_norm': 0.051102714046307444}},
#               'ReplacementLinear': {'dcc': {'ZS_CHS': 0.23809523809523808,
#                 'ZS_R': 0.19047619047619047,
#                 'ZS_log_Tr1K': 0.2857142857142857,
#                 'ZS_log_Tr2K': 0.2857142857142857,
#                 'PMStep': 0.5238095238095238,
#                 'Form_Method': 0.3333333333333333,
#                 'ZS_log_CSArea': 0.2857142857142857,
#                 'ZS_log_StrainRate': 0.6666666666666666,
#                 'ZS_log_PO_MW': 0.14285714285714285,
#                 'ZS_log_FCVm': 0.38095238095238093,
#                 'ZS_FCCED': 0.3333333333333333,
#                 'ZS_log_Fchi': 0.19047619047619047,
#                 'ZS_SS_TPSA_norm': 0.3333333333333333,
#                 'ZS_SS_MolLogP_norm': 0.38095238095238093,
#                 'ZS_HS_BertzCT': 0.2857142857142857,
#                 'ZS_SS_VSA_EState8': 0.3333333333333333,
#                 'ZS_SS_PEOE_VSA8': 0.7142857142857143,
#                 'ZS_log_HS_NumNHCO_norm': 0.2857142857142857,
#                 'ZS_FC_NumHAcceptors_norm': 0.7142857142857143,
#                 'ZS_FC_RingCount_norm': 0.38095238095238093},
#                'feats2shap': {'ZS_CHS': 0.05489123568219731,
#                 'ZS_R': 0.013288851603623988,
#                 'ZS_log_Tr1K': 0.0072095494920921405,
#                 'ZS_log_Tr2K': 0.009204432477500147,
#                 'PMStep': 0.001265917238028908,
#                 'Form_Method': 0.0011174129693387502,
#                 'ZS_log_CSArea': 0.0076661931960570005,
#                 'ZS_log_StrainRate': 0.01582844671441121,
#                 'ZS_log_PO_MW': 0.031496834588182754,
#                 'ZS_log_FCVm': 0.16057320873702102,
#                 'ZS_FCCED': 0.06964953382188015,
#                 'ZS_log_Fchi': 0.018795824887276685,
#                 'ZS_SS_TPSA_norm': 0.01806627725417563,
#                 'ZS_SS_MolLogP_norm': 0.02020811700048651,
#                 'ZS_HS_BertzCT': 0.034143656255907484,
#                 'ZS_SS_VSA_EState8': 0.05103198132724819,
#                 'ZS_SS_PEOE_VSA8': 0.009294854677186758,
#                 'ZS_log_HS_NumNHCO_norm': 0.016882654315823312,
#                 'ZS_FC_NumHAcceptors_norm': 0.024258142740094264,
#                 'ZS_FC_RingCount_norm': 0.051416832621001024}},
#               'ReplacementRand': {'dcc': {'ZS_CHS': 0.3333333333333333,
#                 'ZS_R': 0.6666666666666666,
#                 'ZS_log_Tr1K': 0.23809523809523808,
#                 'ZS_log_Tr2K': 0.2857142857142857,
#                 'PMStep': 0.5714285714285714,
#                 'Form_Method': 0.6190476190476191,
#                 'ZS_log_CSArea': 0.3333333333333333,
#                 'ZS_log_StrainRate': 0.3333333333333333,
#                 'ZS_log_PO_MW': 0.3333333333333333,
#                 'ZS_log_FCVm': 0.38095238095238093,
#                 'ZS_FCCED': 0.19047619047619047,
#                 'ZS_log_Fchi': 0.09523809523809523,
#                 'ZS_SS_TPSA_norm': 0.2857142857142857,
#                 'ZS_SS_MolLogP_norm': 0.42857142857142855,
#                 'ZS_HS_BertzCT': 0.3333333333333333,
#                 'ZS_SS_VSA_EState8': 0.2857142857142857,
#                 'ZS_SS_PEOE_VSA8': 0.6190476190476191,
#                 'ZS_log_HS_NumNHCO_norm': 0.38095238095238093,
#                 'ZS_FC_NumHAcceptors_norm': 0.2857142857142857,
#                 'ZS_FC_RingCount_norm': 0.5714285714285714},
#                'feats2shap': {'ZS_CHS': 0.0554630105361472,
#                 'ZS_R': 0.00740796289674214,
#                 'ZS_log_Tr1K': 0.008253670174576806,
#                 'ZS_log_Tr2K': 0.0053932797297286455,
#                 'PMStep': 0.0027800401109139756,
#                 'Form_Method': 0.003631800870067804,
#                 'ZS_log_CSArea': 0.007638010373967619,
#                 'ZS_log_StrainRate': 0.014633556864128755,
#                 'ZS_log_PO_MW': 0.0910933308252096,
#                 'ZS_log_FCVm': 0.1292116571579141,
#                 'ZS_FCCED': 0.03191638459295454,
#                 'ZS_log_Fchi': 0.03421075789543984,
#                 'ZS_SS_TPSA_norm': 0.019533294317465512,
#                 'ZS_SS_MolLogP_norm': 0.014426558789625505,
#                 'ZS_HS_BertzCT': 0.03904798667520507,
#                 'ZS_SS_VSA_EState8': 0.08168839333872506,
#                 'ZS_SS_PEOE_VSA8': 0.008435860677179474,
#                 'ZS_log_HS_NumNHCO_norm': 0.018764175086559014,
#                 'ZS_FC_NumHAcceptors_norm': 0.01795376767422288,
#                 'ZS_FC_RingCount_norm': 0.05413662965152595}}}})

# %%
from enum import Enum

class PerturbationType(Enum):
    Deletion = "Deletion"
    AdditionLinear = "AdditionLinear"
    AdditionRand = "AdditionRand"
    ReplacementLinear = "ReplacementLinear"
    ReplacementRand = "ReplacementRand"

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D



markers = ["o", "s", "D", "v", "^"]
labels = [
    "Deletion",
    r"$Addition_{Linear}$",
    r"$Addition_{Random}$",
    r"$Replacement_{Linear}$",
    r"$Replacement_{Random}$",
]
dataset2colors = {}
colors = ["#ff595e","#1982c4","#6a4c93","#d677b8", "#222222"]
for k in results.keys():
    
    dataset_name = results[k]["name"]
    task_type = results[k]["type"]
    target_col = results[k]["target_col"]
    if task_type == "classification":
        fig, ax = plt.subplots(figsize=(12, 8))
        color = colors.pop(0)
        dataset2colors[dataset_name] = color
        for ptb_type in PerturbationType:
            if ptb_type.value not in results[k]:
                continue
            dcc_val = results[k][ptb_type.value]["dcc"]
            feats2shap = results[k][ptb_type.value]["feats2shap"]
            feats = list(feats2shap.keys())
            shape_values = [feats2shap[f] for f in feats]
            shape_values = np.array(shape_values)
            shape_values = shape_values / np.max(shape_values)  # Normalize to [0, 1]
            dcc_values = [dcc_val[f] for f in feats]
            plt.scatter(
                dcc_values,
                shape_values,
                marker=markers[list(PerturbationType).index(ptb_type)],
                s=100,
                color=color,
                label=f"{dataset_name}",
            )
        plt.xlabel(r"$DCC_{f_i}$")
        plt.ylabel(r"$SHAP_{f_i}$")

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


markers = ["o", "s", "D", "v", "^"]
labels = [
    "Deletion",
    r"$Addition_{Linear}$",
    r"$Addition_{Random}$",
    r"$Replacement_{Linear}$",
    r"$Replacement_{Random}$",
]
dataset2colors = {}
colors = ["#ff595e","#1982c4","#6a4c93","#d677b8", "#222222"]
for k in results.keys():
    dataset_name = results[k]["name"]
    task_type = results[k]["type"]
    target_col = results[k]["target_col"]
    if task_type == "regression":
        fig, ax = plt.subplots(figsize=(12, 8))
        color = colors.pop(0)
        dataset2colors[dataset_name] = color
        for ptb_type in PerturbationType:
            if ptb_type.value not in results[k]:
                continue
            dcc_val = results[k][ptb_type.value]["dcc"]
            feats2shap = results[k][ptb_type.value]["feats2shap"]
            feats = list(feats2shap.keys())
            shape_values = [feats2shap[f] for f in feats]
            shape_values = np.array(shape_values)
            shape_values = shape_values / np.max(shape_values)  # Normalize to [0, 1]
            dcc_values = [dcc_val[f] for f in feats]
            plt.scatter(
                dcc_values,
                shape_values,
                marker=markers[list(PerturbationType).index(ptb_type)],
                s=100,
                color=color,
                label=f"{dataset_name}",
            )

        plt.xlabel(r"$DCC_{f_i}$")
        plt.ylabel(r"$SHAP_{f_i}$")
